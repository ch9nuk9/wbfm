# %%
# %load_ext autoreload
# %autoreload 2
from DLC_for_WBFM.utils.projects.finished_project_data import ProjectData
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# fname = r"C:\dlc_stacks\Charlie-worm3-new-seg\project_config.yaml"
# fname = "/scratch/zimmer/Charles/dlc_stacks/worm3-2021_09_29/project_config.yaml"
fname = "/scratch/zimmer/Charles/dlc_stacks/worm3-leifer_template/project_config.yaml"
dat = ProjectData.load_final_project_data_from_config(fname)
# Out:
# ...
# Project data for directory:
# /scratch/zimmer/Charles/dlc_stacks/worm3-leifer_template
# ...
# Found the following data files:
# red_data: True
# green_data: True
# ============Segmentation===============
# raw_segmentation: True
# segmentation: True
# ============Tracklets==================
# df_training_tracklets: True
# reindexed_masks_training: True
# ============Traces=====================
# red_traces: True
# green_traces: True
# final_tracks: True
# behavior_annotations: True

# %%
neuron_name = 'neuron_048'


# %matplotlib widget
y = dat.calculate_traces(channel_mode='ratio',
                     calculation_mode='integration',
                     neuron_name=neuron_name, 
                     remove_outliers=False, 
                     filter_mode='no_filtering')
plt.plot(y)

y = dat.calculate_traces(channel_mode='ratio',
                     calculation_mode='integration',
                     neuron_name=neuron_name, 
                     remove_outliers=True, 
                     filter_mode='no_filtering')
plt.plot(y)
# Out:
# Calculating ratio trace for neuron_048 for integration mode
# Calculating ratio trace for neuron_048 for integration mode
# Calculated error threshold at 0.08352056755255552
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

y = dat.calculate_traces(channel_mode='ratio',
                     calculation_mode='integration',
                     neuron_name='neuron_058',
                     min_confidence=None)
plt.plot(y)

y = dat.calculate_traces(channel_mode='ratio',
                     calculation_mode='integration',
                     neuron_name='neuron_058',
                     min_confidence=0.7)
plt.plot(y)
# Out:
# Calculating ratio trace for neuron_058 for integration mode
# Calculating ratio trace for neuron_058 for integration mode
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
dat.final_tracks['neuron_058']['likelihood'].plot()
# Out:
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
