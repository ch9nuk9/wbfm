# %% [markdown]
# # Preprocessing
#
# Data life cycle for this project:
# - .stk (Volumes; Initial recording from microscope)
# - .stk -> .ome.tiff (Volumes; Fiji conversion; take only ~500 frames)
# - .ome.tiff -> .ome.tiff (Volumes to planes; this file)
# - .ome.tiff -> .avi (planes to video; this file)

# %%
import numpy as np
import tifffile
import os

from DLC_for_WBFM.utils.video_and_data_conversion.video_conversion_utils import *
from DLC_for_WBFM.utils.postprocessing.postprocessing_utils import get_crop_coords3d
from DLC_for_WBFM.bin.configuration_definition import *

import deeplabcut
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Read the mcherry data, and save a mini-max projection as .avi

# %% [markdown]
# ### Video settings for both channels

# %%
start_volume = 100

num_frames = 1000
# which_slices = [18, 19, 20, 21, 22]
# which_slices = [10, 11, 12, 13, 14]
num_total_slices = 33
num_crop_slices = 5
# start_slice = 10
# which_slices = list(range(start_slice, start_slice + 1 + num_slices))

center_slice = 12

which_slices = get_crop_coords3d((0,0,center_slice), (1,1,num_crop_slices))

alpha = 0.15 # For consistency; should be decided by hand

# %%
preprocessing = DLCForWBFMPreprocessing(start_volume, num_frames, num_total_slices, num_crop_slices, center_slice, 0.15)

# %% [markdown]
# ### Set up file names and project folder

# %%
def get_mcherry_names():
    """
    Local function, to be changed for each project
    """
    # channel 1
    if os.name == 'nt':
        input_foldername = 'D:\\More-stabilized-wbfm\\test2020-10-22_16-15-20_test4-channel-0-pco_camera1'
    else:
        input_foldername = '/groups/zimmer/Ulises/wbfm/20200924and28/202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1/'
    fname = 'test2020-10-22_16-15-20_test4-channel-0-pco_camera1bigtiff.btf'
    input_fname = os.path.join(input_foldername, fname)
    input_fname = os.path.normpath(input_fname) # Make it work on windows


    # Final .avi
    if os.name == 'nt':
        output_foldername = input_foldername
    else:
        output_foldername = '/users/charles.fieseler/shared_projects/wbfm/dat/short_wbfm_z_stabilized/'
    fname = f'test2020-10-22_mcherry_fr{num_frames}_sl{which_slices[0]}_{which_slices[-1]}.avi'
    output_fname = os.path.join(output_foldername, fname)
    
    return input_fname, output_fname, input_foldername, output_foldername

def get_gcamp_names():
    """
    Local function, to be changed for each project
    """
    if os.name == 'nt':
        input_foldername = 'D:\\More-stabilized-wbfm\\test2020-10-22_16-15-20_test4-channel-1-pco_camera2'
    else:
        input_foldername = '/groups/zimmer/Ulises/wbfm/20200924and28/202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1/'
    fname = 'test2020-10-22_16-15-20_test4-channel-1-pco_camera2bigtiff.btf'
    input_fname = os.path.join(input_foldername, fname)
    input_fname = os.path.normpath(input_fname) # Make it work on windows


    # Final .avi
    if os.name == 'nt':
        output_foldername = input_foldername
    else:
        output_foldername = '/users/charles.fieseler/shared_projects/wbfm/dat/short_wbfm_z_stabilized/'
    fname = f'test2020-10-22_gcamp_fr{num_frames}_sl{which_slices[0]}_{which_slices[-1]}.avi'
    output_fname = os.path.join(output_foldername, fname)
    
    return input_fname, output_fname, input_foldername, output_foldername

# %%
input_red_fname, output_red_fname, _, _ = get_mcherry_names()
input_green_fname, output_green_fname, _, _ = get_mcherry_names()

# %%
if os.name == 'nt':
    project_foldername = 'C:\\Users\\charles.fieseler\\Documents\\Current_work\\DLC_for_WBFM\\DLC_Projects'
else:
    raise Exception
task = 'wbfm_3d'
experimenter = 'Charlie'

# %%
datafiles = DLCForWBFMDatafiles(input_red_fname, input_green_fname,
                                   output_red_fname, output_green_fname)

config = DLCForWBFMConfig('Charlie', datafiles, preprocessing)

# %% [markdown]
# ## NEW: just use config files

# %%
write_all_video_projection_from_ome_file_subset_test(config)
# Out:
# Taking a max of 5 slices, starting at 10
# Taking a max of 5 slices, starting at 10

# %% [markdown]
# # Old: no config files

# %% [markdown]
# ### Get frame size

# %%
# Get the exact frame size
tif = tifffile.TiffFile(input_fname)
with tifffile.TiffFile(input_fname) as tif:
    frame_height, frame_width = tif.pages[0].shape
#     alpha = 0.9 * 255.0 / np.max(tif.pages[0].asarray())
print(frame_height, frame_width)
# Out:
# 700 900

# %%
write_video_projection_from_ome_file_subset(input_fname, output_fname, which_slices=which_slices,
                                             frame_width=frame_width, frame_height=frame_height,
                                             start_volume=start_volume,
                                             num_slices=33,
                                             num_frames=num_frames,
                                             alpha=alpha) # e.g. from above OME-TIFF
# Out:
# Converting volume index 100 to frame index 3300
# Taking a max of 6 slices, starting at 10
# Page 3310/33000; a portion of slice 0/1000 to tmp array index 0
# Page 3311/33000; a portion of slice 0/1000 to tmp array index 1
# Page 3312/33000; a portion of slice 0/1000 to tmp array index 2
# Page 3313/33000; a portion of slice 0/1000 to tmp array index 3
# Page 3314/33000; a portion of slice 0/1000 to tmp array index 4
# Page 3315/33000; a portion of slice 0/1000 to tmp array index 5
# Page 3343/33000; a portion of slice 1/1000 to tmp array index 0
# Page 3344/33000; a portion of slice 1/1000 to tmp array index 1
# Page 3345/33000; a portion of slice 1/1000 to tmp array index 2
# Page 3346/33000; a portion of slice 1/1000 to tmp array index 3
# Page 3347/33000; a portion of slice 1/1000 to tmp array index 4
# Page 3348/33000; a portion of slice 1/1000 to tmp array index 5
# Page 3376/33000; a portion of slice 2/1000 to tmp array index 0
# Page 3377/33000; a portion of slice 2/1000 to tmp array index 1
# Page 3378/33000; a portion of slice 2/1000 to tmp array index 2
# Page 3379/33000; a portion of slice 2/1000 to tmp array index 3
# Page 3380/33000; a portion of slice 2/1000 to tmp array index 4
# Page 3381/33000; a portion of slice 2/1000 to tmp array index 5
# Page 3409/33000; a portion of slice 3/1000 to tmp array index 0
# Page 3410/33000; a portion of slice 3/1000 to tmp array index 1
# Page 3411/33000; a portion of slice 3/1000 to tmp array index 2
# Page 3412/33000; a portion of slice 3/1000 to tmp array index 3
# Page 3413/33000; a portion of slice 3/1000 to tmp array index 4
# Page 3414/33000; a portion of slice 3/1000 to tmp array index 5
# Page 3442/33000; a portion of slice 4/1000 to tmp array index 0
# Page 3443/33000; a portion of slice 4/1000 to tmp array index 1
# Page 3444/33000; a portion of slice 4/1000 to tmp array index 2
# Page 3445/33000; a portion of slice 4/1000 to tmp array index 3
# Page 3446/33000; a portion of slice 4/1000 to tmp array index 4
# Page 3447/33000; a portion of slice 4/1000 to tmp array index 5
# Page 3475/33000; a portion of slice 5/1000 to tmp array index 0
# Page 3476/33000; a portion of slice 5/1000 to tmp array index 1
# Page 3477/33000; a portion of slice 5/1000 to tmp array index 2
# Page 3478/33000; a portion of slice 5/1000 to tmp array index 3
# Page 3479/33000; a portion of slice 5/1000 to tmp array index 4
# Page 3480/33000; a portion of slice 5/1000 to tmp array index 5
# Page 3508/33000; a portion of slice 6/1000 to tmp array index 0
# Page 3509/33000; a portion of slice 6/1000 to tmp array index 1
# Page 3510/33000; a portion of slice 6/1000 to tmp array index 2
# Page 3511/33000; a portion of slice 6/1000 to tmp array index 3
# Page 3512/33000; a portion of slice 6/1000 to tmp array index 4
# Page 3513/33000; a portion of slice 6/1000 to tmp array index 5
# Page 3541/33000; a portion of slice 7/1000 to tmp array index 0
# Page 3542/33000; a portion of slice 7/1000 to tmp array index 1
# Page 3543/33000; a portion of slice 7/1000 to tmp array index 2
# Page 3544/33000; a portion of slice 7/1000 to tmp array index 3
# Page 3545/33000; a portion of slice 7/1000 to tmp array index 4
# Page 3546/33000; a portion of slice 7/1000 to tmp array index 5
# Page 3574/33000; a portion of slice 8/1000 to tmp array index 0
# Page 3575/33000; a portion of slice 8/1000 to tmp array index 1
# Page 3576/33000; a portion of slice 8/1000 to tmp array index 2
# Page 3577/33000; a portion of slice 8/1000 to tmp array index 3
# Page 3578/33000; a portion of slice 8/1000 to tmp array index 4
# Page 3579/33000; a portion of slice 8/1000 to tmp array index 5
# Page 3607/33000; a portion of slice 9/1000 to tmp array index 0
# Page 3608/33000; a portion of slice 9/1000 to tmp array index 1
# Page 3609/33000; a portion of slice 9/1000 to tmp array index 2
# Page 3610/33000; a portion of slice 9/1000 to tmp array index 3
# Page 3611/33000; a portion of slice 9/1000 to tmp array index 4
# Page 3612/33000; a portion of slice 9/1000 to tmp array index 5
# Page 3640/33000; a portion of slice 10/1000 to tmp array index 0
# Page 3641/33000; a portion of slice 10/1000 to tmp array index 1
# Page 3642/33000; a portion of slice 10/1000 to tmp array index 2
# Page 3643/33000; a portion of slice 10/1000 to tmp array index 3
# Page 3644/33000; a portion of slice 10/1000 to tmp array index 4
# Page 3645/33000; a portion of slice 10/1000 to tmp array index 5
# Page 3673/33000; a portion of slice 11/1000 to tmp array index 0
# Page 3674/33000; a portion of slice 11/1000 to tmp array index 1
# Page 3675/33000; a portion of slice 11/1000 to tmp array index 2
# Page 3676/33000; a portion of slice 11/1000 to tmp array index 3
# Page 3677/33000; a portion of slice 11/1000 to tmp array index 4
# Page 3678/33000; a portion of slice 11/1000 to tmp array index 5
# Page 3706/33000; a portion of slice 12/1000 to tmp array index 0
# Page 3707/33000; a portion of slice 12/1000 to tmp array index 1
# Page 3708/33000; a portion of slice 12/1000 to tmp array index 2
# Page 3709/33000; a portion of slice 12/1000 to tmp array index 3
# Page 3710/33000; a portion of slice 12/1000 to tmp array index 4
# Page 3711/33000; a portion of slice 12/1000 to tmp array index 5
# Page 3739/33000; a portion of slice 13/1000 to tmp array index 0
# Page 3740/33000; a portion of slice 13/1000 to tmp array index 1
# Page 3741/33000; a portion of slice 13/1000 to tmp array index 2
# Page 3742/33000; a portion of slice 13/1000 to tmp array index 3
# Page 3743/33000; a portion of slice 13/1000 to tmp array index 4
# Page 3744/33000; a portion of slice 13/1000 to tmp array index 5
# Page 3772/33000; a portion of slice 14/1000 to tmp array index 0
# Page 3773/33000; a portion of slice 14/1000 to tmp array index 1
# Page 3774/33000; a portion of slice 14/1000 to tmp array index 2
# Page 3775/33000; a portion of slice 14/1000 to tmp array index 3
# Page 3776/33000; a portion of slice 14/1000 to tmp array index 4
# Page 3777/33000; a portion of slice 14/1000 to tmp array index 5
# Page 3805/33000; a portion of slice 15/1000 to tmp array index 0
# Page 3806/33000; a portion of slice 15/1000 to tmp array index 1
# Page 3807/33000; a portion of slice 15/1000 to tmp array index 2
# Page 3808/33000; a portion of slice 15/1000 to tmp array index 3
# Page 3809/33000; a portion of slice 15/1000 to tmp array index 4
# Page 3810/33000; a portion of slice 15/1000 to tmp array index 5
# Page 3838/33000; a portion of slice 16/1000 to tmp array index 0
# Page 3839/33000; a portion of slice 16/1000 to tmp array index 1
# Page 3840/33000; a portion of slice 16/1000 to tmp array index 2
# Page 3841/33000; a portion of slice 16/1000 to tmp array index 3
# Page 3842/33000; a portion of slice 16/1000 to tmp array index 4
# Page 3843/33000; a portion of slice 16/1000 to tmp array index 5
# Page 3871/33000; a portion of slice 17/1000 to tmp array index 0
# Page 3872/33000; a portion of slice 17/1000 to tmp array index 1
# Page 3873/33000; a portion of slice 17/1000 to tmp array index 2
# Page 3874/33000; a portion of slice 17/1000 to tmp array index 3
# Page 3875/33000; a portion of slice 17/1000 to tmp array index 4
# Page 3876/33000; a portion of slice 17/1000 to tmp array index 5
# Page 3904/33000; a portion of slice 18/1000 to tmp array index 0
# Page 3905/33000; a portion of slice 18/1000 to tmp array index 1
# Page 3906/33000; a portion of slice 18/1000 to tmp array index 2
# Page 3907/33000; a portion of slice 18/1000 to tmp array index 3
# Page 3908/33000; a portion of slice 18/1000 to tmp array index 4
# Page 3909/33000; a portion of slice 18/1000 to tmp array index 5
# Page 3937/33000; a portion of slice 19/1000 to tmp array index 0
# Page 3938/33000; a portion of slice 19/1000 to tmp array index 1
# Page 3939/33000; a portion of slice 19/1000 to tmp array index 2
# Page 3940/33000; a portion of slice 19/1000 to tmp array index 3
# Page 3941/33000; a portion of slice 19/1000 to tmp array index 4
# Page 3942/33000; a portion of slice 19/1000 to tmp array index 5
# Page 3970/33000; a portion of slice 20/1000 to tmp array index 0
# Page 3971/33000; a portion of slice 20/1000 to tmp array index 1
# Page 3972/33000; a portion of slice 20/1000 to tmp array index 2
# Page 3973/33000; a portion of slice 20/1000 to tmp array index 3
# Page 3974/33000; a portion of slice 20/1000 to tmp array index 4
# Page 3975/33000; a portion of slice 20/1000 to tmp array index 5
# Page 4003/33000; a portion of slice 21/1000 to tmp array index 0
# Page 4004/33000; a portion of slice 21/1000 to tmp array index 1
# Page 4005/33000; a portion of slice 21/1000 to tmp array index 2
# Page 4006/33000; a portion of slice 21/1000 to tmp array index 3
# Page 4007/33000; a portion of slice 21/1000 to tmp array index 4
# Page 4008/33000; a portion of slice 21/1000 to tmp array index 5
# Page 4036/33000; a portion of slice 22/1000 to tmp array index 0
# Page 4037/33000; a portion of slice 22/1000 to tmp array index 1
# Page 4038/33000; a portion of slice 22/1000 to tmp array index 2
# Page 4039/33000; a portion of slice 22/1000 to tmp array index 3
# Page 4040/33000; a portion of slice 22/1000 to tmp array index 4
# Page 4041/33000; a portion of slice 22/1000 to tmp array index 5
# Page 4069/33000; a portion of slice 23/1000 to tmp array index 0
# Page 4070/33000; a portion of slice 23/1000 to tmp array index 1
# Page 4071/33000; a portion of slice 23/1000 to tmp array index 2
# Page 4072/33000; a portion of slice 23/1000 to tmp array index 3
# Page 4073/33000; a portion of slice 23/1000 to tmp array index 4
# Page 4074/33000; a portion of slice 23/1000 to tmp array index 5
# Page 4102/33000; a portion of slice 24/1000 to tmp array index 0
# Page 4103/33000; a portion of slice 24/1000 to tmp array index 1
# Page 4104/33000; a portion of slice 24/1000 to tmp array index 2
# Page 4105/33000; a portion of slice 24/1000 to tmp array index 3
# Page 4106/33000; a portion of slice 24/1000 to tmp array index 4
# Page 4107/33000; a portion of slice 24/1000 to tmp array index 5
# Page 4135/33000; a portion of slice 25/1000 to tmp array index 0
# Page 4136/33000; a portion of slice 25/1000 to tmp array index 1
# Page 4137/33000; a portion of slice 25/1000 to tmp array index 2
# Page 4138/33000; a portion of slice 25/1000 to tmp array index 3
# Page 4139/33000; a portion of slice 25/1000 to tmp array index 4
# Page 4140/33000; a portion of slice 25/1000 to tmp array index 5
# Page 4168/33000; a portion of slice 26/1000 to tmp array index 0
# Page 4169/33000; a portion of slice 26/1000 to tmp array index 1
# Page 4170/33000; a portion of slice 26/1000 to tmp array index 2
# Page 4171/33000; a portion of slice 26/1000 to tmp array index 3
# Page 4172/33000; a portion of slice 26/1000 to tmp array index 4
# Page 4173/33000; a portion of slice 26/1000 to tmp array index 5
# Page 4201/33000; a portion of slice 27/1000 to tmp array index 0
# Page 4202/33000; a portion of slice 27/1000 to tmp array index 1
# Page 4203/33000; a portion of slice 27/1000 to tmp array index 2
# Page 4204/33000; a portion of slice 27/1000 to tmp array index 3
# Page 4205/33000; a portion of slice 27/1000 to tmp array index 4
# Page 4206/33000; a portion of slice 27/1000 to tmp array index 5
# Page 4234/33000; a portion of slice 28/1000 to tmp array index 0
# Page 4235/33000; a portion of slice 28/1000 to tmp array index 1
# Page 4236/33000; a portion of slice 28/1000 to tmp array index 2
# Page 4237/33000; a portion of slice 28/1000 to tmp array index 3
# Page 4238/33000; a portion of slice 28/1000 to tmp array index 4
# Page 4239/33000; a portion of slice 28/1000 to tmp array index 5
# Page 4267/33000; a portion of slice 29/1000 to tmp array index 0
# Page 4268/33000; a portion of slice 29/1000 to tmp array index 1
# Page 4269/33000; a portion of slice 29/1000 to tmp array index 2
# Page 4270/33000; a portion of slice 29/1000 to tmp array index 3
# Page 4271/33000; a portion of slice 29/1000 to tmp array index 4
# Page 4272/33000; a portion of slice 29/1000 to tmp array index 5
# Page 4300/33000; a portion of slice 30/1000 to tmp array index 0
# Page 4301/33000; a portion of slice 30/1000 to tmp array index 1
# Page 4302/33000; a portion of slice 30/1000 to tmp array index 2
# Page 4303/33000; a portion of slice 30/1000 to tmp array index 3
# Page 4304/33000; a portion of slice 30/1000 to tmp array index 4
# Page 4305/33000; a portion of slice 30/1000 to tmp array index 5
# Page 4333/33000; a portion of slice 31/1000 to tmp array index 0
# Page 4334/33000; a portion of slice 31/1000 to tmp array index 1
# Page 4335/33000; a portion of slice 31/1000 to tmp array index 2
# Page 4336/33000; a portion of slice 31/1000 to tmp array index 3
# Page 4337/33000; a portion of slice 31/1000 to tmp array index 4
# Page 4338/33000; a portion of slice 31/1000 to tmp array index 5
# Page 4366/33000; a portion of slice 32/1000 to tmp array index 0
# Page 4367/33000; a portion of slice 32/1000 to tmp array index 1
# Page 4368/33000; a portion of slice 32/1000 to tmp array index 2
# Page 4369/33000; a portion of slice 32/1000 to tmp array index 3
# Page 4370/33000; a portion of slice 32/1000 to tmp array index 4
# Page 4371/33000; a portion of slice 32/1000 to tmp array index 5
# Page 4399/33000; a portion of slice 33/1000 to tmp array index 0
# Page 4400/33000; a portion of slice 33/1000 to tmp array index 1
# Page 4401/33000; a portion of slice 33/1000 to tmp array index 2
# Page 4402/33000; a portion of slice 33/1000 to tmp array index 3
# Page 4403/33000; a portion of slice 33/1000 to tmp array index 4
# Page 4404/33000; a portion of slice 33/1000 to tmp array index 5
# Page 4432/33000; a portion of slice 34/1000 to tmp array index 0
# Page 4433/33000; a portion of slice 34/1000 to tmp array index 1
# Page 4434/33000; a portion of slice 34/1000 to tmp array index 2
# Page 4435/33000; a portion of slice 34/1000 to tmp array index 3
# Page 4436/33000; a portion of slice 34/1000 to tmp array index 4
# Page 4437/33000; a portion of slice 34/1000 to tmp array index 5
# Page 4465/33000; a portion of slice 35/1000 to tmp array index 0
# Page 4466/33000; a portion of slice 35/1000 to tmp array index 1
# Page 4467/33000; a portion of slice 35/1000 to tmp array index 2
# Page 4468/33000; a portion of slice 35/1000 to tmp array index 3
# Page 4469/33000; a portion of slice 35/1000 to tmp array index 4
# Page 4470/33000; a portion of slice 35/1000 to tmp array index 5
# Page 4498/33000; a portion of slice 36/1000 to tmp array index 0
# Page 4499/33000; a portion of slice 36/1000 to tmp array index 1
# Page 4500/33000; a portion of slice 36/1000 to tmp array index 2
# Page 4501/33000; a portion of slice 36/1000 to tmp array index 3
# Page 4502/33000; a portion of slice 36/1000 to tmp array index 4
# Page 4503/33000; a portion of slice 36/1000 to tmp array index 5
# Page 4531/33000; a portion of slice 37/1000 to tmp array index 0
# Page 4532/33000; a portion of slice 37/1000 to tmp array index 1
# Page 4533/33000; a portion of slice 37/1000 to tmp array index 2
# Page 4534/33000; a portion of slice 37/1000 to tmp array index 3
# Page 4535/33000; a portion of slice 37/1000 to tmp array index 4
# Page 4536/33000; a portion of slice 37/1000 to tmp array index 5
# Page 4564/33000; a portion of slice 38/1000 to tmp array index 0
# Page 4565/33000; a portion of slice 38/1000 to tmp array index 1
# Page 4566/33000; a portion of slice 38/1000 to tmp array index 2
# Page 4567/33000; a portion of slice 38/1000 to tmp array index 3
# Page 4568/33000; a portion of slice 38/1000 to tmp array index 4
# Page 4569/33000; a portion of slice 38/1000 to tmp array index 5
# Page 4597/33000; a portion of slice 39/1000 to tmp array index 0
# Page 4598/33000; a portion of slice 39/1000 to tmp array index 1
# Page 4599/33000; a portion of slice 39/1000 to tmp array index 2
# Page 4600/33000; a portion of slice 39/1000 to tmp array index 3
# Page 4601/33000; a portion of slice 39/1000 to tmp array index 4
# Page 4602/33000; a portion of slice 39/1000 to tmp array index 5
# Page 4630/33000; a portion of slice 40/1000 to tmp array index 0
# Page 4631/33000; a portion of slice 40/1000 to tmp array index 1
# Page 4632/33000; a portion of slice 40/1000 to tmp array index 2
# Page 4633/33000; a portion of slice 40/1000 to tmp array index 3
# Page 4634/33000; a portion of slice 40/1000 to tmp array index 4
# Page 4635/33000; a portion of slice 40/1000 to tmp array index 5
# Page 4663/33000; a portion of slice 41/1000 to tmp array index 0
# Page 4664/33000; a portion of slice 41/1000 to tmp array index 1
# Page 4665/33000; a portion of slice 41/1000 to tmp array index 2
# Page 4666/33000; a portion of slice 41/1000 to tmp array index 3
# Page 4667/33000; a portion of slice 41/1000 to tmp array index 4
# Page 4668/33000; a portion of slice 41/1000 to tmp array index 5
# Page 4696/33000; a portion of slice 42/1000 to tmp array index 0
# Page 4697/33000; a portion of slice 42/1000 to tmp array index 1
# Page 4698/33000; a portion of slice 42/1000 to tmp array index 2
# Page 4699/33000; a portion of slice 42/1000 to tmp array index 3
# Page 4700/33000; a portion of slice 42/1000 to tmp array index 4
# Page 4701/33000; a portion of slice 42/1000 to tmp array index 5
# Page 4729/33000; a portion of slice 43/1000 to tmp array index 0
# Page 4730/33000; a portion of slice 43/1000 to tmp array index 1
# Page 4731/33000; a portion of slice 43/1000 to tmp array index 2
# Page 4732/33000; a portion of slice 43/1000 to tmp array index 3
# Page 4733/33000; a portion of slice 43/1000 to tmp array index 4
# Page 4734/33000; a portion of slice 43/1000 to tmp array index 5
# Page 4762/33000; a portion of slice 44/1000 to tmp array index 0
# Page 4763/33000; a portion of slice 44/1000 to tmp array index 1
# Page 4764/33000; a portion of slice 44/1000 to tmp array index 2
# Page 4765/33000; a portion of slice 44/1000 to tmp array index 3
# Page 4766/33000; a portion of slice 44/1000 to tmp array index 4
# Page 4767/33000; a portion of slice 44/1000 to tmp array index 5
# Page 4795/33000; a portion of slice 45/1000 to tmp array index 0
# Page 4796/33000; a portion of slice 45/1000 to tmp array index 1
# Page 4797/33000; a portion of slice 45/1000 to tmp array index 2
# Page 4798/33000; a portion of slice 45/1000 to tmp array index 3
# Page 4799/33000; a portion of slice 45/1000 to tmp array index 4
# Page 4800/33000; a portion of slice 45/1000 to tmp array index 5
# Page 4828/33000; a portion of slice 46/1000 to tmp array index 0
# Page 4829/33000; a portion of slice 46/1000 to tmp array index 1
# Page 4830/33000; a portion of slice 46/1000 to tmp array index 2
# Page 4831/33000; a portion of slice 46/1000 to tmp array index 3
# Page 4832/33000; a portion of slice 46/1000 to tmp array index 4
# Page 4833/33000; a portion of slice 46/1000 to tmp array index 5
# Page 4861/33000; a portion of slice 47/1000 to tmp array index 0
# Page 4862/33000; a portion of slice 47/1000 to tmp array index 1
# Page 4863/33000; a portion of slice 47/1000 to tmp array index 2
# Page 4864/33000; a portion of slice 47/1000 to tmp array index 3
# Page 4865/33000; a portion of slice 47/1000 to tmp array index 4
# Page 4866/33000; a portion of slice 47/1000 to tmp array index 5
# Page 4894/33000; a portion of slice 48/1000 to tmp array index 0
# Page 4895/33000; a portion of slice 48/1000 to tmp array index 1
# Page 4896/33000; a portion of slice 48/1000 to tmp array index 2
# Page 4897/33000; a portion of slice 48/1000 to tmp array index 3
# Page 4898/33000; a portion of slice 48/1000 to tmp array index 4
# Page 4899/33000; a portion of slice 48/1000 to tmp array index 5
# Page 4927/33000; a portion of slice 49/1000 to tmp array index 0
# Page 4928/33000; a portion of slice 49/1000 to tmp array index 1
# Page 4929/33000; a portion of slice 49/1000 to tmp array index 2
# Page 4930/33000; a portion of slice 49/1000 to tmp array index 3
# Page 4931/33000; a portion of slice 49/1000 to tmp array index 4
# Page 4932/33000; a portion of slice 49/1000 to tmp array index 5
# Page 4960/33000; a portion of slice 50/1000 to tmp array index 0
# Page 4961/33000; a portion of slice 50/1000 to tmp array index 1
# Page 4962/33000; a portion of slice 50/1000 to tmp array index 2
# Page 4963/33000; a portion of slice 50/1000 to tmp array index 3
# Page 4964/33000; a portion of slice 50/1000 to tmp array index 4
# Page 4965/33000; a portion of slice 50/1000 to tmp array index 5
# Page 4993/33000; a portion of slice 51/1000 to tmp array index 0
# Page 4994/33000; a portion of slice 51/1000 to tmp array index 1
# Page 4995/33000; a portion of slice 51/1000 to tmp array index 2
# Page 4996/33000; a portion of slice 51/1000 to tmp array index 3
# Page 4997/33000; a portion of slice 51/1000 to tmp array index 4
# Page 4998/33000; a portion of slice 51/1000 to tmp array index 5
# Page 5026/33000; a portion of slice 52/1000 to tmp array index 0
# Page 5027/33000; a portion of slice 52/1000 to tmp array index 1
# Page 5028/33000; a portion of slice 52/1000 to tmp array index 2
# Page 5029/33000; a portion of slice 52/1000 to tmp array index 3
# Page 5030/33000; a portion of slice 52/1000 to tmp array index 4
# Page 5031/33000; a portion of slice 52/1000 to tmp array index 5
# Page 5059/33000; a portion of slice 53/1000 to tmp array index 0
# Page 5060/33000; a portion of slice 53/1000 to tmp array index 1
# Page 5061/33000; a portion of slice 53/1000 to tmp array index 2
# Page 5062/33000; a portion of slice 53/1000 to tmp array index 3
# Page 5063/33000; a portion of slice 53/1000 to tmp array index 4
# Page 5064/33000; a portion of slice 53/1000 to tmp array index 5
# Page 5092/33000; a portion of slice 54/1000 to tmp array index 0
# Page 5093/33000; a portion of slice 54/1000 to tmp array index 1
# Page 5094/33000; a portion of slice 54/1000 to tmp array index 2
# Page 5095/33000; a portion of slice 54/1000 to tmp array index 3
# Page 5096/33000; a portion of slice 54/1000 to tmp array index 4
# Page 5097/33000; a portion of slice 54/1000 to tmp array index 5
# Page 5125/33000; a portion of slice 55/1000 to tmp array index 0
# Page 5126/33000; a portion of slice 55/1000 to tmp array index 1
# Page 5127/33000; a portion of slice 55/1000 to tmp array index 2
# Page 5128/33000; a portion of slice 55/1000 to tmp array index 3
# Page 5129/33000; a portion of slice 55/1000 to tmp array index 4
# Page 5130/33000; a portion of slice 55/1000 to tmp array index 5
# Page 5158/33000; a portion of slice 56/1000 to tmp array index 0
# Page 5159/33000; a portion of slice 56/1000 to tmp array index 1
# Page 5160/33000; a portion of slice 56/1000 to tmp array index 2
# Page 5161/33000; a portion of slice 56/1000 to tmp array index 3
# Page 5162/33000; a portion of slice 56/1000 to tmp array index 4
# Page 5163/33000; a portion of slice 56/1000 to tmp array index 5
# Page 5191/33000; a portion of slice 57/1000 to tmp array index 0
# Page 5192/33000; a portion of slice 57/1000 to tmp array index 1
# Page 5193/33000; a portion of slice 57/1000 to tmp array index 2
# Page 5194/33000; a portion of slice 57/1000 to tmp array index 3
# Page 5195/33000; a portion of slice 57/1000 to tmp array index 4
# Page 5196/33000; a portion of slice 57/1000 to tmp array index 5
# Page 5224/33000; a portion of slice 58/1000 to tmp array index 0
# Page 5225/33000; a portion of slice 58/1000 to tmp array index 1
# Page 5226/33000; a portion of slice 58/1000 to tmp array index 2
# Page 5227/33000; a portion of slice 58/1000 to tmp array index 3
# Page 5228/33000; a portion of slice 58/1000 to tmp array index 4
# Page 5229/33000; a portion of slice 58/1000 to tmp array index 5
# Page 5257/33000; a portion of slice 59/1000 to tmp array index 0
# Page 5258/33000; a portion of slice 59/1000 to tmp array index 1
# Page 5259/33000; a portion of slice 59/1000 to tmp array index 2
# Page 5260/33000; a portion of slice 59/1000 to tmp array index 3
# Page 5261/33000; a portion of slice 59/1000 to tmp array index 4
# Page 5262/33000; a portion of slice 59/1000 to tmp array index 5
# Page 5290/33000; a portion of slice 60/1000 to tmp array index 0
# Page 5291/33000; a portion of slice 60/1000 to tmp array index 1
# Page 5292/33000; a portion of slice 60/1000 to tmp array index 2
# Page 5293/33000; a portion of slice 60/1000 to tmp array index 3
# Page 5294/33000; a portion of slice 60/1000 to tmp array index 4
# Page 5295/33000; a portion of slice 60/1000 to tmp array index 5
# Page 5323/33000; a portion of slice 61/1000 to tmp array index 0
# Page 5324/33000; a portion of slice 61/1000 to tmp array index 1
# Page 5325/33000; a portion of slice 61/1000 to tmp array index 2
# Page 5326/33000; a portion of slice 61/1000 to tmp array index 3
# Page 5327/33000; a portion of slice 61/1000 to tmp array index 4
# Page 5328/33000; a portion of slice 61/1000 to tmp array index 5
# Page 5356/33000; a portion of slice 62/1000 to tmp array index 0
# Page 5357/33000; a portion of slice 62/1000 to tmp array index 1
# Page 5358/33000; a portion of slice 62/1000 to tmp array index 2
# Page 5359/33000; a portion of slice 62/1000 to tmp array index 3
# Page 5360/33000; a portion of slice 62/1000 to tmp array index 4
# Page 5361/33000; a portion of slice 62/1000 to tmp array index 5
# Page 5389/33000; a portion of slice 63/1000 to tmp array index 0
# Page 5390/33000; a portion of slice 63/1000 to tmp array index 1
# Page 5391/33000; a portion of slice 63/1000 to tmp array index 2
# Page 5392/33000; a portion of slice 63/1000 to tmp array index 3
# Page 5393/33000; a portion of slice 63/1000 to tmp array index 4
# Page 5394/33000; a portion of slice 63/1000 to tmp array index 5
# Page 5422/33000; a portion of slice 64/1000 to tmp array index 0
# Page 5423/33000; a portion of slice 64/1000 to tmp array index 1
# Page 5424/33000; a portion of slice 64/1000 to tmp array index 2
# Page 5425/33000; a portion of slice 64/1000 to tmp array index 3
# Page 5426/33000; a portion of slice 64/1000 to tmp array index 4
# Page 5427/33000; a portion of slice 64/1000 to tmp array index 5
# Page 5455/33000; a portion of slice 65/1000 to tmp array index 0
# Page 5456/33000; a portion of slice 65/1000 to tmp array index 1
# Page 5457/33000; a portion of slice 65/1000 to tmp array index 2
# Page 5458/33000; a portion of slice 65/1000 to tmp array index 3
# Page 5459/33000; a portion of slice 65/1000 to tmp array index 4
# Page 5460/33000; a portion of slice 65/1000 to tmp array index 5
# Page 5488/33000; a portion of slice 66/1000 to tmp array index 0
# Page 5489/33000; a portion of slice 66/1000 to tmp array index 1
# Page 5490/33000; a portion of slice 66/1000 to tmp array index 2
# Page 5491/33000; a portion of slice 66/1000 to tmp array index 3
# Page 5492/33000; a portion of slice 66/1000 to tmp array index 4
# Page 5493/33000; a portion of slice 66/1000 to tmp array index 5
# Page 5521/33000; a portion of slice 67/1000 to tmp array index 0
# Page 5522/33000; a portion of slice 67/1000 to tmp array index 1
# Page 5523/33000; a portion of slice 67/1000 to tmp array index 2
# Page 5524/33000; a portion of slice 67/1000 to tmp array index 3
# Page 5525/33000; a portion of slice 67/1000 to tmp array index 4
# Page 5526/33000; a portion of slice 67/1000 to tmp array index 5
# Page 5554/33000; a portion of slice 68/1000 to tmp array index 0
# Page 5555/33000; a portion of slice 68/1000 to tmp array index 1
# Page 5556/33000; a portion of slice 68/1000 to tmp array index 2
# Page 5557/33000; a portion of slice 68/1000 to tmp array index 3
# Page 5558/33000; a portion of slice 68/1000 to tmp array index 4
# Page 5559/33000; a portion of slice 68/1000 to tmp array index 5
# Page 5587/33000; a portion of slice 69/1000 to tmp array index 0
# Page 5588/33000; a portion of slice 69/1000 to tmp array index 1
# Page 5589/33000; a portion of slice 69/1000 to tmp array index 2
# Page 5590/33000; a portion of slice 69/1000 to tmp array index 3
# Page 5591/33000; a portion of slice 69/1000 to tmp array index 4
# Page 5592/33000; a portion of slice 69/1000 to tmp array index 5
# Page 5620/33000; a portion of slice 70/1000 to tmp array index 0
# Page 5621/33000; a portion of slice 70/1000 to tmp array index 1
# Page 5622/33000; a portion of slice 70/1000 to tmp array index 2
# Page 5623/33000; a portion of slice 70/1000 to tmp array index 3
# Page 5624/33000; a portion of slice 70/1000 to tmp array index 4
# Page 5625/33000; a portion of slice 70/1000 to tmp array index 5
# Page 5653/33000; a portion of slice 71/1000 to tmp array index 0
# Page 5654/33000; a portion of slice 71/1000 to tmp array index 1
# Page 5655/33000; a portion of slice 71/1000 to tmp array index 2
# Page 5656/33000; a portion of slice 71/1000 to tmp array index 3
# Page 5657/33000; a portion of slice 71/1000 to tmp array index 4
# Page 5658/33000; a portion of slice 71/1000 to tmp array index 5
# Page 5686/33000; a portion of slice 72/1000 to tmp array index 0
# Page 5687/33000; a portion of slice 72/1000 to tmp array index 1
# Page 5688/33000; a portion of slice 72/1000 to tmp array index 2
# Page 5689/33000; a portion of slice 72/1000 to tmp array index 3
# Page 5690/33000; a portion of slice 72/1000 to tmp array index 4
# Page 5691/33000; a portion of slice 72/1000 to tmp array index 5
# Page 5719/33000; a portion of slice 73/1000 to tmp array index 0
# Page 5720/33000; a portion of slice 73/1000 to tmp array index 1
# Page 5721/33000; a portion of slice 73/1000 to tmp array index 2
# Page 5722/33000; a portion of slice 73/1000 to tmp array index 3
# Page 5723/33000; a portion of slice 73/1000 to tmp array index 4
# Page 5724/33000; a portion of slice 73/1000 to tmp array index 5
# Page 5752/33000; a portion of slice 74/1000 to tmp array index 0
# Page 5753/33000; a portion of slice 74/1000 to tmp array index 1
# Page 5754/33000; a portion of slice 74/1000 to tmp array index 2
# Page 5755/33000; a portion of slice 74/1000 to tmp array index 3
# Page 5756/33000; a portion of slice 74/1000 to tmp array index 4
# Page 5757/33000; a portion of slice 74/1000 to tmp array index 5
# Page 5785/33000; a portion of slice 75/1000 to tmp array index 0
# Page 5786/33000; a portion of slice 75/1000 to tmp array index 1
# Page 5787/33000; a portion of slice 75/1000 to tmp array index 2
# Page 5788/33000; a portion of slice 75/1000 to tmp array index 3
# Page 5789/33000; a portion of slice 75/1000 to tmp array index 4
# Page 5790/33000; a portion of slice 75/1000 to tmp array index 5
# Page 5818/33000; a portion of slice 76/1000 to tmp array index 0
# Page 5819/33000; a portion of slice 76/1000 to tmp array index 1
# Page 5820/33000; a portion of slice 76/1000 to tmp array index 2
# Page 5821/33000; a portion of slice 76/1000 to tmp array index 3
# Page 5822/33000; a portion of slice 76/1000 to tmp array index 4
# Page 5823/33000; a portion of slice 76/1000 to tmp array index 5
# Page 5851/33000; a portion of slice 77/1000 to tmp array index 0
# Page 5852/33000; a portion of slice 77/1000 to tmp array index 1
# Page 5853/33000; a portion of slice 77/1000 to tmp array index 2
# Page 5854/33000; a portion of slice 77/1000 to tmp array index 3
# Page 5855/33000; a portion of slice 77/1000 to tmp array index 4
# Page 5856/33000; a portion of slice 77/1000 to tmp array index 5
# Page 5884/33000; a portion of slice 78/1000 to tmp array index 0
# Page 5885/33000; a portion of slice 78/1000 to tmp array index 1
# Page 5886/33000; a portion of slice 78/1000 to tmp array index 2
# Page 5887/33000; a portion of slice 78/1000 to tmp array index 3
# Page 5888/33000; a portion of slice 78/1000 to tmp array index 4
# Page 5889/33000; a portion of slice 78/1000 to tmp array index 5
# Page 5917/33000; a portion of slice 79/1000 to tmp array index 0
# Page 5918/33000; a portion of slice 79/1000 to tmp array index 1
# Page 5919/33000; a portion of slice 79/1000 to tmp array index 2
# Page 5920/33000; a portion of slice 79/1000 to tmp array index 3
# Page 5921/33000; a portion of slice 79/1000 to tmp array index 4
# Page 5922/33000; a portion of slice 79/1000 to tmp array index 5
# Page 5950/33000; a portion of slice 80/1000 to tmp array index 0
# Page 5951/33000; a portion of slice 80/1000 to tmp array index 1
# Page 5952/33000; a portion of slice 80/1000 to tmp array index 2
# Page 5953/33000; a portion of slice 80/1000 to tmp array index 3
# Page 5954/33000; a portion of slice 80/1000 to tmp array index 4
# Page 5955/33000; a portion of slice 80/1000 to tmp array index 5
# Page 5983/33000; a portion of slice 81/1000 to tmp array index 0
# Page 5984/33000; a portion of slice 81/1000 to tmp array index 1
# Page 5985/33000; a portion of slice 81/1000 to tmp array index 2
# Page 5986/33000; a portion of slice 81/1000 to tmp array index 3
# Page 5987/33000; a portion of slice 81/1000 to tmp array index 4
# Page 5988/33000; a portion of slice 81/1000 to tmp array index 5
# Page 6016/33000; a portion of slice 82/1000 to tmp array index 0
# Page 6017/33000; a portion of slice 82/1000 to tmp array index 1
# Page 6018/33000; a portion of slice 82/1000 to tmp array index 2
# Page 6019/33000; a portion of slice 82/1000 to tmp array index 3
# Page 6020/33000; a portion of slice 82/1000 to tmp array index 4
# Page 6021/33000; a portion of slice 82/1000 to tmp array index 5
# Page 6049/33000; a portion of slice 83/1000 to tmp array index 0
# Page 6050/33000; a portion of slice 83/1000 to tmp array index 1
# Page 6051/33000; a portion of slice 83/1000 to tmp array index 2
# Page 6052/33000; a portion of slice 83/1000 to tmp array index 3
# Page 6053/33000; a portion of slice 83/1000 to tmp array index 4
# Page 6054/33000; a portion of slice 83/1000 to tmp array index 5
# Page 6082/33000; a portion of slice 84/1000 to tmp array index 0
# Page 6083/33000; a portion of slice 84/1000 to tmp array index 1
# Page 6084/33000; a portion of slice 84/1000 to tmp array index 2
# Page 6085/33000; a portion of slice 84/1000 to tmp array index 3
# Page 6086/33000; a portion of slice 84/1000 to tmp array index 4
# Page 6087/33000; a portion of slice 84/1000 to tmp array index 5
# Page 6115/33000; a portion of slice 85/1000 to tmp array index 0
# Page 6116/33000; a portion of slice 85/1000 to tmp array index 1
# Page 6117/33000; a portion of slice 85/1000 to tmp array index 2
# Page 6118/33000; a portion of slice 85/1000 to tmp array index 3
# Page 6119/33000; a portion of slice 85/1000 to tmp array index 4
# Page 6120/33000; a portion of slice 85/1000 to tmp array index 5
# Page 6148/33000; a portion of slice 86/1000 to tmp array index 0
# Page 6149/33000; a portion of slice 86/1000 to tmp array index 1
# Page 6150/33000; a portion of slice 86/1000 to tmp array index 2
# Page 6151/33000; a portion of slice 86/1000 to tmp array index 3
# Page 6152/33000; a portion of slice 86/1000 to tmp array index 4
# Page 6153/33000; a portion of slice 86/1000 to tmp array index 5
# Page 6181/33000; a portion of slice 87/1000 to tmp array index 0
# Page 6182/33000; a portion of slice 87/1000 to tmp array index 1
# Page 6183/33000; a portion of slice 87/1000 to tmp array index 2
# Page 6184/33000; a portion of slice 87/1000 to tmp array index 3
# Page 6185/33000; a portion of slice 87/1000 to tmp array index 4
# Page 6186/33000; a portion of slice 87/1000 to tmp array index 5
# Page 6214/33000; a portion of slice 88/1000 to tmp array index 0
# Page 6215/33000; a portion of slice 88/1000 to tmp array index 1
# Page 6216/33000; a portion of slice 88/1000 to tmp array index 2
# Page 6217/33000; a portion of slice 88/1000 to tmp array index 3
# Page 6218/33000; a portion of slice 88/1000 to tmp array index 4
# Page 6219/33000; a portion of slice 88/1000 to tmp array index 5
# Page 6247/33000; a portion of slice 89/1000 to tmp array index 0
# Page 6248/33000; a portion of slice 89/1000 to tmp array index 1
# Page 6249/33000; a portion of slice 89/1000 to tmp array index 2
# Page 6250/33000; a portion of slice 89/1000 to tmp array index 3
# Page 6251/33000; a portion of slice 89/1000 to tmp array index 4
# Page 6252/33000; a portion of slice 89/1000 to tmp array index 5
# Page 6280/33000; a portion of slice 90/1000 to tmp array index 0
# Page 6281/33000; a portion of slice 90/1000 to tmp array index 1
# Page 6282/33000; a portion of slice 90/1000 to tmp array index 2
# Page 6283/33000; a portion of slice 90/1000 to tmp array index 3
# Page 6284/33000; a portion of slice 90/1000 to tmp array index 4
# Page 6285/33000; a portion of slice 90/1000 to tmp array index 5
# Page 6313/33000; a portion of slice 91/1000 to tmp array index 0
# Page 6314/33000; a portion of slice 91/1000 to tmp array index 1
# Page 6315/33000; a portion of slice 91/1000 to tmp array index 2

# %% [markdown]
# ## Do the same, but for other channel

# %%
input_fname, output_fname, _, _ = get_gcamp_names()

# %%
write_video_projection_from_ome_file_subset(input_fname, output_fname, which_slices=which_slices,
                                             frame_width=frame_width, frame_height=frame_height,
                                             num_slices=33,
                                             start_volume=start_volume,
                                             num_frames=num_frames,
                                             alpha=alpha,
                                             flip_x=True) # FLIP THE GCAMP

# %% [markdown]
# # Now, Make a DLC project folder and prep for annotations

# %% [markdown]
# ## Create a project and copy the mcherry from above

# %%
# %env DLClight=True
import deeplabcut
import os

# %%
mcherry_raw, mcherry_fname, input_foldername, _ = get_mcherry_names()

# %%
if os.name == 'nt':
    project_foldername = 'C:\\Users\\charles.fieseler\\Documents\\Current_work\\DLC_for_WBFM\\DLC_Projects'
else:
    raise Exception
task = 'wbfm_3d'
experimenter = 'Charlie'

# %%
path_config_file = deeplabcut.create_new_project(task,experimenter,videos=[output_fname],copy_videos=True,working_directory=project_foldername)

# %% [markdown]
# ## Extract individual volumes to be annotated

# %%
import deeplabcut
from DLC_for_WBFM.utils.preprocessing.custom_frame_extraction import *

# %%
# Get a couple volumes to annotate
num_training_volumes = 30
which_volumes = list(range(start_volume, start_volume + num_training_volumes))

# Take the entire z stack
which_slice = None
nz = 33

# %%
project_folder = 'C:\\Users\\charles.fieseler\\Documents\\Current_work\\DLC_for_WBFM\\DLC_Projects\\wbfm_3d-Charlie-2020-11-02\\'
path_config_file = os.path.join(project_folder, 'config.yaml')

video_fname = os.path.join(mcherry_raw)

# %%
extract_volume_from_tiff_in_dlc_project(path_config_file, nz=nz, which_vol=which_volumes, which_slice=which_slice, video_fname=video_fname)

# %% [markdown]
# ### Synchronize the chosen volumes with training frames
#
# For now, just pops up the GUI to do it manually

# %%
deeplabcut.extract_frames(path_config_file, mode='manual')

# %% [markdown]
# ## Now, use ICY to annotate in 3d
# __DONE BY HAND AND SAVED IN CORRECT FOLDER__

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Convert the generated .xml file to DLC format
from DLC_for_WBFM.utils.training_data.DLC_XML_conversion_utils import *
import deeplabcut

# %%
project_folder = 'C:\\Users\\charles.fieseler\\Documents\\Current_work\\DLC_for_WBFM\\DLC_Projects\\wbfm_3d-Charlie-2020-10-21\\'
path_config_file = os.path.join(project_folder, 'config.yaml')

video_fname = os.path.join(project_folder, 'videos\\mcherry_frames1000_slice17_22.btf')

# %%
df = icy_xml_to_dlc(path_config_file)

# %%
# Check the annotations
deeplabcut.check_labels(path_config_file)
