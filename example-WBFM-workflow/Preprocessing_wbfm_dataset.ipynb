# %% [markdown]
# # Preprocessing
#
# Data life cycle for this project:
# - .stk (Volumes; Initial recording from microscope)
# - .stk -> .ome.tiff (Volumes; Fiji conversion; take only ~500 frames)
# - .ome.tiff -> .ome.tiff (Volumes to planes; this file)
# - .ome.tiff -> .avi (planes to video; this file)

# %%
import numpy as np
import tifffile
import os

from DLC_for_WBFM.utils.video_and_data_conversion.video_conversion_utils import *

# %% [markdown]
# ## Read the mcherry data, and save a mini-max projection as .avi

# %% [markdown]
# ### Video settings for both channels

# %%
start_volume = 100

num_frames = 1000
# which_slices = [18, 19, 20, 21, 22]
# which_slices = [10, 11, 12, 13, 14]
num_slices = 5
start_slice = 17
which_slices = list(range(start_slice, start_slice + 1 + num_slices))

alpha = 0.15 # For consistency; should be decided by hand

# %% [markdown]
# ### Set up file names

# %%
# channel 1
if os.name == 'nt':
    input_foldername = 'Y:\\Ulises\\wbfm\\20200924and28\\202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1'
else:
    input_foldername = '/groups/zimmer/Ulises/wbfm/20200924and28/202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1/'
fname = '202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1bigtiff.btf'
input_fname = os.path.join(input_foldername, fname)
input_fname = os.path.normpath(input_fname) # Make it work on windows


# Final .avi
if os.name == 'nt':
    output_foldername = 'Y:\\shared_projects\\wbfm\\dat\\short_wbfm_z_stabilized'
else:
    output_foldername = '/users/charles.fieseler/shared_projects/wbfm/dat/short_wbfm_z_stabilized/'
fname = f'202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1_bigtiff_mcherry_frames{num_frames}_slice{which_slices[0]}_{which_slices[-1]}.avi'
output_fname = os.path.join(output_foldername, fname)

# %% [markdown]
# ### Get frame size

# %%
# Get the exact frame size
tif = tifffile.TiffFile(input_fname)
with tifffile.TiffFile(input_fname) as tif:
    frame_height, frame_width = tif.pages[0].shape
#     alpha = 0.9 * 255.0 / np.max(tif.pages[0].asarray())
# print(frame_height, frame_width)

# %%
write_video_projection_from_ome_file_subset(input_fname, output_fname, which_slices=which_slices,
                                             frame_width=frame_width, frame_height=frame_height,
                                             start_volume=start_volume,
                                             num_slices=33,
                                             num_frames=num_frames,
                                             alpha=alpha) # e.g. from above OME-TIFF
# Out:
# Converting volume index 100 to frame index 3300
# Taking a max of 6 slices, starting at 17
# Page 3317/33000; a portion of slice 0/1000 to tmp array index 0
# Page 3318/33000; a portion of slice 0/1000 to tmp array index 1
# Page 3319/33000; a portion of slice 0/1000 to tmp array index 2
# Page 3320/33000; a portion of slice 0/1000 to tmp array index 3
# Page 3321/33000; a portion of slice 0/1000 to tmp array index 4
# Page 3322/33000; a portion of slice 0/1000 to tmp array index 5
# Page 3350/33000; a portion of slice 1/1000 to tmp array index 0
# Page 3351/33000; a portion of slice 1/1000 to tmp array index 1
# Page 3352/33000; a portion of slice 1/1000 to tmp array index 2
# Page 3353/33000; a portion of slice 1/1000 to tmp array index 3
# Page 3354/33000; a portion of slice 1/1000 to tmp array index 4
# Page 3355/33000; a portion of slice 1/1000 to tmp array index 5
# Page 3383/33000; a portion of slice 2/1000 to tmp array index 0
# Page 3384/33000; a portion of slice 2/1000 to tmp array index 1
# Page 3385/33000; a portion of slice 2/1000 to tmp array index 2
# Page 3386/33000; a portion of slice 2/1000 to tmp array index 3
# Page 3387/33000; a portion of slice 2/1000 to tmp array index 4
# Page 3388/33000; a portion of slice 2/1000 to tmp array index 5
# Page 3416/33000; a portion of slice 3/1000 to tmp array index 0
# Page 3417/33000; a portion of slice 3/1000 to tmp array index 1
# Page 3418/33000; a portion of slice 3/1000 to tmp array index 2
# Page 3419/33000; a portion of slice 3/1000 to tmp array index 3
# Page 3420/33000; a portion of slice 3/1000 to tmp array index 4
# Page 3421/33000; a portion of slice 3/1000 to tmp array index 5
# Page 3449/33000; a portion of slice 4/1000 to tmp array index 0
# Page 3450/33000; a portion of slice 4/1000 to tmp array index 1
# Page 3451/33000; a portion of slice 4/1000 to tmp array index 2
# Page 3452/33000; a portion of slice 4/1000 to tmp array index 3
# Page 3453/33000; a portion of slice 4/1000 to tmp array index 4
# Page 3454/33000; a portion of slice 4/1000 to tmp array index 5
# Page 3482/33000; a portion of slice 5/1000 to tmp array index 0
# Page 3483/33000; a portion of slice 5/1000 to tmp array index 1
# Page 3484/33000; a portion of slice 5/1000 to tmp array index 2
# Page 3485/33000; a portion of slice 5/1000 to tmp array index 3
# Page 3486/33000; a portion of slice 5/1000 to tmp array index 4
# Page 3487/33000; a portion of slice 5/1000 to tmp array index 5
# Page 3515/33000; a portion of slice 6/1000 to tmp array index 0
# Page 3516/33000; a portion of slice 6/1000 to tmp array index 1
# Page 3517/33000; a portion of slice 6/1000 to tmp array index 2
# Page 3518/33000; a portion of slice 6/1000 to tmp array index 3
# Page 3519/33000; a portion of slice 6/1000 to tmp array index 4
# Page 3520/33000; a portion of slice 6/1000 to tmp array index 5
# Page 3548/33000; a portion of slice 7/1000 to tmp array index 0
# Page 3549/33000; a portion of slice 7/1000 to tmp array index 1
# Page 3550/33000; a portion of slice 7/1000 to tmp array index 2
# Page 3551/33000; a portion of slice 7/1000 to tmp array index 3
# Page 3552/33000; a portion of slice 7/1000 to tmp array index 4
# Page 3553/33000; a portion of slice 7/1000 to tmp array index 5
# Page 3581/33000; a portion of slice 8/1000 to tmp array index 0
# Page 3582/33000; a portion of slice 8/1000 to tmp array index 1
# Page 3583/33000; a portion of slice 8/1000 to tmp array index 2
# Page 3584/33000; a portion of slice 8/1000 to tmp array index 3
# Page 3585/33000; a portion of slice 8/1000 to tmp array index 4
# Page 3586/33000; a portion of slice 8/1000 to tmp array index 5
# Page 3614/33000; a portion of slice 9/1000 to tmp array index 0
# Page 3615/33000; a portion of slice 9/1000 to tmp array index 1
# Page 3616/33000; a portion of slice 9/1000 to tmp array index 2
# Page 3617/33000; a portion of slice 9/1000 to tmp array index 3
# Page 3618/33000; a portion of slice 9/1000 to tmp array index 4
# Page 3619/33000; a portion of slice 9/1000 to tmp array index 5
# Page 3647/33000; a portion of slice 10/1000 to tmp array index 0
# Page 3648/33000; a portion of slice 10/1000 to tmp array index 1
# Page 3649/33000; a portion of slice 10/1000 to tmp array index 2
# Page 3650/33000; a portion of slice 10/1000 to tmp array index 3
# Page 3651/33000; a portion of slice 10/1000 to tmp array index 4
# Page 3652/33000; a portion of slice 10/1000 to tmp array index 5
# Page 3680/33000; a portion of slice 11/1000 to tmp array index 0
# Page 3681/33000; a portion of slice 11/1000 to tmp array index 1
# Page 3682/33000; a portion of slice 11/1000 to tmp array index 2
# Page 3683/33000; a portion of slice 11/1000 to tmp array index 3
# Page 3684/33000; a portion of slice 11/1000 to tmp array index 4
# Page 3685/33000; a portion of slice 11/1000 to tmp array index 5
# Page 3713/33000; a portion of slice 12/1000 to tmp array index 0
# Page 3714/33000; a portion of slice 12/1000 to tmp array index 1
# Page 3715/33000; a portion of slice 12/1000 to tmp array index 2
# Page 3716/33000; a portion of slice 12/1000 to tmp array index 3
# Page 3717/33000; a portion of slice 12/1000 to tmp array index 4
# Page 3718/33000; a portion of slice 12/1000 to tmp array index 5
# Page 3746/33000; a portion of slice 13/1000 to tmp array index 0
# Page 3747/33000; a portion of slice 13/1000 to tmp array index 1
# Page 3748/33000; a portion of slice 13/1000 to tmp array index 2
# Page 3749/33000; a portion of slice 13/1000 to tmp array index 3
# Page 3750/33000; a portion of slice 13/1000 to tmp array index 4
# Page 3751/33000; a portion of slice 13/1000 to tmp array index 5
# Page 3779/33000; a portion of slice 14/1000 to tmp array index 0
# Page 3780/33000; a portion of slice 14/1000 to tmp array index 1
# Page 3781/33000; a portion of slice 14/1000 to tmp array index 2
# Page 3782/33000; a portion of slice 14/1000 to tmp array index 3
# Page 3783/33000; a portion of slice 14/1000 to tmp array index 4
# Page 3784/33000; a portion of slice 14/1000 to tmp array index 5
# Page 3812/33000; a portion of slice 15/1000 to tmp array index 0
# Page 3813/33000; a portion of slice 15/1000 to tmp array index 1
# Page 3814/33000; a portion of slice 15/1000 to tmp array index 2
# Page 3815/33000; a portion of slice 15/1000 to tmp array index 3
# Page 3816/33000; a portion of slice 15/1000 to tmp array index 4
# Page 3817/33000; a portion of slice 15/1000 to tmp array index 5
# Page 3845/33000; a portion of slice 16/1000 to tmp array index 0
# Page 3846/33000; a portion of slice 16/1000 to tmp array index 1
# Page 3847/33000; a portion of slice 16/1000 to tmp array index 2
# Page 3848/33000; a portion of slice 16/1000 to tmp array index 3
# Page 3849/33000; a portion of slice 16/1000 to tmp array index 4
# Page 3850/33000; a portion of slice 16/1000 to tmp array index 5
# Page 3878/33000; a portion of slice 17/1000 to tmp array index 0
# Page 3879/33000; a portion of slice 17/1000 to tmp array index 1
# Page 3880/33000; a portion of slice 17/1000 to tmp array index 2
# Page 3881/33000; a portion of slice 17/1000 to tmp array index 3
# Page 3882/33000; a portion of slice 17/1000 to tmp array index 4
# Page 3883/33000; a portion of slice 17/1000 to tmp array index 5
# Page 3911/33000; a portion of slice 18/1000 to tmp array index 0
# Page 3912/33000; a portion of slice 18/1000 to tmp array index 1
# Page 3913/33000; a portion of slice 18/1000 to tmp array index 2
# Page 3914/33000; a portion of slice 18/1000 to tmp array index 3
# Page 3915/33000; a portion of slice 18/1000 to tmp array index 4
# Page 3916/33000; a portion of slice 18/1000 to tmp array index 5
# Page 3944/33000; a portion of slice 19/1000 to tmp array index 0
# Page 3945/33000; a portion of slice 19/1000 to tmp array index 1
# Page 3946/33000; a portion of slice 19/1000 to tmp array index 2
# Page 3947/33000; a portion of slice 19/1000 to tmp array index 3
# Page 3948/33000; a portion of slice 19/1000 to tmp array index 4
# Page 3949/33000; a portion of slice 19/1000 to tmp array index 5
# Page 3977/33000; a portion of slice 20/1000 to tmp array index 0
# Page 3978/33000; a portion of slice 20/1000 to tmp array index 1
# Page 3979/33000; a portion of slice 20/1000 to tmp array index 2
# Page 3980/33000; a portion of slice 20/1000 to tmp array index 3
# Page 3981/33000; a portion of slice 20/1000 to tmp array index 4
# Page 3982/33000; a portion of slice 20/1000 to tmp array index 5
# Page 4010/33000; a portion of slice 21/1000 to tmp array index 0
# Page 4011/33000; a portion of slice 21/1000 to tmp array index 1
# Page 4012/33000; a portion of slice 21/1000 to tmp array index 2
# Page 4013/33000; a portion of slice 21/1000 to tmp array index 3
# Page 4014/33000; a portion of slice 21/1000 to tmp array index 4
# Page 4015/33000; a portion of slice 21/1000 to tmp array index 5
# Page 4043/33000; a portion of slice 22/1000 to tmp array index 0
# Page 4044/33000; a portion of slice 22/1000 to tmp array index 1
# Page 4045/33000; a portion of slice 22/1000 to tmp array index 2
# Page 4046/33000; a portion of slice 22/1000 to tmp array index 3
# Page 4047/33000; a portion of slice 22/1000 to tmp array index 4
# Page 4048/33000; a portion of slice 22/1000 to tmp array index 5
# Page 4076/33000; a portion of slice 23/1000 to tmp array index 0
# Page 4077/33000; a portion of slice 23/1000 to tmp array index 1
# Page 4078/33000; a portion of slice 23/1000 to tmp array index 2
# Page 4079/33000; a portion of slice 23/1000 to tmp array index 3
# Page 4080/33000; a portion of slice 23/1000 to tmp array index 4
# Page 4081/33000; a portion of slice 23/1000 to tmp array index 5
# Page 4109/33000; a portion of slice 24/1000 to tmp array index 0
# Page 4110/33000; a portion of slice 24/1000 to tmp array index 1
# Page 4111/33000; a portion of slice 24/1000 to tmp array index 2
# Page 4112/33000; a portion of slice 24/1000 to tmp array index 3
# Page 4113/33000; a portion of slice 24/1000 to tmp array index 4
# Page 4114/33000; a portion of slice 24/1000 to tmp array index 5
# Page 4142/33000; a portion of slice 25/1000 to tmp array index 0
# Page 4143/33000; a portion of slice 25/1000 to tmp array index 1
# Page 4144/33000; a portion of slice 25/1000 to tmp array index 2
# Page 4145/33000; a portion of slice 25/1000 to tmp array index 3
# Page 4146/33000; a portion of slice 25/1000 to tmp array index 4
# Page 4147/33000; a portion of slice 25/1000 to tmp array index 5
# Page 4175/33000; a portion of slice 26/1000 to tmp array index 0
# Page 4176/33000; a portion of slice 26/1000 to tmp array index 1
# Page 4177/33000; a portion of slice 26/1000 to tmp array index 2
# Page 4178/33000; a portion of slice 26/1000 to tmp array index 3
# Page 4179/33000; a portion of slice 26/1000 to tmp array index 4
# Page 4180/33000; a portion of slice 26/1000 to tmp array index 5
# Page 4208/33000; a portion of slice 27/1000 to tmp array index 0
# Page 4209/33000; a portion of slice 27/1000 to tmp array index 1
# Page 4210/33000; a portion of slice 27/1000 to tmp array index 2
# Page 4211/33000; a portion of slice 27/1000 to tmp array index 3
# Page 4212/33000; a portion of slice 27/1000 to tmp array index 4
# Page 4213/33000; a portion of slice 27/1000 to tmp array index 5
# Page 4241/33000; a portion of slice 28/1000 to tmp array index 0
# Page 4242/33000; a portion of slice 28/1000 to tmp array index 1
# Page 4243/33000; a portion of slice 28/1000 to tmp array index 2
# Page 4244/33000; a portion of slice 28/1000 to tmp array index 3
# Page 4245/33000; a portion of slice 28/1000 to tmp array index 4
# Page 4246/33000; a portion of slice 28/1000 to tmp array index 5
# Page 4274/33000; a portion of slice 29/1000 to tmp array index 0
# Page 4275/33000; a portion of slice 29/1000 to tmp array index 1
# Page 4276/33000; a portion of slice 29/1000 to tmp array index 2
# Page 4277/33000; a portion of slice 29/1000 to tmp array index 3
# Page 4278/33000; a portion of slice 29/1000 to tmp array index 4
# Page 4279/33000; a portion of slice 29/1000 to tmp array index 5
# Page 4307/33000; a portion of slice 30/1000 to tmp array index 0
# Page 4308/33000; a portion of slice 30/1000 to tmp array index 1
# Page 4309/33000; a portion of slice 30/1000 to tmp array index 2
# Page 4310/33000; a portion of slice 30/1000 to tmp array index 3
# Page 4311/33000; a portion of slice 30/1000 to tmp array index 4
# Page 4312/33000; a portion of slice 30/1000 to tmp array index 5
# Page 4340/33000; a portion of slice 31/1000 to tmp array index 0
# Page 4341/33000; a portion of slice 31/1000 to tmp array index 1
# Page 4342/33000; a portion of slice 31/1000 to tmp array index 2
# Page 4343/33000; a portion of slice 31/1000 to tmp array index 3
# Page 4344/33000; a portion of slice 31/1000 to tmp array index 4
# Page 4345/33000; a portion of slice 31/1000 to tmp array index 5
# Page 4373/33000; a portion of slice 32/1000 to tmp array index 0
# Page 4374/33000; a portion of slice 32/1000 to tmp array index 1
# Page 4375/33000; a portion of slice 32/1000 to tmp array index 2
# Page 4376/33000; a portion of slice 32/1000 to tmp array index 3
# Page 4377/33000; a portion of slice 32/1000 to tmp array index 4
# Page 4378/33000; a portion of slice 32/1000 to tmp array index 5
# Page 4406/33000; a portion of slice 33/1000 to tmp array index 0
# Page 4407/33000; a portion of slice 33/1000 to tmp array index 1
# Page 4408/33000; a portion of slice 33/1000 to tmp array index 2
# Page 4409/33000; a portion of slice 33/1000 to tmp array index 3
# Page 4410/33000; a portion of slice 33/1000 to tmp array index 4
# Page 4411/33000; a portion of slice 33/1000 to tmp array index 5
# Page 4439/33000; a portion of slice 34/1000 to tmp array index 0
# Page 4440/33000; a portion of slice 34/1000 to tmp array index 1
# Page 4441/33000; a portion of slice 34/1000 to tmp array index 2
# Page 4442/33000; a portion of slice 34/1000 to tmp array index 3
# Page 4443/33000; a portion of slice 34/1000 to tmp array index 4
# Page 4444/33000; a portion of slice 34/1000 to tmp array index 5
# Page 4472/33000; a portion of slice 35/1000 to tmp array index 0
# Page 4473/33000; a portion of slice 35/1000 to tmp array index 1
# Page 4474/33000; a portion of slice 35/1000 to tmp array index 2
# Page 4475/33000; a portion of slice 35/1000 to tmp array index 3
# Page 4476/33000; a portion of slice 35/1000 to tmp array index 4
# Page 4477/33000; a portion of slice 35/1000 to tmp array index 5
# Page 4505/33000; a portion of slice 36/1000 to tmp array index 0
# Page 4506/33000; a portion of slice 36/1000 to tmp array index 1
# Page 4507/33000; a portion of slice 36/1000 to tmp array index 2
# Page 4508/33000; a portion of slice 36/1000 to tmp array index 3
# Page 4509/33000; a portion of slice 36/1000 to tmp array index 4
# Page 4510/33000; a portion of slice 36/1000 to tmp array index 5
# Page 4538/33000; a portion of slice 37/1000 to tmp array index 0
# Page 4539/33000; a portion of slice 37/1000 to tmp array index 1
# Page 4540/33000; a portion of slice 37/1000 to tmp array index 2
# Page 4541/33000; a portion of slice 37/1000 to tmp array index 3
# Page 4542/33000; a portion of slice 37/1000 to tmp array index 4
# Page 4543/33000; a portion of slice 37/1000 to tmp array index 5
# Page 4571/33000; a portion of slice 38/1000 to tmp array index 0
# Page 4572/33000; a portion of slice 38/1000 to tmp array index 1
# Page 4573/33000; a portion of slice 38/1000 to tmp array index 2
# Page 4574/33000; a portion of slice 38/1000 to tmp array index 3
# Page 4575/33000; a portion of slice 38/1000 to tmp array index 4
# Page 4576/33000; a portion of slice 38/1000 to tmp array index 5
# Page 4604/33000; a portion of slice 39/1000 to tmp array index 0
# Page 4605/33000; a portion of slice 39/1000 to tmp array index 1
# Page 4606/33000; a portion of slice 39/1000 to tmp array index 2
# Page 4607/33000; a portion of slice 39/1000 to tmp array index 3
# Page 4608/33000; a portion of slice 39/1000 to tmp array index 4
# Page 4609/33000; a portion of slice 39/1000 to tmp array index 5
# Page 4637/33000; a portion of slice 40/1000 to tmp array index 0
# Page 4638/33000; a portion of slice 40/1000 to tmp array index 1
# Page 4639/33000; a portion of slice 40/1000 to tmp array index 2
# Page 4640/33000; a portion of slice 40/1000 to tmp array index 3
# Page 4641/33000; a portion of slice 40/1000 to tmp array index 4
# Page 4642/33000; a portion of slice 40/1000 to tmp array index 5
# Page 4670/33000; a portion of slice 41/1000 to tmp array index 0
# Page 4671/33000; a portion of slice 41/1000 to tmp array index 1
# Page 4672/33000; a portion of slice 41/1000 to tmp array index 2
# Page 4673/33000; a portion of slice 41/1000 to tmp array index 3
# Page 4674/33000; a portion of slice 41/1000 to tmp array index 4
# Page 4675/33000; a portion of slice 41/1000 to tmp array index 5
# Page 4703/33000; a portion of slice 42/1000 to tmp array index 0
# Page 4704/33000; a portion of slice 42/1000 to tmp array index 1
# Page 4705/33000; a portion of slice 42/1000 to tmp array index 2
# Page 4706/33000; a portion of slice 42/1000 to tmp array index 3
# Page 4707/33000; a portion of slice 42/1000 to tmp array index 4
# Page 4708/33000; a portion of slice 42/1000 to tmp array index 5
# Page 4736/33000; a portion of slice 43/1000 to tmp array index 0
# Page 4737/33000; a portion of slice 43/1000 to tmp array index 1
# Page 4738/33000; a portion of slice 43/1000 to tmp array index 2
# Page 4739/33000; a portion of slice 43/1000 to tmp array index 3
# Page 4740/33000; a portion of slice 43/1000 to tmp array index 4
# Page 4741/33000; a portion of slice 43/1000 to tmp array index 5
# Page 4769/33000; a portion of slice 44/1000 to tmp array index 0
# Page 4770/33000; a portion of slice 44/1000 to tmp array index 1
# Page 4771/33000; a portion of slice 44/1000 to tmp array index 2
# Page 4772/33000; a portion of slice 44/1000 to tmp array index 3
# Page 4773/33000; a portion of slice 44/1000 to tmp array index 4
# Page 4774/33000; a portion of slice 44/1000 to tmp array index 5
# Page 4802/33000; a portion of slice 45/1000 to tmp array index 0
# Page 4803/33000; a portion of slice 45/1000 to tmp array index 1
# Page 4804/33000; a portion of slice 45/1000 to tmp array index 2
# Page 4805/33000; a portion of slice 45/1000 to tmp array index 3
# Page 4806/33000; a portion of slice 45/1000 to tmp array index 4
# Page 4807/33000; a portion of slice 45/1000 to tmp array index 5
# Page 4835/33000; a portion of slice 46/1000 to tmp array index 0
# Page 4836/33000; a portion of slice 46/1000 to tmp array index 1
# Page 4837/33000; a portion of slice 46/1000 to tmp array index 2
# Page 4838/33000; a portion of slice 46/1000 to tmp array index 3
# Page 4839/33000; a portion of slice 46/1000 to tmp array index 4
# Page 4840/33000; a portion of slice 46/1000 to tmp array index 5
# Page 4868/33000; a portion of slice 47/1000 to tmp array index 0
# Page 4869/33000; a portion of slice 47/1000 to tmp array index 1
# Page 4870/33000; a portion of slice 47/1000 to tmp array index 2
# Page 4871/33000; a portion of slice 47/1000 to tmp array index 3
# Page 4872/33000; a portion of slice 47/1000 to tmp array index 4
# Page 4873/33000; a portion of slice 47/1000 to tmp array index 5
# Page 4901/33000; a portion of slice 48/1000 to tmp array index 0
# Page 4902/33000; a portion of slice 48/1000 to tmp array index 1
# Page 4903/33000; a portion of slice 48/1000 to tmp array index 2
# Page 4904/33000; a portion of slice 48/1000 to tmp array index 3
# Page 4905/33000; a portion of slice 48/1000 to tmp array index 4
# Page 4906/33000; a portion of slice 48/1000 to tmp array index 5
# Page 4934/33000; a portion of slice 49/1000 to tmp array index 0
# Page 4935/33000; a portion of slice 49/1000 to tmp array index 1
# Page 4936/33000; a portion of slice 49/1000 to tmp array index 2
# Page 4937/33000; a portion of slice 49/1000 to tmp array index 3
# Page 4938/33000; a portion of slice 49/1000 to tmp array index 4
# Page 4939/33000; a portion of slice 49/1000 to tmp array index 5
# Page 4967/33000; a portion of slice 50/1000 to tmp array index 0
# Page 4968/33000; a portion of slice 50/1000 to tmp array index 1
# Page 4969/33000; a portion of slice 50/1000 to tmp array index 2
# Page 4970/33000; a portion of slice 50/1000 to tmp array index 3
# Page 4971/33000; a portion of slice 50/1000 to tmp array index 4
# Page 4972/33000; a portion of slice 50/1000 to tmp array index 5
# Page 5000/33000; a portion of slice 51/1000 to tmp array index 0
# Page 5001/33000; a portion of slice 51/1000 to tmp array index 1
# Page 5002/33000; a portion of slice 51/1000 to tmp array index 2
# Page 5003/33000; a portion of slice 51/1000 to tmp array index 3
# Page 5004/33000; a portion of slice 51/1000 to tmp array index 4
# Page 5005/33000; a portion of slice 51/1000 to tmp array index 5
# Page 5033/33000; a portion of slice 52/1000 to tmp array index 0
# Page 5034/33000; a portion of slice 52/1000 to tmp array index 1
# Page 5035/33000; a portion of slice 52/1000 to tmp array index 2
# Page 5036/33000; a portion of slice 52/1000 to tmp array index 3
# Page 5037/33000; a portion of slice 52/1000 to tmp array index 4
# Page 5038/33000; a portion of slice 52/1000 to tmp array index 5
# Page 5066/33000; a portion of slice 53/1000 to tmp array index 0
# Page 5067/33000; a portion of slice 53/1000 to tmp array index 1
# Page 5068/33000; a portion of slice 53/1000 to tmp array index 2
# Page 5069/33000; a portion of slice 53/1000 to tmp array index 3
# Page 5070/33000; a portion of slice 53/1000 to tmp array index 4
# Page 5071/33000; a portion of slice 53/1000 to tmp array index 5
# Page 5099/33000; a portion of slice 54/1000 to tmp array index 0
# Page 5100/33000; a portion of slice 54/1000 to tmp array index 1
# Page 5101/33000; a portion of slice 54/1000 to tmp array index 2
# Page 5102/33000; a portion of slice 54/1000 to tmp array index 3
# Page 5103/33000; a portion of slice 54/1000 to tmp array index 4
# Page 5104/33000; a portion of slice 54/1000 to tmp array index 5
# Page 5132/33000; a portion of slice 55/1000 to tmp array index 0
# Page 5133/33000; a portion of slice 55/1000 to tmp array index 1
# Page 5134/33000; a portion of slice 55/1000 to tmp array index 2
# Page 5135/33000; a portion of slice 55/1000 to tmp array index 3
# Page 5136/33000; a portion of slice 55/1000 to tmp array index 4
# Page 5137/33000; a portion of slice 55/1000 to tmp array index 5
# Page 5165/33000; a portion of slice 56/1000 to tmp array index 0
# Page 5166/33000; a portion of slice 56/1000 to tmp array index 1
# Page 5167/33000; a portion of slice 56/1000 to tmp array index 2
# Page 5168/33000; a portion of slice 56/1000 to tmp array index 3
# Page 5169/33000; a portion of slice 56/1000 to tmp array index 4
# Page 5170/33000; a portion of slice 56/1000 to tmp array index 5
# Page 5198/33000; a portion of slice 57/1000 to tmp array index 0
# Page 5199/33000; a portion of slice 57/1000 to tmp array index 1
# Page 5200/33000; a portion of slice 57/1000 to tmp array index 2
# Page 5201/33000; a portion of slice 57/1000 to tmp array index 3
# Page 5202/33000; a portion of slice 57/1000 to tmp array index 4
# Page 5203/33000; a portion of slice 57/1000 to tmp array index 5
# Page 5231/33000; a portion of slice 58/1000 to tmp array index 0
# Page 5232/33000; a portion of slice 58/1000 to tmp array index 1
# Page 5233/33000; a portion of slice 58/1000 to tmp array index 2
# Page 5234/33000; a portion of slice 58/1000 to tmp array index 3
# Page 5235/33000; a portion of slice 58/1000 to tmp array index 4
# Page 5236/33000; a portion of slice 58/1000 to tmp array index 5
# Page 5264/33000; a portion of slice 59/1000 to tmp array index 0
# Page 5265/33000; a portion of slice 59/1000 to tmp array index 1
# Page 5266/33000; a portion of slice 59/1000 to tmp array index 2
# Page 5267/33000; a portion of slice 59/1000 to tmp array index 3
# Page 5268/33000; a portion of slice 59/1000 to tmp array index 4
# Page 5269/33000; a portion of slice 59/1000 to tmp array index 5
# Page 5297/33000; a portion of slice 60/1000 to tmp array index 0
# Page 5298/33000; a portion of slice 60/1000 to tmp array index 1
# Page 5299/33000; a portion of slice 60/1000 to tmp array index 2
# Page 5300/33000; a portion of slice 60/1000 to tmp array index 3
# Page 5301/33000; a portion of slice 60/1000 to tmp array index 4
# Page 5302/33000; a portion of slice 60/1000 to tmp array index 5
# Page 5330/33000; a portion of slice 61/1000 to tmp array index 0
# Page 5331/33000; a portion of slice 61/1000 to tmp array index 1
# Page 5332/33000; a portion of slice 61/1000 to tmp array index 2
# Page 5333/33000; a portion of slice 61/1000 to tmp array index 3
# Page 5334/33000; a portion of slice 61/1000 to tmp array index 4
# Page 5335/33000; a portion of slice 61/1000 to tmp array index 5
# Page 5363/33000; a portion of slice 62/1000 to tmp array index 0
# Page 5364/33000; a portion of slice 62/1000 to tmp array index 1
# Page 5365/33000; a portion of slice 62/1000 to tmp array index 2
# Page 5366/33000; a portion of slice 62/1000 to tmp array index 3
# Page 5367/33000; a portion of slice 62/1000 to tmp array index 4
# Page 5368/33000; a portion of slice 62/1000 to tmp array index 5
# Page 5396/33000; a portion of slice 63/1000 to tmp array index 0
# Page 5397/33000; a portion of slice 63/1000 to tmp array index 1
# Page 5398/33000; a portion of slice 63/1000 to tmp array index 2
# Page 5399/33000; a portion of slice 63/1000 to tmp array index 3
# Page 5400/33000; a portion of slice 63/1000 to tmp array index 4
# Page 5401/33000; a portion of slice 63/1000 to tmp array index 5
# Page 5429/33000; a portion of slice 64/1000 to tmp array index 0
# Page 5430/33000; a portion of slice 64/1000 to tmp array index 1
# Page 5431/33000; a portion of slice 64/1000 to tmp array index 2
# Page 5432/33000; a portion of slice 64/1000 to tmp array index 3
# Page 5433/33000; a portion of slice 64/1000 to tmp array index 4
# Page 5434/33000; a portion of slice 64/1000 to tmp array index 5
# Page 5462/33000; a portion of slice 65/1000 to tmp array index 0
# Page 5463/33000; a portion of slice 65/1000 to tmp array index 1
# Page 5464/33000; a portion of slice 65/1000 to tmp array index 2
# Page 5465/33000; a portion of slice 65/1000 to tmp array index 3
# Page 5466/33000; a portion of slice 65/1000 to tmp array index 4
# Page 5467/33000; a portion of slice 65/1000 to tmp array index 5
# Page 5495/33000; a portion of slice 66/1000 to tmp array index 0
# Page 5496/33000; a portion of slice 66/1000 to tmp array index 1
# Page 5497/33000; a portion of slice 66/1000 to tmp array index 2
# Page 5498/33000; a portion of slice 66/1000 to tmp array index 3
# Page 5499/33000; a portion of slice 66/1000 to tmp array index 4
# Page 5500/33000; a portion of slice 66/1000 to tmp array index 5
# Page 5528/33000; a portion of slice 67/1000 to tmp array index 0
# Page 5529/33000; a portion of slice 67/1000 to tmp array index 1
# Page 5530/33000; a portion of slice 67/1000 to tmp array index 2
# Page 5531/33000; a portion of slice 67/1000 to tmp array index 3
# Page 5532/33000; a portion of slice 67/1000 to tmp array index 4
# Page 5533/33000; a portion of slice 67/1000 to tmp array index 5
# Page 5561/33000; a portion of slice 68/1000 to tmp array index 0
# Page 5562/33000; a portion of slice 68/1000 to tmp array index 1
# Page 5563/33000; a portion of slice 68/1000 to tmp array index 2
# Page 5564/33000; a portion of slice 68/1000 to tmp array index 3
# Page 5565/33000; a portion of slice 68/1000 to tmp array index 4
# Page 5566/33000; a portion of slice 68/1000 to tmp array index 5
# Page 5594/33000; a portion of slice 69/1000 to tmp array index 0
# Page 5595/33000; a portion of slice 69/1000 to tmp array index 1
# Page 5596/33000; a portion of slice 69/1000 to tmp array index 2
# Page 5597/33000; a portion of slice 69/1000 to tmp array index 3
# Page 5598/33000; a portion of slice 69/1000 to tmp array index 4
# Page 5599/33000; a portion of slice 69/1000 to tmp array index 5
# Page 5627/33000; a portion of slice 70/1000 to tmp array index 0
# Page 5628/33000; a portion of slice 70/1000 to tmp array index 1
# Page 5629/33000; a portion of slice 70/1000 to tmp array index 2
# Page 5630/33000; a portion of slice 70/1000 to tmp array index 3
# Page 5631/33000; a portion of slice 70/1000 to tmp array index 4
# Page 5632/33000; a portion of slice 70/1000 to tmp array index 5
# Page 5660/33000; a portion of slice 71/1000 to tmp array index 0
# Page 5661/33000; a portion of slice 71/1000 to tmp array index 1
# Page 5662/33000; a portion of slice 71/1000 to tmp array index 2
# Page 5663/33000; a portion of slice 71/1000 to tmp array index 3
# Page 5664/33000; a portion of slice 71/1000 to tmp array index 4
# Page 5665/33000; a portion of slice 71/1000 to tmp array index 5
# Page 5693/33000; a portion of slice 72/1000 to tmp array index 0
# Page 5694/33000; a portion of slice 72/1000 to tmp array index 1
# Page 5695/33000; a portion of slice 72/1000 to tmp array index 2
# Page 5696/33000; a portion of slice 72/1000 to tmp array index 3
# Page 5697/33000; a portion of slice 72/1000 to tmp array index 4
# Page 5698/33000; a portion of slice 72/1000 to tmp array index 5
# Page 5726/33000; a portion of slice 73/1000 to tmp array index 0
# Page 5727/33000; a portion of slice 73/1000 to tmp array index 1
# Page 5728/33000; a portion of slice 73/1000 to tmp array index 2
# Page 5729/33000; a portion of slice 73/1000 to tmp array index 3
# Page 5730/33000; a portion of slice 73/1000 to tmp array index 4
# Page 5731/33000; a portion of slice 73/1000 to tmp array index 5
# Page 5759/33000; a portion of slice 74/1000 to tmp array index 0
# Page 5760/33000; a portion of slice 74/1000 to tmp array index 1
# Page 5761/33000; a portion of slice 74/1000 to tmp array index 2
# Page 5762/33000; a portion of slice 74/1000 to tmp array index 3
# Page 5763/33000; a portion of slice 74/1000 to tmp array index 4
# Page 5764/33000; a portion of slice 74/1000 to tmp array index 5
# Page 5792/33000; a portion of slice 75/1000 to tmp array index 0
# Page 5793/33000; a portion of slice 75/1000 to tmp array index 1
# Page 5794/33000; a portion of slice 75/1000 to tmp array index 2
# Page 5795/33000; a portion of slice 75/1000 to tmp array index 3
# Page 5796/33000; a portion of slice 75/1000 to tmp array index 4
# Page 5797/33000; a portion of slice 75/1000 to tmp array index 5
# Page 5825/33000; a portion of slice 76/1000 to tmp array index 0
# Page 5826/33000; a portion of slice 76/1000 to tmp array index 1
# Page 5827/33000; a portion of slice 76/1000 to tmp array index 2
# Page 5828/33000; a portion of slice 76/1000 to tmp array index 3
# Page 5829/33000; a portion of slice 76/1000 to tmp array index 4
# Page 5830/33000; a portion of slice 76/1000 to tmp array index 5
# Page 5858/33000; a portion of slice 77/1000 to tmp array index 0
# Page 5859/33000; a portion of slice 77/1000 to tmp array index 1
# Page 5860/33000; a portion of slice 77/1000 to tmp array index 2
# Page 5861/33000; a portion of slice 77/1000 to tmp array index 3
# Page 5862/33000; a portion of slice 77/1000 to tmp array index 4
# Page 5863/33000; a portion of slice 77/1000 to tmp array index 5
# Page 5891/33000; a portion of slice 78/1000 to tmp array index 0
# Page 5892/33000; a portion of slice 78/1000 to tmp array index 1
# Page 5893/33000; a portion of slice 78/1000 to tmp array index 2
# Page 5894/33000; a portion of slice 78/1000 to tmp array index 3
# Page 5895/33000; a portion of slice 78/1000 to tmp array index 4
# Page 5896/33000; a portion of slice 78/1000 to tmp array index 5
# Page 5924/33000; a portion of slice 79/1000 to tmp array index 0
# Page 5925/33000; a portion of slice 79/1000 to tmp array index 1
# Page 5926/33000; a portion of slice 79/1000 to tmp array index 2
# Page 5927/33000; a portion of slice 79/1000 to tmp array index 3
# Page 5928/33000; a portion of slice 79/1000 to tmp array index 4
# Page 5929/33000; a portion of slice 79/1000 to tmp array index 5
# Page 5957/33000; a portion of slice 80/1000 to tmp array index 0
# Page 5958/33000; a portion of slice 80/1000 to tmp array index 1
# Page 5959/33000; a portion of slice 80/1000 to tmp array index 2
# Page 5960/33000; a portion of slice 80/1000 to tmp array index 3
# Page 5961/33000; a portion of slice 80/1000 to tmp array index 4
# Page 5962/33000; a portion of slice 80/1000 to tmp array index 5
# Page 5990/33000; a portion of slice 81/1000 to tmp array index 0
# Page 5991/33000; a portion of slice 81/1000 to tmp array index 1
# Page 5992/33000; a portion of slice 81/1000 to tmp array index 2
# Page 5993/33000; a portion of slice 81/1000 to tmp array index 3
# Page 5994/33000; a portion of slice 81/1000 to tmp array index 4
# Page 5995/33000; a portion of slice 81/1000 to tmp array index 5
# Page 6023/33000; a portion of slice 82/1000 to tmp array index 0
# Page 6024/33000; a portion of slice 82/1000 to tmp array index 1
# Page 6025/33000; a portion of slice 82/1000 to tmp array index 2
# Page 6026/33000; a portion of slice 82/1000 to tmp array index 3
# Page 6027/33000; a portion of slice 82/1000 to tmp array index 4
# Page 6028/33000; a portion of slice 82/1000 to tmp array index 5
# Page 6056/33000; a portion of slice 83/1000 to tmp array index 0
# Page 6057/33000; a portion of slice 83/1000 to tmp array index 1
# Page 6058/33000; a portion of slice 83/1000 to tmp array index 2
# Page 6059/33000; a portion of slice 83/1000 to tmp array index 3
# Page 6060/33000; a portion of slice 83/1000 to tmp array index 4
# Page 6061/33000; a portion of slice 83/1000 to tmp array index 5
# Page 6089/33000; a portion of slice 84/1000 to tmp array index 0
# Page 6090/33000; a portion of slice 84/1000 to tmp array index 1
# Page 6091/33000; a portion of slice 84/1000 to tmp array index 2
# Page 6092/33000; a portion of slice 84/1000 to tmp array index 3
# Page 6093/33000; a portion of slice 84/1000 to tmp array index 4
# Page 6094/33000; a portion of slice 84/1000 to tmp array index 5
# Page 6122/33000; a portion of slice 85/1000 to tmp array index 0
# Page 6123/33000; a portion of slice 85/1000 to tmp array index 1
# Page 6124/33000; a portion of slice 85/1000 to tmp array index 2
# Page 6125/33000; a portion of slice 85/1000 to tmp array index 3
# Page 6126/33000; a portion of slice 85/1000 to tmp array index 4
# Page 6127/33000; a portion of slice 85/1000 to tmp array index 5
# Page 6155/33000; a portion of slice 86/1000 to tmp array index 0
# Page 6156/33000; a portion of slice 86/1000 to tmp array index 1
# Page 6157/33000; a portion of slice 86/1000 to tmp array index 2
# Page 6158/33000; a portion of slice 86/1000 to tmp array index 3
# Page 6159/33000; a portion of slice 86/1000 to tmp array index 4
# Page 6160/33000; a portion of slice 86/1000 to tmp array index 5
# Page 6188/33000; a portion of slice 87/1000 to tmp array index 0
# Page 6189/33000; a portion of slice 87/1000 to tmp array index 1
# Page 6190/33000; a portion of slice 87/1000 to tmp array index 2
# Page 6191/33000; a portion of slice 87/1000 to tmp array index 3
# Page 6192/33000; a portion of slice 87/1000 to tmp array index 4
# Page 6193/33000; a portion of slice 87/1000 to tmp array index 5
# Page 6221/33000; a portion of slice 88/1000 to tmp array index 0
# Page 6222/33000; a portion of slice 88/1000 to tmp array index 1
# Page 6223/33000; a portion of slice 88/1000 to tmp array index 2
# Page 6224/33000; a portion of slice 88/1000 to tmp array index 3
# Page 6225/33000; a portion of slice 88/1000 to tmp array index 4
# Page 6226/33000; a portion of slice 88/1000 to tmp array index 5
# Page 6254/33000; a portion of slice 89/1000 to tmp array index 0
# Page 6255/33000; a portion of slice 89/1000 to tmp array index 1
# Page 6256/33000; a portion of slice 89/1000 to tmp array index 2
# Page 6257/33000; a portion of slice 89/1000 to tmp array index 3
# Page 6258/33000; a portion of slice 89/1000 to tmp array index 4
# Page 6259/33000; a portion of slice 89/1000 to tmp array index 5
# Page 6287/33000; a portion of slice 90/1000 to tmp array index 0
# Page 6288/33000; a portion of slice 90/1000 to tmp array index 1
# Page 6289/33000; a portion of slice 90/1000 to tmp array index 2
# Page 6290/33000; a portion of slice 90/1000 to tmp array index 3
# Page 6291/33000; a portion of slice 90/1000 to tmp array index 4
# Page 6292/33000; a portion of slice 90/1000 to tmp array index 5
# Page 6320/33000; a portion of slice 91/1000 to tmp array index 0
# Page 6321/33000; a portion of slice 91/1000 to tmp array index 1
# Page 6322/33000; a portion of slice 91/1000 to tmp array index 2
# Page 6323/33000; a portion of slice 91/1000 to tmp array index 3
# Page 6324/33000; a portion of slice 91/1000 to tmp array index 4
# Page 6325/33000; a portion of slice 91/1000 to tmp array index 5
# Page 6353/33000; a portion of slice 92/1000 to tmp array index 0
# Page 6354/33000; a portion of slice 92/1000 to tmp array index 1
# Page 6355/33000; a portion of slice 92/1000 to tmp array index 2
# Page 6356/33000; a portion of slice 92/1000 to tmp array index 3
# Page 6357/33000; a portion of slice 92/1000 to tmp array index 4
# Page 6358/33000; a portion of slice 92/1000 to tmp array index 5
# Page 6386/33000; a portion of slice 93/1000 to tmp array index 0
# Page 6387/33000; a portion of slice 93/1000 to tmp array index 1
# Page 6388/33000; a portion of slice 93/1000 to tmp array index 2
# Page 6389/33000; a portion of slice 93/1000 to tmp array index 3
# Page 6390/33000; a portion of slice 93/1000 to tmp array index 4
# Page 6391/33000; a portion of slice 93/1000 to tmp array index 5
# Page 6419/33000; a portion of slice 94/1000 to tmp array index 0
# Page 6420/33000; a portion of slice 94/1000 to tmp array index 1
# Page 6421/33000; a portion of slice 94/1000 to tmp array index 2
# Page 6422/33000; a portion of slice 94/1000 to tmp array index 3
# Page 6423/33000; a portion of slice 94/1000 to tmp array index 4
# Page 6424/33000; a portion of slice 94/1000 to tmp array index 5
# Page 6452/33000; a portion of slice 95/1000 to tmp array index 0
# Page 6453/33000; a portion of slice 95/1000 to tmp array index 1
# Page 6454/33000; a portion of slice 95/1000 to tmp array index 2
# Page 6455/33000; a portion of slice 95/1000 to tmp array index 3
# Page 6456/33000; a portion of slice 95/1000 to tmp array index 4
# Page 6457/33000; a portion of slice 95/1000 to tmp array index 5
# Page 6485/33000; a portion of slice 96/1000 to tmp array index 0
# Page 6486/33000; a portion of slice 96/1000 to tmp array index 1
# Page 6487/33000; a portion of slice 96/1000 to tmp array index 2
# Page 6488/33000; a portion of slice 96/1000 to tmp array index 3
# Page 6489/33000; a portion of slice 96/1000 to tmp array index 4
# Page 6490/33000; a portion of slice 96/1000 to tmp array index 5
# Page 6518/33000; a portion of slice 97/1000 to tmp array index 0
# Page 6519/33000; a portion of slice 97/1000 to tmp array index 1
# Page 6520/33000; a portion of slice 97/1000 to tmp array index 2
# Page 6521/33000; a portion of slice 97/1000 to tmp array index 3
# Page 6522/33000; a portion of slice 97/1000 to tmp array index 4
# Page 6523/33000; a portion of slice 97/1000 to tmp array index 5
# Page 6551/33000; a portion of slice 98/1000 to tmp array index 0
# Page 6552/33000; a portion of slice 98/1000 to tmp array index 1
# Page 6553/33000; a portion of slice 98/1000 to tmp array index 2
# Page 6554/33000; a portion of slice 98/1000 to tmp array index 3
# Page 6555/33000; a portion of slice 98/1000 to tmp array index 4
# Page 6556/33000; a portion of slice 98/1000 to tmp array index 5
# Page 6584/33000; a portion of slice 99/1000 to tmp array index 0
# Page 6585/33000; a portion of slice 99/1000 to tmp array index 1
# Page 6586/33000; a portion of slice 99/1000 to tmp array index 2
# Page 6587/33000; a portion of slice 99/1000 to tmp array index 3
# Page 6588/33000; a portion of slice 99/1000 to tmp array index 4
# Page 6589/33000; a portion of slice 99/1000 to tmp array index 5
# Page 6617/33000; a portion of slice 100/1000 to tmp array index 0
# Page 6618/33000; a portion of slice 100/1000 to tmp array index 1
# Page 6619/33000; a portion of slice 100/1000 to tmp array index 2
# Page 6620/33000; a portion of slice 100/1000 to tmp array index 3
# Page 6621/33000; a portion of slice 100/1000 to tmp array index 4
# Page 6622/33000; a portion of slice 100/1000 to tmp array index 5
# Page 6650/33000; a portion of slice 101/1000 to tmp array index 0
# Page 6651/33000; a portion of slice 101/1000 to tmp array index 1
# Page 6652/33000; a portion of slice 101/1000 to tmp array index 2
# Page 6653/33000; a portion of slice 101/1000 to tmp array index 3
# Page 6654/33000; a portion of slice 101/1000 to tmp array index 4
# Page 6655/33000; a portion of slice 101/1000 to tmp array index 5
# Page 6683/33000; a portion of slice 102/1000 to tmp array index 0
# Page 6684/33000; a portion of slice 102/1000 to tmp array index 1
# Page 6685/33000; a portion of slice 102/1000 to tmp array index 2
# Page 6686/33000; a portion of slice 102/1000 to tmp array index 3
# Page 6687/33000; a portion of slice 102/1000 to tmp array index 4
# Page 6688/33000; a portion of slice 102/1000 to tmp array index 5
# Page 6716/33000; a portion of slice 103/1000 to tmp array index 0
# Page 6717/33000; a portion of slice 103/1000 to tmp array index 1
# Page 6718/33000; a portion of slice 103/1000 to tmp array index 2
# Page 6719/33000; a portion of slice 103/1000 to tmp array index 3
# Page 6720/33000; a portion of slice 103/1000 to tmp array index 4
# Page 6721/33000; a portion of slice 103/1000 to tmp array index 5
# Page 6749/33000; a portion of slice 104/1000 to tmp array index 0
# Page 6750/33000; a portion of slice 104/1000 to tmp array index 1
# Page 6751/33000; a portion of slice 104/1000 to tmp array index 2
# Page 6752/33000; a portion of slice 104/1000 to tmp array index 3
# Page 6753/33000; a portion of slice 104/1000 to tmp array index 4
# Page 6754/33000; a portion of slice 104/1000 to tmp array index 5
# Page 6782/33000; a portion of slice 105/1000 to tmp array index 0
# Page 6783/33000; a portion of slice 105/1000 to tmp array index 1
# Page 6784/33000; a portion of slice 105/1000 to tmp array index 2
# Page 6785/33000; a portion of slice 105/1000 to tmp array index 3
# Page 6786/33000; a portion of slice 105/1000 to tmp array index 4
# Page 6787/33000; a portion of slice 105/1000 to tmp array index 5
# Page 6815/33000; a portion of slice 106/1000 to tmp array index 0
# Page 6816/33000; a portion of slice 106/1000 to tmp array index 1
# Page 6817/33000; a portion of slice 106/1000 to tmp array index 2
# Page 6818/33000; a portion of slice 106/1000 to tmp array index 3
# Page 6819/33000; a portion of slice 106/1000 to tmp array index 4
# Page 6820/33000; a portion of slice 106/1000 to tmp array index 5
# Page 6848/33000; a portion of slice 107/1000 to tmp array index 0
# Page 6849/33000; a portion of slice 107/1000 to tmp array index 1
# Page 6850/33000; a portion of slice 107/1000 to tmp array index 2
# Page 6851/33000; a portion of slice 107/1000 to tmp array index 3
# Page 6852/33000; a portion of slice 107/1000 to tmp array index 4
# Page 6853/33000; a portion of slice 107/1000 to tmp array index 5
# Page 6881/33000; a portion of slice 108/1000 to tmp array index 0
# Page 6882/33000; a portion of slice 108/1000 to tmp array index 1
# Page 6883/33000; a portion of slice 108/1000 to tmp array index 2
# Page 6884/33000; a portion of slice 108/1000 to tmp array index 3
# Page 6885/33000; a portion of slice 108/1000 to tmp array index 4
# Page 6886/33000; a portion of slice 108/1000 to tmp array index 5
# Page 6914/33000; a portion of slice 109/1000 to tmp array index 0
# Page 6915/33000; a portion of slice 109/1000 to tmp array index 1
# Page 6916/33000; a portion of slice 109/1000 to tmp array index 2
# Page 6917/33000; a portion of slice 109/1000 to tmp array index 3
# Page 6918/33000; a portion of slice 109/1000 to tmp array index 4
# Page 6919/33000; a portion of slice 109/1000 to tmp array index 5
# Page 6947/33000; a portion of slice 110/1000 to tmp array index 0
# Page 6948/33000; a portion of slice 110/1000 to tmp array index 1
# Page 6949/33000; a portion of slice 110/1000 to tmp array index 2
# Page 6950/33000; a portion of slice 110/1000 to tmp array index 3
# Page 6951/33000; a portion of slice 110/1000 to tmp array index 4
# Page 6952/33000; a portion of slice 110/1000 to tmp array index 5
# Page 6980/33000; a portion of slice 111/1000 to tmp array index 0
# Page 6981/33000; a portion of slice 111/1000 to tmp array index 1
# Page 6982/33000; a portion of slice 111/1000 to tmp array index 2
# Page 6983/33000; a portion of slice 111/1000 to tmp array index 3
# Page 6984/33000; a portion of slice 111/1000 to tmp array index 4
# Page 6985/33000; a portion of slice 111/1000 to tmp array index 5
# Page 7013/33000; a portion of slice 112/1000 to tmp array index 0
# Page 7014/33000; a portion of slice 112/1000 to tmp array index 1
# Page 7015/33000; a portion of slice 112/1000 to tmp array index 2
# Page 7016/33000; a portion of slice 112/1000 to tmp array index 3
# Page 7017/33000; a portion of slice 112/1000 to tmp array index 4
# Page 7018/33000; a portion of slice 112/1000 to tmp array index 5
# Page 7046/33000; a portion of slice 113/1000 to tmp array index 0
# Page 7047/33000; a portion of slice 113/1000 to tmp array index 1
# Page 7048/33000; a portion of slice 113/1000 to tmp array index 2
# Page 7049/33000; a portion of slice 113/1000 to tmp array index 3
# Page 7050/33000; a portion of slice 113/1000 to tmp array index 4
# Page 7051/33000; a portion of slice 113/1000 to tmp array index 5
# Page 7079/33000; a portion of slice 114/1000 to tmp array index 0
# Page 7080/33000; a portion of slice 114/1000 to tmp array index 1
# Page 7081/33000; a portion of slice 114/1000 to tmp array index 2
# Page 7082/33000; a portion of slice 114/1000 to tmp array index 3
# Page 7083/33000; a portion of slice 114/1000 to tmp array index 4
# Page 7084/33000; a portion of slice 114/1000 to tmp array index 5
# Page 7112/33000; a portion of slice 115/1000 to tmp array index 0
# Page 7113/33000; a portion of slice 115/1000 to tmp array index 1
# Page 7114/33000; a portion of slice 115/1000 to tmp array index 2
# Page 7115/33000; a portion of slice 115/1000 to tmp array index 3
# Page 7116/33000; a portion of slice 115/1000 to tmp array index 4
# Page 7117/33000; a portion of slice 115/1000 to tmp array index 5
# Page 7145/33000; a portion of slice 116/1000 to tmp array index 0
# Page 7146/33000; a portion of slice 116/1000 to tmp array index 1
# Page 7147/33000; a portion of slice 116/1000 to tmp array index 2
# Page 7148/33000; a portion of slice 116/1000 to tmp array index 3
# Page 7149/33000; a portion of slice 116/1000 to tmp array index 4
# Page 7150/33000; a portion of slice 116/1000 to tmp array index 5
# Page 7178/33000; a portion of slice 117/1000 to tmp array index 0
# Page 7179/33000; a portion of slice 117/1000 to tmp array index 1
# Page 7180/33000; a portion of slice 117/1000 to tmp array index 2
# Page 7181/33000; a portion of slice 117/1000 to tmp array index 3
# Page 7182/33000; a portion of slice 117/1000 to tmp array index 4
# Page 7183/33000; a portion of slice 117/1000 to tmp array index 5
# Page 7211/33000; a portion of slice 118/1000 to tmp array index 0
# Page 7212/33000; a portion of slice 118/1000 to tmp array index 1
# Page 7213/33000; a portion of slice 118/1000 to tmp array index 2
# Page 7214/33000; a portion of slice 118/1000 to tmp array index 3
# Page 7215/33000; a portion of slice 118/1000 to tmp array index 4
# Page 7216/33000; a portion of slice 118/1000 to tmp array index 5
# Page 7244/33000; a portion of slice 119/1000 to tmp array index 0
# Page 7245/33000; a portion of slice 119/1000 to tmp array index 1
# Page 7246/33000; a portion of slice 119/1000 to tmp array index 2
# Page 7247/33000; a portion of slice 119/1000 to tmp array index 3
# Page 7248/33000; a portion of slice 119/1000 to tmp array index 4
# Page 7249/33000; a portion of slice 119/1000 to tmp array index 5
# Page 7277/33000; a portion of slice 120/1000 to tmp array index 0
# Page 7278/33000; a portion of slice 120/1000 to tmp array index 1
# Page 7279/33000; a portion of slice 120/1000 to tmp array index 2
# Page 7280/33000; a portion of slice 120/1000 to tmp array index 3
# Page 7281/33000; a portion of slice 120/1000 to tmp array index 4
# Page 7282/33000; a portion of slice 120/1000 to tmp array index 5
# Page 7310/33000; a portion of slice 121/1000 to tmp array index 0
# Page 7311/33000; a portion of slice 121/1000 to tmp array index 1
# Page 7312/33000; a portion of slice 121/1000 to tmp array index 2
# Page 7313/33000; a portion of slice 121/1000 to tmp array index 3
# Page 7314/33000; a portion of slice 121/1000 to tmp array index 4
# Page 7315/33000; a portion of slice 121/1000 to tmp array index 5
# Page 7343/33000; a portion of slice 122/1000 to tmp array index 0
# Page 7344/33000; a portion of slice 122/1000 to tmp array index 1
# Page 7345/33000; a portion of slice 122/1000 to tmp array index 2
# ...
# Page 35032/33000; a portion of slice 961/1000 to tmp array index 2
# Page 35033/33000; a portion of slice 961/1000 to tmp array index 3
# Page 35034/33000; a portion of slice 961/1000 to tmp array index 4
# Page 35035/33000; a portion of slice 961/1000 to tmp array index 5
# Page 35063/33000; a portion of slice 962/1000 to tmp array index 0
# Page 35064/33000; a portion of slice 962/1000 to tmp array index 1
# Page 35065/33000; a portion of slice 962/1000 to tmp array index 2
# Page 35066/33000; a portion of slice 962/1000 to tmp array index 3
# Page 35067/33000; a portion of slice 962/1000 to tmp array index 4
# Page 35068/33000; a portion of slice 962/1000 to tmp array index 5
# Page 35096/33000; a portion of slice 963/1000 to tmp array index 0
# Page 35097/33000; a portion of slice 963/1000 to tmp array index 1
# Page 35098/33000; a portion of slice 963/1000 to tmp array index 2
# Page 35099/33000; a portion of slice 963/1000 to tmp array index 3
# Page 35100/33000; a portion of slice 963/1000 to tmp array index 4
# Page 35101/33000; a portion of slice 963/1000 to tmp array index 5
# Page 35129/33000; a portion of slice 964/1000 to tmp array index 0
# Page 35130/33000; a portion of slice 964/1000 to tmp array index 1
# Page 35131/33000; a portion of slice 964/1000 to tmp array index 2
# Page 35132/33000; a portion of slice 964/1000 to tmp array index 3
# Page 35133/33000; a portion of slice 964/1000 to tmp array index 4
# Page 35134/33000; a portion of slice 964/1000 to tmp array index 5
# Page 35162/33000; a portion of slice 965/1000 to tmp array index 0
# Page 35163/33000; a portion of slice 965/1000 to tmp array index 1
# Page 35164/33000; a portion of slice 965/1000 to tmp array index 2
# Page 35165/33000; a portion of slice 965/1000 to tmp array index 3
# Page 35166/33000; a portion of slice 965/1000 to tmp array index 4
# Page 35167/33000; a portion of slice 965/1000 to tmp array index 5
# Page 35195/33000; a portion of slice 966/1000 to tmp array index 0
# Page 35196/33000; a portion of slice 966/1000 to tmp array index 1
# Page 35197/33000; a portion of slice 966/1000 to tmp array index 2
# Page 35198/33000; a portion of slice 966/1000 to tmp array index 3
# Page 35199/33000; a portion of slice 966/1000 to tmp array index 4
# Page 35200/33000; a portion of slice 966/1000 to tmp array index 5
# Page 35228/33000; a portion of slice 967/1000 to tmp array index 0
# Page 35229/33000; a portion of slice 967/1000 to tmp array index 1
# Page 35230/33000; a portion of slice 967/1000 to tmp array index 2
# Page 35231/33000; a portion of slice 967/1000 to tmp array index 3
# Page 35232/33000; a portion of slice 967/1000 to tmp array index 4
# Page 35233/33000; a portion of slice 967/1000 to tmp array index 5
# Page 35261/33000; a portion of slice 968/1000 to tmp array index 0
# Page 35262/33000; a portion of slice 968/1000 to tmp array index 1
# Page 35263/33000; a portion of slice 968/1000 to tmp array index 2
# Page 35264/33000; a portion of slice 968/1000 to tmp array index 3
# Page 35265/33000; a portion of slice 968/1000 to tmp array index 4
# Page 35266/33000; a portion of slice 968/1000 to tmp array index 5
# Page 35294/33000; a portion of slice 969/1000 to tmp array index 0
# Page 35295/33000; a portion of slice 969/1000 to tmp array index 1
# Page 35296/33000; a portion of slice 969/1000 to tmp array index 2
# Page 35297/33000; a portion of slice 969/1000 to tmp array index 3
# Page 35298/33000; a portion of slice 969/1000 to tmp array index 4
# Page 35299/33000; a portion of slice 969/1000 to tmp array index 5
# Page 35327/33000; a portion of slice 970/1000 to tmp array index 0
# Page 35328/33000; a portion of slice 970/1000 to tmp array index 1
# Page 35329/33000; a portion of slice 970/1000 to tmp array index 2
# Page 35330/33000; a portion of slice 970/1000 to tmp array index 3
# Page 35331/33000; a portion of slice 970/1000 to tmp array index 4
# Page 35332/33000; a portion of slice 970/1000 to tmp array index 5
# Page 35360/33000; a portion of slice 971/1000 to tmp array index 0
# Page 35361/33000; a portion of slice 971/1000 to tmp array index 1
# Page 35362/33000; a portion of slice 971/1000 to tmp array index 2
# Page 35363/33000; a portion of slice 971/1000 to tmp array index 3
# Page 35364/33000; a portion of slice 971/1000 to tmp array index 4
# Page 35365/33000; a portion of slice 971/1000 to tmp array index 5
# Page 35393/33000; a portion of slice 972/1000 to tmp array index 0
# Page 35394/33000; a portion of slice 972/1000 to tmp array index 1
# Page 35395/33000; a portion of slice 972/1000 to tmp array index 2
# Page 35396/33000; a portion of slice 972/1000 to tmp array index 3
# Page 35397/33000; a portion of slice 972/1000 to tmp array index 4
# Page 35398/33000; a portion of slice 972/1000 to tmp array index 5
# Page 35426/33000; a portion of slice 973/1000 to tmp array index 0
# Page 35427/33000; a portion of slice 973/1000 to tmp array index 1
# Page 35428/33000; a portion of slice 973/1000 to tmp array index 2
# Page 35429/33000; a portion of slice 973/1000 to tmp array index 3
# Page 35430/33000; a portion of slice 973/1000 to tmp array index 4
# Page 35431/33000; a portion of slice 973/1000 to tmp array index 5
# Page 35459/33000; a portion of slice 974/1000 to tmp array index 0
# Page 35460/33000; a portion of slice 974/1000 to tmp array index 1
# Page 35461/33000; a portion of slice 974/1000 to tmp array index 2
# Page 35462/33000; a portion of slice 974/1000 to tmp array index 3
# Page 35463/33000; a portion of slice 974/1000 to tmp array index 4
# Page 35464/33000; a portion of slice 974/1000 to tmp array index 5
# Page 35492/33000; a portion of slice 975/1000 to tmp array index 0
# Page 35493/33000; a portion of slice 975/1000 to tmp array index 1
# Page 35494/33000; a portion of slice 975/1000 to tmp array index 2
# Page 35495/33000; a portion of slice 975/1000 to tmp array index 3
# Page 35496/33000; a portion of slice 975/1000 to tmp array index 4
# Page 35497/33000; a portion of slice 975/1000 to tmp array index 5
# Page 35525/33000; a portion of slice 976/1000 to tmp array index 0
# Page 35526/33000; a portion of slice 976/1000 to tmp array index 1
# Page 35527/33000; a portion of slice 976/1000 to tmp array index 2
# Page 35528/33000; a portion of slice 976/1000 to tmp array index 3
# Page 35529/33000; a portion of slice 976/1000 to tmp array index 4
# Page 35530/33000; a portion of slice 976/1000 to tmp array index 5
# Page 35558/33000; a portion of slice 977/1000 to tmp array index 0
# Page 35559/33000; a portion of slice 977/1000 to tmp array index 1
# Page 35560/33000; a portion of slice 977/1000 to tmp array index 2
# Page 35561/33000; a portion of slice 977/1000 to tmp array index 3
# Page 35562/33000; a portion of slice 977/1000 to tmp array index 4
# Page 35563/33000; a portion of slice 977/1000 to tmp array index 5
# Page 35591/33000; a portion of slice 978/1000 to tmp array index 0
# Page 35592/33000; a portion of slice 978/1000 to tmp array index 1
# Page 35593/33000; a portion of slice 978/1000 to tmp array index 2
# Page 35594/33000; a portion of slice 978/1000 to tmp array index 3
# Page 35595/33000; a portion of slice 978/1000 to tmp array index 4
# Page 35596/33000; a portion of slice 978/1000 to tmp array index 5
# Page 35624/33000; a portion of slice 979/1000 to tmp array index 0
# Page 35625/33000; a portion of slice 979/1000 to tmp array index 1
# Page 35626/33000; a portion of slice 979/1000 to tmp array index 2
# Page 35627/33000; a portion of slice 979/1000 to tmp array index 3
# Page 35628/33000; a portion of slice 979/1000 to tmp array index 4
# Page 35629/33000; a portion of slice 979/1000 to tmp array index 5
# Page 35657/33000; a portion of slice 980/1000 to tmp array index 0
# Page 35658/33000; a portion of slice 980/1000 to tmp array index 1
# Page 35659/33000; a portion of slice 980/1000 to tmp array index 2
# Page 35660/33000; a portion of slice 980/1000 to tmp array index 3
# Page 35661/33000; a portion of slice 980/1000 to tmp array index 4
# Page 35662/33000; a portion of slice 980/1000 to tmp array index 5
# Page 35690/33000; a portion of slice 981/1000 to tmp array index 0
# Page 35691/33000; a portion of slice 981/1000 to tmp array index 1
# Page 35692/33000; a portion of slice 981/1000 to tmp array index 2
# Page 35693/33000; a portion of slice 981/1000 to tmp array index 3
# Page 35694/33000; a portion of slice 981/1000 to tmp array index 4
# Page 35695/33000; a portion of slice 981/1000 to tmp array index 5
# Page 35723/33000; a portion of slice 982/1000 to tmp array index 0
# Page 35724/33000; a portion of slice 982/1000 to tmp array index 1
# Page 35725/33000; a portion of slice 982/1000 to tmp array index 2
# Page 35726/33000; a portion of slice 982/1000 to tmp array index 3
# Page 35727/33000; a portion of slice 982/1000 to tmp array index 4
# Page 35728/33000; a portion of slice 982/1000 to tmp array index 5
# Page 35756/33000; a portion of slice 983/1000 to tmp array index 0
# Page 35757/33000; a portion of slice 983/1000 to tmp array index 1
# Page 35758/33000; a portion of slice 983/1000 to tmp array index 2
# Page 35759/33000; a portion of slice 983/1000 to tmp array index 3
# Page 35760/33000; a portion of slice 983/1000 to tmp array index 4
# Page 35761/33000; a portion of slice 983/1000 to tmp array index 5
# Page 35789/33000; a portion of slice 984/1000 to tmp array index 0
# Page 35790/33000; a portion of slice 984/1000 to tmp array index 1
# Page 35791/33000; a portion of slice 984/1000 to tmp array index 2
# Page 35792/33000; a portion of slice 984/1000 to tmp array index 3
# Page 35793/33000; a portion of slice 984/1000 to tmp array index 4
# Page 35794/33000; a portion of slice 984/1000 to tmp array index 5
# Page 35822/33000; a portion of slice 985/1000 to tmp array index 0
# Page 35823/33000; a portion of slice 985/1000 to tmp array index 1
# Page 35824/33000; a portion of slice 985/1000 to tmp array index 2
# Page 35825/33000; a portion of slice 985/1000 to tmp array index 3
# Page 35826/33000; a portion of slice 985/1000 to tmp array index 4
# Page 35827/33000; a portion of slice 985/1000 to tmp array index 5
# Page 35855/33000; a portion of slice 986/1000 to tmp array index 0
# Page 35856/33000; a portion of slice 986/1000 to tmp array index 1
# Page 35857/33000; a portion of slice 986/1000 to tmp array index 2
# Page 35858/33000; a portion of slice 986/1000 to tmp array index 3
# Page 35859/33000; a portion of slice 986/1000 to tmp array index 4
# Page 35860/33000; a portion of slice 986/1000 to tmp array index 5
# Page 35888/33000; a portion of slice 987/1000 to tmp array index 0
# Page 35889/33000; a portion of slice 987/1000 to tmp array index 1
# Page 35890/33000; a portion of slice 987/1000 to tmp array index 2
# Page 35891/33000; a portion of slice 987/1000 to tmp array index 3
# Page 35892/33000; a portion of slice 987/1000 to tmp array index 4
# Page 35893/33000; a portion of slice 987/1000 to tmp array index 5
# Page 35921/33000; a portion of slice 988/1000 to tmp array index 0
# Page 35922/33000; a portion of slice 988/1000 to tmp array index 1
# Page 35923/33000; a portion of slice 988/1000 to tmp array index 2
# Page 35924/33000; a portion of slice 988/1000 to tmp array index 3
# Page 35925/33000; a portion of slice 988/1000 to tmp array index 4
# Page 35926/33000; a portion of slice 988/1000 to tmp array index 5
# Page 35954/33000; a portion of slice 989/1000 to tmp array index 0
# Page 35955/33000; a portion of slice 989/1000 to tmp array index 1
# Page 35956/33000; a portion of slice 989/1000 to tmp array index 2
# Page 35957/33000; a portion of slice 989/1000 to tmp array index 3
# Page 35958/33000; a portion of slice 989/1000 to tmp array index 4
# Page 35959/33000; a portion of slice 989/1000 to tmp array index 5
# Page 35987/33000; a portion of slice 990/1000 to tmp array index 0
# Page 35988/33000; a portion of slice 990/1000 to tmp array index 1
# Page 35989/33000; a portion of slice 990/1000 to tmp array index 2
# Page 35990/33000; a portion of slice 990/1000 to tmp array index 3
# Page 35991/33000; a portion of slice 990/1000 to tmp array index 4
# Page 35992/33000; a portion of slice 990/1000 to tmp array index 5
# Page 36020/33000; a portion of slice 991/1000 to tmp array index 0
# Page 36021/33000; a portion of slice 991/1000 to tmp array index 1
# Page 36022/33000; a portion of slice 991/1000 to tmp array index 2
# Page 36023/33000; a portion of slice 991/1000 to tmp array index 3
# Page 36024/33000; a portion of slice 991/1000 to tmp array index 4
# Page 36025/33000; a portion of slice 991/1000 to tmp array index 5
# Page 36053/33000; a portion of slice 992/1000 to tmp array index 0
# Page 36054/33000; a portion of slice 992/1000 to tmp array index 1
# Page 36055/33000; a portion of slice 992/1000 to tmp array index 2
# Page 36056/33000; a portion of slice 992/1000 to tmp array index 3
# Page 36057/33000; a portion of slice 992/1000 to tmp array index 4
# Page 36058/33000; a portion of slice 992/1000 to tmp array index 5
# Page 36086/33000; a portion of slice 993/1000 to tmp array index 0
# Page 36087/33000; a portion of slice 993/1000 to tmp array index 1
# Page 36088/33000; a portion of slice 993/1000 to tmp array index 2
# Page 36089/33000; a portion of slice 993/1000 to tmp array index 3
# Page 36090/33000; a portion of slice 993/1000 to tmp array index 4
# Page 36091/33000; a portion of slice 993/1000 to tmp array index 5
# Page 36119/33000; a portion of slice 994/1000 to tmp array index 0
# Page 36120/33000; a portion of slice 994/1000 to tmp array index 1
# Page 36121/33000; a portion of slice 994/1000 to tmp array index 2
# Page 36122/33000; a portion of slice 994/1000 to tmp array index 3
# Page 36123/33000; a portion of slice 994/1000 to tmp array index 4
# Page 36124/33000; a portion of slice 994/1000 to tmp array index 5
# Page 36152/33000; a portion of slice 995/1000 to tmp array index 0
# Page 36153/33000; a portion of slice 995/1000 to tmp array index 1
# Page 36154/33000; a portion of slice 995/1000 to tmp array index 2
# Page 36155/33000; a portion of slice 995/1000 to tmp array index 3
# Page 36156/33000; a portion of slice 995/1000 to tmp array index 4
# Page 36157/33000; a portion of slice 995/1000 to tmp array index 5
# Page 36185/33000; a portion of slice 996/1000 to tmp array index 0
# Page 36186/33000; a portion of slice 996/1000 to tmp array index 1
# Page 36187/33000; a portion of slice 996/1000 to tmp array index 2
# Page 36188/33000; a portion of slice 996/1000 to tmp array index 3
# Page 36189/33000; a portion of slice 996/1000 to tmp array index 4
# Page 36190/33000; a portion of slice 996/1000 to tmp array index 5
# Page 36218/33000; a portion of slice 997/1000 to tmp array index 0
# Page 36219/33000; a portion of slice 997/1000 to tmp array index 1
# Page 36220/33000; a portion of slice 997/1000 to tmp array index 2
# Page 36221/33000; a portion of slice 997/1000 to tmp array index 3
# Page 36222/33000; a portion of slice 997/1000 to tmp array index 4
# Page 36223/33000; a portion of slice 997/1000 to tmp array index 5
# Page 36251/33000; a portion of slice 998/1000 to tmp array index 0
# Page 36252/33000; a portion of slice 998/1000 to tmp array index 1
# Page 36253/33000; a portion of slice 998/1000 to tmp array index 2
# Page 36254/33000; a portion of slice 998/1000 to tmp array index 3
# Page 36255/33000; a portion of slice 998/1000 to tmp array index 4
# Page 36256/33000; a portion of slice 998/1000 to tmp array index 5
# Page 36284/33000; a portion of slice 999/1000 to tmp array index 0
# Page 36285/33000; a portion of slice 999/1000 to tmp array index 1
# Page 36286/33000; a portion of slice 999/1000 to tmp array index 2
# Page 36287/33000; a portion of slice 999/1000 to tmp array index 3
# Page 36288/33000; a portion of slice 999/1000 to tmp array index 4
# Page 36289/33000; a portion of slice 999/1000 to tmp array index 5
# Page 36317/33000; a portion of slice 1000/1000 to tmp array index 0
# Page 36318/33000; a portion of slice 1000/1000 to tmp array index 1
# Page 36319/33000; a portion of slice 1000/1000 to tmp array index 2
# Page 36320/33000; a portion of slice 1000/1000 to tmp array index 3
# Page 36321/33000; a portion of slice 1000/1000 to tmp array index 4
# Page 36322/33000; a portion of slice 1000/1000 to tmp array index 5

# %% [markdown]
# ## Do the same, but for other channel

# %%
if os.name == 'nt':
    input_foldername = 'Y:\\Ulises\\wbfm\\20200924and28\\202009282020-09-28_17-30-28_worm4_chemotaxis-channel-1-pco_camera2'
else:
    input_foldername = '/groups/zimmer/Ulises/wbfm/20200924and28/202009282020-09-28_17-30-28_worm4_chemotaxis-channel-1-pco_camera2/'
fname = '202009282020-09-28_17-30-28_worm4_chemotaxis-channel-1-pco_camera2bigtiff.btf'
input_fname = os.path.join(input_foldername, fname)
# input_fname = os.path.normpath(input_fname) # Make it work on windows

# Final .avi
if os.name == 'nt':
    output_foldername = 'Y:\\shared_projects\\wbfm\\dat\\short_wbfm_z_stabilized'
else:
    output_foldername = '/users/charles.fieseler/shared_projects/wbfm/dat/short_wbfm_z_stabilized/'
fname = f'202009282020-09-28_17-30-28_worm4_chemotaxis-channel-1-pco_camera2_bigtiff_gcamp_frames{num_frames}_slice{which_slices[0]}_{which_slices[-1]}.avi'
output_fname = os.path.join(output_foldername, fname)

# %%
write_video_projection_from_ome_file_subset(input_fname, output_fname, which_slices=which_slices,
                                             frame_width=frame_width, frame_height=frame_height,
                                             num_slices=33,
                                             start_volume=start_volume,
                                             num_frames=num_frames,
                                             alpha=alpha) # e.g. from above OME-TIFF
# Out:
# Converting volume index 100 to frame index 3300
# Taking a max of 6 slices, starting at 17
# Page 3317/33000; a portion of slice 0/1000 to tmp array index 0
# Page 3318/33000; a portion of slice 0/1000 to tmp array index 1
# Page 3319/33000; a portion of slice 0/1000 to tmp array index 2
# Page 3320/33000; a portion of slice 0/1000 to tmp array index 3
# Page 3321/33000; a portion of slice 0/1000 to tmp array index 4
# Page 3322/33000; a portion of slice 0/1000 to tmp array index 5
# Page 3350/33000; a portion of slice 1/1000 to tmp array index 0
# Page 3351/33000; a portion of slice 1/1000 to tmp array index 1
# Page 3352/33000; a portion of slice 1/1000 to tmp array index 2
# Page 3353/33000; a portion of slice 1/1000 to tmp array index 3
# Page 3354/33000; a portion of slice 1/1000 to tmp array index 4
# Page 3355/33000; a portion of slice 1/1000 to tmp array index 5
# Page 3383/33000; a portion of slice 2/1000 to tmp array index 0
# Page 3384/33000; a portion of slice 2/1000 to tmp array index 1
# Page 3385/33000; a portion of slice 2/1000 to tmp array index 2
# Page 3386/33000; a portion of slice 2/1000 to tmp array index 3
# Page 3387/33000; a portion of slice 2/1000 to tmp array index 4
# Page 3388/33000; a portion of slice 2/1000 to tmp array index 5
# Page 3416/33000; a portion of slice 3/1000 to tmp array index 0
# Page 3417/33000; a portion of slice 3/1000 to tmp array index 1
# Page 3418/33000; a portion of slice 3/1000 to tmp array index 2
# Page 3419/33000; a portion of slice 3/1000 to tmp array index 3
# Page 3420/33000; a portion of slice 3/1000 to tmp array index 4
# Page 3421/33000; a portion of slice 3/1000 to tmp array index 5
# Page 3449/33000; a portion of slice 4/1000 to tmp array index 0
# Page 3450/33000; a portion of slice 4/1000 to tmp array index 1
# Page 3451/33000; a portion of slice 4/1000 to tmp array index 2
# Page 3452/33000; a portion of slice 4/1000 to tmp array index 3
# Page 3453/33000; a portion of slice 4/1000 to tmp array index 4
# Page 3454/33000; a portion of slice 4/1000 to tmp array index 5
# Page 3482/33000; a portion of slice 5/1000 to tmp array index 0
# Page 3483/33000; a portion of slice 5/1000 to tmp array index 1
# Page 3484/33000; a portion of slice 5/1000 to tmp array index 2
# Page 3485/33000; a portion of slice 5/1000 to tmp array index 3
# Page 3486/33000; a portion of slice 5/1000 to tmp array index 4
# Page 3487/33000; a portion of slice 5/1000 to tmp array index 5
# Page 3515/33000; a portion of slice 6/1000 to tmp array index 0
# Page 3516/33000; a portion of slice 6/1000 to tmp array index 1
# Page 3517/33000; a portion of slice 6/1000 to tmp array index 2
# Page 3518/33000; a portion of slice 6/1000 to tmp array index 3
# Page 3519/33000; a portion of slice 6/1000 to tmp array index 4
# Page 3520/33000; a portion of slice 6/1000 to tmp array index 5
# Page 3548/33000; a portion of slice 7/1000 to tmp array index 0
# Page 3549/33000; a portion of slice 7/1000 to tmp array index 1
# Page 3550/33000; a portion of slice 7/1000 to tmp array index 2
# Page 3551/33000; a portion of slice 7/1000 to tmp array index 3
# Page 3552/33000; a portion of slice 7/1000 to tmp array index 4
# Page 3553/33000; a portion of slice 7/1000 to tmp array index 5
# Page 3581/33000; a portion of slice 8/1000 to tmp array index 0
# Page 3582/33000; a portion of slice 8/1000 to tmp array index 1
# Page 3583/33000; a portion of slice 8/1000 to tmp array index 2
# Page 3584/33000; a portion of slice 8/1000 to tmp array index 3
# Page 3585/33000; a portion of slice 8/1000 to tmp array index 4
# Page 3586/33000; a portion of slice 8/1000 to tmp array index 5
# Page 3614/33000; a portion of slice 9/1000 to tmp array index 0
# Page 3615/33000; a portion of slice 9/1000 to tmp array index 1
# Page 3616/33000; a portion of slice 9/1000 to tmp array index 2
# Page 3617/33000; a portion of slice 9/1000 to tmp array index 3
# Page 3618/33000; a portion of slice 9/1000 to tmp array index 4
# Page 3619/33000; a portion of slice 9/1000 to tmp array index 5
# Page 3647/33000; a portion of slice 10/1000 to tmp array index 0
# Page 3648/33000; a portion of slice 10/1000 to tmp array index 1
# Page 3649/33000; a portion of slice 10/1000 to tmp array index 2
# Page 3650/33000; a portion of slice 10/1000 to tmp array index 3
# Page 3651/33000; a portion of slice 10/1000 to tmp array index 4
# Page 3652/33000; a portion of slice 10/1000 to tmp array index 5
# Page 3680/33000; a portion of slice 11/1000 to tmp array index 0
# Page 3681/33000; a portion of slice 11/1000 to tmp array index 1
# Page 3682/33000; a portion of slice 11/1000 to tmp array index 2
# Page 3683/33000; a portion of slice 11/1000 to tmp array index 3
# Page 3684/33000; a portion of slice 11/1000 to tmp array index 4
# Page 3685/33000; a portion of slice 11/1000 to tmp array index 5
# Page 3713/33000; a portion of slice 12/1000 to tmp array index 0
# Page 3714/33000; a portion of slice 12/1000 to tmp array index 1
# Page 3715/33000; a portion of slice 12/1000 to tmp array index 2
# Page 3716/33000; a portion of slice 12/1000 to tmp array index 3
# Page 3717/33000; a portion of slice 12/1000 to tmp array index 4
# Page 3718/33000; a portion of slice 12/1000 to tmp array index 5
# Page 3746/33000; a portion of slice 13/1000 to tmp array index 0
# Page 3747/33000; a portion of slice 13/1000 to tmp array index 1
# Page 3748/33000; a portion of slice 13/1000 to tmp array index 2
# Page 3749/33000; a portion of slice 13/1000 to tmp array index 3
# Page 3750/33000; a portion of slice 13/1000 to tmp array index 4
# Page 3751/33000; a portion of slice 13/1000 to tmp array index 5
# Page 3779/33000; a portion of slice 14/1000 to tmp array index 0
# Page 3780/33000; a portion of slice 14/1000 to tmp array index 1
# Page 3781/33000; a portion of slice 14/1000 to tmp array index 2
# Page 3782/33000; a portion of slice 14/1000 to tmp array index 3
# Page 3783/33000; a portion of slice 14/1000 to tmp array index 4
# Page 3784/33000; a portion of slice 14/1000 to tmp array index 5
# Page 3812/33000; a portion of slice 15/1000 to tmp array index 0
# Page 3813/33000; a portion of slice 15/1000 to tmp array index 1
# Page 3814/33000; a portion of slice 15/1000 to tmp array index 2
# Page 3815/33000; a portion of slice 15/1000 to tmp array index 3
# Page 3816/33000; a portion of slice 15/1000 to tmp array index 4
# Page 3817/33000; a portion of slice 15/1000 to tmp array index 5
# Page 3845/33000; a portion of slice 16/1000 to tmp array index 0
# Page 3846/33000; a portion of slice 16/1000 to tmp array index 1
# Page 3847/33000; a portion of slice 16/1000 to tmp array index 2
# Page 3848/33000; a portion of slice 16/1000 to tmp array index 3
# Page 3849/33000; a portion of slice 16/1000 to tmp array index 4
# Page 3850/33000; a portion of slice 16/1000 to tmp array index 5
# Page 3878/33000; a portion of slice 17/1000 to tmp array index 0
# Page 3879/33000; a portion of slice 17/1000 to tmp array index 1
# Page 3880/33000; a portion of slice 17/1000 to tmp array index 2
# Page 3881/33000; a portion of slice 17/1000 to tmp array index 3
# Page 3882/33000; a portion of slice 17/1000 to tmp array index 4
# Page 3883/33000; a portion of slice 17/1000 to tmp array index 5
# Page 3911/33000; a portion of slice 18/1000 to tmp array index 0
# Page 3912/33000; a portion of slice 18/1000 to tmp array index 1
# Page 3913/33000; a portion of slice 18/1000 to tmp array index 2
# Page 3914/33000; a portion of slice 18/1000 to tmp array index 3
# Page 3915/33000; a portion of slice 18/1000 to tmp array index 4
# Page 3916/33000; a portion of slice 18/1000 to tmp array index 5
# Page 3944/33000; a portion of slice 19/1000 to tmp array index 0
# Page 3945/33000; a portion of slice 19/1000 to tmp array index 1
# Page 3946/33000; a portion of slice 19/1000 to tmp array index 2
# Page 3947/33000; a portion of slice 19/1000 to tmp array index 3
# Page 3948/33000; a portion of slice 19/1000 to tmp array index 4
# Page 3949/33000; a portion of slice 19/1000 to tmp array index 5
# Page 3977/33000; a portion of slice 20/1000 to tmp array index 0
# Page 3978/33000; a portion of slice 20/1000 to tmp array index 1
# Page 3979/33000; a portion of slice 20/1000 to tmp array index 2
# Page 3980/33000; a portion of slice 20/1000 to tmp array index 3
# Page 3981/33000; a portion of slice 20/1000 to tmp array index 4
# Page 3982/33000; a portion of slice 20/1000 to tmp array index 5
# Page 4010/33000; a portion of slice 21/1000 to tmp array index 0
# Page 4011/33000; a portion of slice 21/1000 to tmp array index 1
# Page 4012/33000; a portion of slice 21/1000 to tmp array index 2
# Page 4013/33000; a portion of slice 21/1000 to tmp array index 3
# Page 4014/33000; a portion of slice 21/1000 to tmp array index 4
# Page 4015/33000; a portion of slice 21/1000 to tmp array index 5
# Page 4043/33000; a portion of slice 22/1000 to tmp array index 0
# Page 4044/33000; a portion of slice 22/1000 to tmp array index 1
# Page 4045/33000; a portion of slice 22/1000 to tmp array index 2
# Page 4046/33000; a portion of slice 22/1000 to tmp array index 3
# Page 4047/33000; a portion of slice 22/1000 to tmp array index 4
# Page 4048/33000; a portion of slice 22/1000 to tmp array index 5
# Page 4076/33000; a portion of slice 23/1000 to tmp array index 0
# Page 4077/33000; a portion of slice 23/1000 to tmp array index 1
# Page 4078/33000; a portion of slice 23/1000 to tmp array index 2
# Page 4079/33000; a portion of slice 23/1000 to tmp array index 3
# Page 4080/33000; a portion of slice 23/1000 to tmp array index 4
# Page 4081/33000; a portion of slice 23/1000 to tmp array index 5
# Page 4109/33000; a portion of slice 24/1000 to tmp array index 0
# Page 4110/33000; a portion of slice 24/1000 to tmp array index 1
# Page 4111/33000; a portion of slice 24/1000 to tmp array index 2
# Page 4112/33000; a portion of slice 24/1000 to tmp array index 3
# Page 4113/33000; a portion of slice 24/1000 to tmp array index 4
# Page 4114/33000; a portion of slice 24/1000 to tmp array index 5
# Page 4142/33000; a portion of slice 25/1000 to tmp array index 0
# Page 4143/33000; a portion of slice 25/1000 to tmp array index 1
# Page 4144/33000; a portion of slice 25/1000 to tmp array index 2
# Page 4145/33000; a portion of slice 25/1000 to tmp array index 3
# Page 4146/33000; a portion of slice 25/1000 to tmp array index 4
# Page 4147/33000; a portion of slice 25/1000 to tmp array index 5
# Page 4175/33000; a portion of slice 26/1000 to tmp array index 0
# Page 4176/33000; a portion of slice 26/1000 to tmp array index 1
# Page 4177/33000; a portion of slice 26/1000 to tmp array index 2
# Page 4178/33000; a portion of slice 26/1000 to tmp array index 3
# Page 4179/33000; a portion of slice 26/1000 to tmp array index 4
# Page 4180/33000; a portion of slice 26/1000 to tmp array index 5
# Page 4208/33000; a portion of slice 27/1000 to tmp array index 0
# Page 4209/33000; a portion of slice 27/1000 to tmp array index 1
# Page 4210/33000; a portion of slice 27/1000 to tmp array index 2
# Page 4211/33000; a portion of slice 27/1000 to tmp array index 3
# Page 4212/33000; a portion of slice 27/1000 to tmp array index 4
# Page 4213/33000; a portion of slice 27/1000 to tmp array index 5
# Page 4241/33000; a portion of slice 28/1000 to tmp array index 0
# Page 4242/33000; a portion of slice 28/1000 to tmp array index 1
# Page 4243/33000; a portion of slice 28/1000 to tmp array index 2
# Page 4244/33000; a portion of slice 28/1000 to tmp array index 3
# Page 4245/33000; a portion of slice 28/1000 to tmp array index 4
# Page 4246/33000; a portion of slice 28/1000 to tmp array index 5
# Page 4274/33000; a portion of slice 29/1000 to tmp array index 0
# Page 4275/33000; a portion of slice 29/1000 to tmp array index 1
# Page 4276/33000; a portion of slice 29/1000 to tmp array index 2
# Page 4277/33000; a portion of slice 29/1000 to tmp array index 3
# Page 4278/33000; a portion of slice 29/1000 to tmp array index 4
# Page 4279/33000; a portion of slice 29/1000 to tmp array index 5
# Page 4307/33000; a portion of slice 30/1000 to tmp array index 0
# Page 4308/33000; a portion of slice 30/1000 to tmp array index 1
# Page 4309/33000; a portion of slice 30/1000 to tmp array index 2
# Page 4310/33000; a portion of slice 30/1000 to tmp array index 3
# Page 4311/33000; a portion of slice 30/1000 to tmp array index 4
# Page 4312/33000; a portion of slice 30/1000 to tmp array index 5
# Page 4340/33000; a portion of slice 31/1000 to tmp array index 0
# Page 4341/33000; a portion of slice 31/1000 to tmp array index 1
# Page 4342/33000; a portion of slice 31/1000 to tmp array index 2
# Page 4343/33000; a portion of slice 31/1000 to tmp array index 3
# Page 4344/33000; a portion of slice 31/1000 to tmp array index 4
# Page 4345/33000; a portion of slice 31/1000 to tmp array index 5
# Page 4373/33000; a portion of slice 32/1000 to tmp array index 0
# Page 4374/33000; a portion of slice 32/1000 to tmp array index 1
# Page 4375/33000; a portion of slice 32/1000 to tmp array index 2
# Page 4376/33000; a portion of slice 32/1000 to tmp array index 3
# Page 4377/33000; a portion of slice 32/1000 to tmp array index 4
# Page 4378/33000; a portion of slice 32/1000 to tmp array index 5
# Page 4406/33000; a portion of slice 33/1000 to tmp array index 0
# Page 4407/33000; a portion of slice 33/1000 to tmp array index 1
# Page 4408/33000; a portion of slice 33/1000 to tmp array index 2
# Page 4409/33000; a portion of slice 33/1000 to tmp array index 3
# Page 4410/33000; a portion of slice 33/1000 to tmp array index 4
# Page 4411/33000; a portion of slice 33/1000 to tmp array index 5
# Page 4439/33000; a portion of slice 34/1000 to tmp array index 0
# Page 4440/33000; a portion of slice 34/1000 to tmp array index 1
# Page 4441/33000; a portion of slice 34/1000 to tmp array index 2
# Page 4442/33000; a portion of slice 34/1000 to tmp array index 3
# Page 4443/33000; a portion of slice 34/1000 to tmp array index 4
# Page 4444/33000; a portion of slice 34/1000 to tmp array index 5
# Page 4472/33000; a portion of slice 35/1000 to tmp array index 0
# Page 4473/33000; a portion of slice 35/1000 to tmp array index 1
# Page 4474/33000; a portion of slice 35/1000 to tmp array index 2
# Page 4475/33000; a portion of slice 35/1000 to tmp array index 3
# Page 4476/33000; a portion of slice 35/1000 to tmp array index 4
# Page 4477/33000; a portion of slice 35/1000 to tmp array index 5
# Page 4505/33000; a portion of slice 36/1000 to tmp array index 0
# Page 4506/33000; a portion of slice 36/1000 to tmp array index 1
# Page 4507/33000; a portion of slice 36/1000 to tmp array index 2
# Page 4508/33000; a portion of slice 36/1000 to tmp array index 3
# Page 4509/33000; a portion of slice 36/1000 to tmp array index 4
# Page 4510/33000; a portion of slice 36/1000 to tmp array index 5
# Page 4538/33000; a portion of slice 37/1000 to tmp array index 0
# Page 4539/33000; a portion of slice 37/1000 to tmp array index 1
# Page 4540/33000; a portion of slice 37/1000 to tmp array index 2
# Page 4541/33000; a portion of slice 37/1000 to tmp array index 3
# Page 4542/33000; a portion of slice 37/1000 to tmp array index 4
# Page 4543/33000; a portion of slice 37/1000 to tmp array index 5
# Page 4571/33000; a portion of slice 38/1000 to tmp array index 0
# Page 4572/33000; a portion of slice 38/1000 to tmp array index 1
# Page 4573/33000; a portion of slice 38/1000 to tmp array index 2
# Page 4574/33000; a portion of slice 38/1000 to tmp array index 3
# Page 4575/33000; a portion of slice 38/1000 to tmp array index 4
# Page 4576/33000; a portion of slice 38/1000 to tmp array index 5
# Page 4604/33000; a portion of slice 39/1000 to tmp array index 0
# Page 4605/33000; a portion of slice 39/1000 to tmp array index 1
# Page 4606/33000; a portion of slice 39/1000 to tmp array index 2
# Page 4607/33000; a portion of slice 39/1000 to tmp array index 3
# Page 4608/33000; a portion of slice 39/1000 to tmp array index 4
# Page 4609/33000; a portion of slice 39/1000 to tmp array index 5
# Page 4637/33000; a portion of slice 40/1000 to tmp array index 0
# Page 4638/33000; a portion of slice 40/1000 to tmp array index 1
# Page 4639/33000; a portion of slice 40/1000 to tmp array index 2
# Page 4640/33000; a portion of slice 40/1000 to tmp array index 3
# Page 4641/33000; a portion of slice 40/1000 to tmp array index 4
# Page 4642/33000; a portion of slice 40/1000 to tmp array index 5
# Page 4670/33000; a portion of slice 41/1000 to tmp array index 0
# Page 4671/33000; a portion of slice 41/1000 to tmp array index 1
# Page 4672/33000; a portion of slice 41/1000 to tmp array index 2
# Page 4673/33000; a portion of slice 41/1000 to tmp array index 3
# Page 4674/33000; a portion of slice 41/1000 to tmp array index 4
# Page 4675/33000; a portion of slice 41/1000 to tmp array index 5
# Page 4703/33000; a portion of slice 42/1000 to tmp array index 0
# Page 4704/33000; a portion of slice 42/1000 to tmp array index 1
# Page 4705/33000; a portion of slice 42/1000 to tmp array index 2
# Page 4706/33000; a portion of slice 42/1000 to tmp array index 3
# Page 4707/33000; a portion of slice 42/1000 to tmp array index 4
# Page 4708/33000; a portion of slice 42/1000 to tmp array index 5
# Page 4736/33000; a portion of slice 43/1000 to tmp array index 0
# Page 4737/33000; a portion of slice 43/1000 to tmp array index 1
# Page 4738/33000; a portion of slice 43/1000 to tmp array index 2
# Page 4739/33000; a portion of slice 43/1000 to tmp array index 3
# Page 4740/33000; a portion of slice 43/1000 to tmp array index 4
# Page 4741/33000; a portion of slice 43/1000 to tmp array index 5
# Page 4769/33000; a portion of slice 44/1000 to tmp array index 0
# Page 4770/33000; a portion of slice 44/1000 to tmp array index 1
# Page 4771/33000; a portion of slice 44/1000 to tmp array index 2
# Page 4772/33000; a portion of slice 44/1000 to tmp array index 3
# Page 4773/33000; a portion of slice 44/1000 to tmp array index 4
# Page 4774/33000; a portion of slice 44/1000 to tmp array index 5
# Page 4802/33000; a portion of slice 45/1000 to tmp array index 0
# Page 4803/33000; a portion of slice 45/1000 to tmp array index 1
# Page 4804/33000; a portion of slice 45/1000 to tmp array index 2
# Page 4805/33000; a portion of slice 45/1000 to tmp array index 3
# Page 4806/33000; a portion of slice 45/1000 to tmp array index 4
# Page 4807/33000; a portion of slice 45/1000 to tmp array index 5
# Page 4835/33000; a portion of slice 46/1000 to tmp array index 0
# Page 4836/33000; a portion of slice 46/1000 to tmp array index 1
# Page 4837/33000; a portion of slice 46/1000 to tmp array index 2
# Page 4838/33000; a portion of slice 46/1000 to tmp array index 3
# Page 4839/33000; a portion of slice 46/1000 to tmp array index 4
# Page 4840/33000; a portion of slice 46/1000 to tmp array index 5
# Page 4868/33000; a portion of slice 47/1000 to tmp array index 0
# Page 4869/33000; a portion of slice 47/1000 to tmp array index 1
# Page 4870/33000; a portion of slice 47/1000 to tmp array index 2
# Page 4871/33000; a portion of slice 47/1000 to tmp array index 3
# Page 4872/33000; a portion of slice 47/1000 to tmp array index 4
# Page 4873/33000; a portion of slice 47/1000 to tmp array index 5
# Page 4901/33000; a portion of slice 48/1000 to tmp array index 0
# Page 4902/33000; a portion of slice 48/1000 to tmp array index 1
# Page 4903/33000; a portion of slice 48/1000 to tmp array index 2
# Page 4904/33000; a portion of slice 48/1000 to tmp array index 3
# Page 4905/33000; a portion of slice 48/1000 to tmp array index 4
# Page 4906/33000; a portion of slice 48/1000 to tmp array index 5
# Page 4934/33000; a portion of slice 49/1000 to tmp array index 0
# Page 4935/33000; a portion of slice 49/1000 to tmp array index 1
# Page 4936/33000; a portion of slice 49/1000 to tmp array index 2
# Page 4937/33000; a portion of slice 49/1000 to tmp array index 3
# Page 4938/33000; a portion of slice 49/1000 to tmp array index 4
# Page 4939/33000; a portion of slice 49/1000 to tmp array index 5
# Page 4967/33000; a portion of slice 50/1000 to tmp array index 0
# Page 4968/33000; a portion of slice 50/1000 to tmp array index 1
# Page 4969/33000; a portion of slice 50/1000 to tmp array index 2
# Page 4970/33000; a portion of slice 50/1000 to tmp array index 3
# Page 4971/33000; a portion of slice 50/1000 to tmp array index 4
# Page 4972/33000; a portion of slice 50/1000 to tmp array index 5
# Page 5000/33000; a portion of slice 51/1000 to tmp array index 0
# Page 5001/33000; a portion of slice 51/1000 to tmp array index 1
# Page 5002/33000; a portion of slice 51/1000 to tmp array index 2
# Page 5003/33000; a portion of slice 51/1000 to tmp array index 3
# Page 5004/33000; a portion of slice 51/1000 to tmp array index 4
# Page 5005/33000; a portion of slice 51/1000 to tmp array index 5
# Page 5033/33000; a portion of slice 52/1000 to tmp array index 0
# Page 5034/33000; a portion of slice 52/1000 to tmp array index 1
# Page 5035/33000; a portion of slice 52/1000 to tmp array index 2
# Page 5036/33000; a portion of slice 52/1000 to tmp array index 3
# Page 5037/33000; a portion of slice 52/1000 to tmp array index 4
# Page 5038/33000; a portion of slice 52/1000 to tmp array index 5
# Page 5066/33000; a portion of slice 53/1000 to tmp array index 0
# Page 5067/33000; a portion of slice 53/1000 to tmp array index 1
# Page 5068/33000; a portion of slice 53/1000 to tmp array index 2
# Page 5069/33000; a portion of slice 53/1000 to tmp array index 3
# Page 5070/33000; a portion of slice 53/1000 to tmp array index 4
# Page 5071/33000; a portion of slice 53/1000 to tmp array index 5
# Page 5099/33000; a portion of slice 54/1000 to tmp array index 0
# Page 5100/33000; a portion of slice 54/1000 to tmp array index 1
# Page 5101/33000; a portion of slice 54/1000 to tmp array index 2
# Page 5102/33000; a portion of slice 54/1000 to tmp array index 3
# Page 5103/33000; a portion of slice 54/1000 to tmp array index 4
# Page 5104/33000; a portion of slice 54/1000 to tmp array index 5
# Page 5132/33000; a portion of slice 55/1000 to tmp array index 0
# Page 5133/33000; a portion of slice 55/1000 to tmp array index 1
# Page 5134/33000; a portion of slice 55/1000 to tmp array index 2
# Page 5135/33000; a portion of slice 55/1000 to tmp array index 3
# Page 5136/33000; a portion of slice 55/1000 to tmp array index 4
# Page 5137/33000; a portion of slice 55/1000 to tmp array index 5
# Page 5165/33000; a portion of slice 56/1000 to tmp array index 0
# Page 5166/33000; a portion of slice 56/1000 to tmp array index 1
# Page 5167/33000; a portion of slice 56/1000 to tmp array index 2
# Page 5168/33000; a portion of slice 56/1000 to tmp array index 3
# Page 5169/33000; a portion of slice 56/1000 to tmp array index 4
# Page 5170/33000; a portion of slice 56/1000 to tmp array index 5
# Page 5198/33000; a portion of slice 57/1000 to tmp array index 0
# Page 5199/33000; a portion of slice 57/1000 to tmp array index 1
# Page 5200/33000; a portion of slice 57/1000 to tmp array index 2
# Page 5201/33000; a portion of slice 57/1000 to tmp array index 3
# Page 5202/33000; a portion of slice 57/1000 to tmp array index 4
# Page 5203/33000; a portion of slice 57/1000 to tmp array index 5
# Page 5231/33000; a portion of slice 58/1000 to tmp array index 0
# Page 5232/33000; a portion of slice 58/1000 to tmp array index 1
# Page 5233/33000; a portion of slice 58/1000 to tmp array index 2
# Page 5234/33000; a portion of slice 58/1000 to tmp array index 3
# Page 5235/33000; a portion of slice 58/1000 to tmp array index 4
# Page 5236/33000; a portion of slice 58/1000 to tmp array index 5
# Page 5264/33000; a portion of slice 59/1000 to tmp array index 0
# Page 5265/33000; a portion of slice 59/1000 to tmp array index 1
# Page 5266/33000; a portion of slice 59/1000 to tmp array index 2
# Page 5267/33000; a portion of slice 59/1000 to tmp array index 3
# Page 5268/33000; a portion of slice 59/1000 to tmp array index 4
# Page 5269/33000; a portion of slice 59/1000 to tmp array index 5
# Page 5297/33000; a portion of slice 60/1000 to tmp array index 0
# Page 5298/33000; a portion of slice 60/1000 to tmp array index 1
# Page 5299/33000; a portion of slice 60/1000 to tmp array index 2
# Page 5300/33000; a portion of slice 60/1000 to tmp array index 3
# Page 5301/33000; a portion of slice 60/1000 to tmp array index 4
# Page 5302/33000; a portion of slice 60/1000 to tmp array index 5
# Page 5330/33000; a portion of slice 61/1000 to tmp array index 0
# Page 5331/33000; a portion of slice 61/1000 to tmp array index 1
# Page 5332/33000; a portion of slice 61/1000 to tmp array index 2
# Page 5333/33000; a portion of slice 61/1000 to tmp array index 3
# Page 5334/33000; a portion of slice 61/1000 to tmp array index 4
# Page 5335/33000; a portion of slice 61/1000 to tmp array index 5
# Page 5363/33000; a portion of slice 62/1000 to tmp array index 0
# Page 5364/33000; a portion of slice 62/1000 to tmp array index 1
# Page 5365/33000; a portion of slice 62/1000 to tmp array index 2
# Page 5366/33000; a portion of slice 62/1000 to tmp array index 3
# Page 5367/33000; a portion of slice 62/1000 to tmp array index 4
# Page 5368/33000; a portion of slice 62/1000 to tmp array index 5
# Page 5396/33000; a portion of slice 63/1000 to tmp array index 0
# Page 5397/33000; a portion of slice 63/1000 to tmp array index 1
# Page 5398/33000; a portion of slice 63/1000 to tmp array index 2
# Page 5399/33000; a portion of slice 63/1000 to tmp array index 3
# Page 5400/33000; a portion of slice 63/1000 to tmp array index 4
# Page 5401/33000; a portion of slice 63/1000 to tmp array index 5
# Page 5429/33000; a portion of slice 64/1000 to tmp array index 0
# Page 5430/33000; a portion of slice 64/1000 to tmp array index 1
# Page 5431/33000; a portion of slice 64/1000 to tmp array index 2
# Page 5432/33000; a portion of slice 64/1000 to tmp array index 3
# Page 5433/33000; a portion of slice 64/1000 to tmp array index 4
# Page 5434/33000; a portion of slice 64/1000 to tmp array index 5
# Page 5462/33000; a portion of slice 65/1000 to tmp array index 0
# Page 5463/33000; a portion of slice 65/1000 to tmp array index 1
# Page 5464/33000; a portion of slice 65/1000 to tmp array index 2
# Page 5465/33000; a portion of slice 65/1000 to tmp array index 3
# Page 5466/33000; a portion of slice 65/1000 to tmp array index 4
# Page 5467/33000; a portion of slice 65/1000 to tmp array index 5
# Page 5495/33000; a portion of slice 66/1000 to tmp array index 0
# Page 5496/33000; a portion of slice 66/1000 to tmp array index 1
# Page 5497/33000; a portion of slice 66/1000 to tmp array index 2
# Page 5498/33000; a portion of slice 66/1000 to tmp array index 3
# Page 5499/33000; a portion of slice 66/1000 to tmp array index 4
# Page 5500/33000; a portion of slice 66/1000 to tmp array index 5
# Page 5528/33000; a portion of slice 67/1000 to tmp array index 0
# Page 5529/33000; a portion of slice 67/1000 to tmp array index 1
# Page 5530/33000; a portion of slice 67/1000 to tmp array index 2
# Page 5531/33000; a portion of slice 67/1000 to tmp array index 3
# Page 5532/33000; a portion of slice 67/1000 to tmp array index 4
# Page 5533/33000; a portion of slice 67/1000 to tmp array index 5
# Page 5561/33000; a portion of slice 68/1000 to tmp array index 0
# Page 5562/33000; a portion of slice 68/1000 to tmp array index 1
# Page 5563/33000; a portion of slice 68/1000 to tmp array index 2
# Page 5564/33000; a portion of slice 68/1000 to tmp array index 3
# Page 5565/33000; a portion of slice 68/1000 to tmp array index 4
# Page 5566/33000; a portion of slice 68/1000 to tmp array index 5
# Page 5594/33000; a portion of slice 69/1000 to tmp array index 0
# Page 5595/33000; a portion of slice 69/1000 to tmp array index 1
# Page 5596/33000; a portion of slice 69/1000 to tmp array index 2
# Page 5597/33000; a portion of slice 69/1000 to tmp array index 3
# Page 5598/33000; a portion of slice 69/1000 to tmp array index 4
# Page 5599/33000; a portion of slice 69/1000 to tmp array index 5
# Page 5627/33000; a portion of slice 70/1000 to tmp array index 0
# Page 5628/33000; a portion of slice 70/1000 to tmp array index 1
# Page 5629/33000; a portion of slice 70/1000 to tmp array index 2
# Page 5630/33000; a portion of slice 70/1000 to tmp array index 3
# Page 5631/33000; a portion of slice 70/1000 to tmp array index 4
# Page 5632/33000; a portion of slice 70/1000 to tmp array index 5
# Page 5660/33000; a portion of slice 71/1000 to tmp array index 0
# Page 5661/33000; a portion of slice 71/1000 to tmp array index 1
# Page 5662/33000; a portion of slice 71/1000 to tmp array index 2
# Page 5663/33000; a portion of slice 71/1000 to tmp array index 3
# Page 5664/33000; a portion of slice 71/1000 to tmp array index 4
# Page 5665/33000; a portion of slice 71/1000 to tmp array index 5
# Page 5693/33000; a portion of slice 72/1000 to tmp array index 0
# Page 5694/33000; a portion of slice 72/1000 to tmp array index 1
# Page 5695/33000; a portion of slice 72/1000 to tmp array index 2
# Page 5696/33000; a portion of slice 72/1000 to tmp array index 3
# Page 5697/33000; a portion of slice 72/1000 to tmp array index 4
# Page 5698/33000; a portion of slice 72/1000 to tmp array index 5
# Page 5726/33000; a portion of slice 73/1000 to tmp array index 0
# Page 5727/33000; a portion of slice 73/1000 to tmp array index 1
# Page 5728/33000; a portion of slice 73/1000 to tmp array index 2
# Page 5729/33000; a portion of slice 73/1000 to tmp array index 3
# Page 5730/33000; a portion of slice 73/1000 to tmp array index 4
# Page 5731/33000; a portion of slice 73/1000 to tmp array index 5
# Page 5759/33000; a portion of slice 74/1000 to tmp array index 0
# Page 5760/33000; a portion of slice 74/1000 to tmp array index 1
# Page 5761/33000; a portion of slice 74/1000 to tmp array index 2
# Page 5762/33000; a portion of slice 74/1000 to tmp array index 3
# Page 5763/33000; a portion of slice 74/1000 to tmp array index 4
# Page 5764/33000; a portion of slice 74/1000 to tmp array index 5
# Page 5792/33000; a portion of slice 75/1000 to tmp array index 0
# Page 5793/33000; a portion of slice 75/1000 to tmp array index 1
# Page 5794/33000; a portion of slice 75/1000 to tmp array index 2
# Page 5795/33000; a portion of slice 75/1000 to tmp array index 3
# Page 5796/33000; a portion of slice 75/1000 to tmp array index 4
# Page 5797/33000; a portion of slice 75/1000 to tmp array index 5
# Page 5825/33000; a portion of slice 76/1000 to tmp array index 0
# Page 5826/33000; a portion of slice 76/1000 to tmp array index 1
# Page 5827/33000; a portion of slice 76/1000 to tmp array index 2
# Page 5828/33000; a portion of slice 76/1000 to tmp array index 3
# Page 5829/33000; a portion of slice 76/1000 to tmp array index 4
# Page 5830/33000; a portion of slice 76/1000 to tmp array index 5
# Page 5858/33000; a portion of slice 77/1000 to tmp array index 0
# Page 5859/33000; a portion of slice 77/1000 to tmp array index 1
# Page 5860/33000; a portion of slice 77/1000 to tmp array index 2
# Page 5861/33000; a portion of slice 77/1000 to tmp array index 3
# Page 5862/33000; a portion of slice 77/1000 to tmp array index 4
# Page 5863/33000; a portion of slice 77/1000 to tmp array index 5
# Page 5891/33000; a portion of slice 78/1000 to tmp array index 0
# Page 5892/33000; a portion of slice 78/1000 to tmp array index 1
# Page 5893/33000; a portion of slice 78/1000 to tmp array index 2
# Page 5894/33000; a portion of slice 78/1000 to tmp array index 3
# Page 5895/33000; a portion of slice 78/1000 to tmp array index 4
# Page 5896/33000; a portion of slice 78/1000 to tmp array index 5
# Page 5924/33000; a portion of slice 79/1000 to tmp array index 0
# Page 5925/33000; a portion of slice 79/1000 to tmp array index 1
# Page 5926/33000; a portion of slice 79/1000 to tmp array index 2
# Page 5927/33000; a portion of slice 79/1000 to tmp array index 3
# Page 5928/33000; a portion of slice 79/1000 to tmp array index 4
# Page 5929/33000; a portion of slice 79/1000 to tmp array index 5
# Page 5957/33000; a portion of slice 80/1000 to tmp array index 0
# Page 5958/33000; a portion of slice 80/1000 to tmp array index 1
# Page 5959/33000; a portion of slice 80/1000 to tmp array index 2
# Page 5960/33000; a portion of slice 80/1000 to tmp array index 3
# Page 5961/33000; a portion of slice 80/1000 to tmp array index 4
# Page 5962/33000; a portion of slice 80/1000 to tmp array index 5
# Page 5990/33000; a portion of slice 81/1000 to tmp array index 0
# Page 5991/33000; a portion of slice 81/1000 to tmp array index 1
# Page 5992/33000; a portion of slice 81/1000 to tmp array index 2
# Page 5993/33000; a portion of slice 81/1000 to tmp array index 3
# Page 5994/33000; a portion of slice 81/1000 to tmp array index 4
# Page 5995/33000; a portion of slice 81/1000 to tmp array index 5
# Page 6023/33000; a portion of slice 82/1000 to tmp array index 0
# Page 6024/33000; a portion of slice 82/1000 to tmp array index 1
# Page 6025/33000; a portion of slice 82/1000 to tmp array index 2
# Page 6026/33000; a portion of slice 82/1000 to tmp array index 3
# Page 6027/33000; a portion of slice 82/1000 to tmp array index 4
# Page 6028/33000; a portion of slice 82/1000 to tmp array index 5
# Page 6056/33000; a portion of slice 83/1000 to tmp array index 0
# Page 6057/33000; a portion of slice 83/1000 to tmp array index 1
# Page 6058/33000; a portion of slice 83/1000 to tmp array index 2
# Page 6059/33000; a portion of slice 83/1000 to tmp array index 3
# Page 6060/33000; a portion of slice 83/1000 to tmp array index 4
# Page 6061/33000; a portion of slice 83/1000 to tmp array index 5
# Page 6089/33000; a portion of slice 84/1000 to tmp array index 0
# Page 6090/33000; a portion of slice 84/1000 to tmp array index 1
# Page 6091/33000; a portion of slice 84/1000 to tmp array index 2
# Page 6092/33000; a portion of slice 84/1000 to tmp array index 3
# Page 6093/33000; a portion of slice 84/1000 to tmp array index 4
# Page 6094/33000; a portion of slice 84/1000 to tmp array index 5
# Page 6122/33000; a portion of slice 85/1000 to tmp array index 0
# Page 6123/33000; a portion of slice 85/1000 to tmp array index 1
# Page 6124/33000; a portion of slice 85/1000 to tmp array index 2
# Page 6125/33000; a portion of slice 85/1000 to tmp array index 3
# Page 6126/33000; a portion of slice 85/1000 to tmp array index 4
# Page 6127/33000; a portion of slice 85/1000 to tmp array index 5
# Page 6155/33000; a portion of slice 86/1000 to tmp array index 0
# Page 6156/33000; a portion of slice 86/1000 to tmp array index 1
# Page 6157/33000; a portion of slice 86/1000 to tmp array index 2
# Page 6158/33000; a portion of slice 86/1000 to tmp array index 3
# Page 6159/33000; a portion of slice 86/1000 to tmp array index 4
# Page 6160/33000; a portion of slice 86/1000 to tmp array index 5
# Page 6188/33000; a portion of slice 87/1000 to tmp array index 0
# Page 6189/33000; a portion of slice 87/1000 to tmp array index 1
# Page 6190/33000; a portion of slice 87/1000 to tmp array index 2
# Page 6191/33000; a portion of slice 87/1000 to tmp array index 3
# Page 6192/33000; a portion of slice 87/1000 to tmp array index 4
# Page 6193/33000; a portion of slice 87/1000 to tmp array index 5
# Page 6221/33000; a portion of slice 88/1000 to tmp array index 0
# Page 6222/33000; a portion of slice 88/1000 to tmp array index 1
# Page 6223/33000; a portion of slice 88/1000 to tmp array index 2
# Page 6224/33000; a portion of slice 88/1000 to tmp array index 3
# Page 6225/33000; a portion of slice 88/1000 to tmp array index 4
# Page 6226/33000; a portion of slice 88/1000 to tmp array index 5
# Page 6254/33000; a portion of slice 89/1000 to tmp array index 0
# Page 6255/33000; a portion of slice 89/1000 to tmp array index 1
# Page 6256/33000; a portion of slice 89/1000 to tmp array index 2
# Page 6257/33000; a portion of slice 89/1000 to tmp array index 3
# Page 6258/33000; a portion of slice 89/1000 to tmp array index 4
# Page 6259/33000; a portion of slice 89/1000 to tmp array index 5
# Page 6287/33000; a portion of slice 90/1000 to tmp array index 0
# Page 6288/33000; a portion of slice 90/1000 to tmp array index 1
# Page 6289/33000; a portion of slice 90/1000 to tmp array index 2
# Page 6290/33000; a portion of slice 90/1000 to tmp array index 3
# Page 6291/33000; a portion of slice 90/1000 to tmp array index 4
# Page 6292/33000; a portion of slice 90/1000 to tmp array index 5
# Page 6320/33000; a portion of slice 91/1000 to tmp array index 0
# Page 6321/33000; a portion of slice 91/1000 to tmp array index 1
# Page 6322/33000; a portion of slice 91/1000 to tmp array index 2
# Page 6323/33000; a portion of slice 91/1000 to tmp array index 3
# Page 6324/33000; a portion of slice 91/1000 to tmp array index 4
# Page 6325/33000; a portion of slice 91/1000 to tmp array index 5
# Page 6353/33000; a portion of slice 92/1000 to tmp array index 0
# Page 6354/33000; a portion of slice 92/1000 to tmp array index 1
# Page 6355/33000; a portion of slice 92/1000 to tmp array index 2
# Page 6356/33000; a portion of slice 92/1000 to tmp array index 3
# Page 6357/33000; a portion of slice 92/1000 to tmp array index 4
# Page 6358/33000; a portion of slice 92/1000 to tmp array index 5
# Page 6386/33000; a portion of slice 93/1000 to tmp array index 0
# Page 6387/33000; a portion of slice 93/1000 to tmp array index 1
# Page 6388/33000; a portion of slice 93/1000 to tmp array index 2
# Page 6389/33000; a portion of slice 93/1000 to tmp array index 3
# Page 6390/33000; a portion of slice 93/1000 to tmp array index 4
# Page 6391/33000; a portion of slice 93/1000 to tmp array index 5
# Page 6419/33000; a portion of slice 94/1000 to tmp array index 0
# Page 6420/33000; a portion of slice 94/1000 to tmp array index 1
# Page 6421/33000; a portion of slice 94/1000 to tmp array index 2
# Page 6422/33000; a portion of slice 94/1000 to tmp array index 3
# Page 6423/33000; a portion of slice 94/1000 to tmp array index 4
# Page 6424/33000; a portion of slice 94/1000 to tmp array index 5
# Page 6452/33000; a portion of slice 95/1000 to tmp array index 0
# Page 6453/33000; a portion of slice 95/1000 to tmp array index 1
# Page 6454/33000; a portion of slice 95/1000 to tmp array index 2
# Page 6455/33000; a portion of slice 95/1000 to tmp array index 3
# Page 6456/33000; a portion of slice 95/1000 to tmp array index 4
# Page 6457/33000; a portion of slice 95/1000 to tmp array index 5
# Page 6485/33000; a portion of slice 96/1000 to tmp array index 0
# Page 6486/33000; a portion of slice 96/1000 to tmp array index 1
# Page 6487/33000; a portion of slice 96/1000 to tmp array index 2
# Page 6488/33000; a portion of slice 96/1000 to tmp array index 3
# Page 6489/33000; a portion of slice 96/1000 to tmp array index 4
# Page 6490/33000; a portion of slice 96/1000 to tmp array index 5
# Page 6518/33000; a portion of slice 97/1000 to tmp array index 0
# Page 6519/33000; a portion of slice 97/1000 to tmp array index 1
# Page 6520/33000; a portion of slice 97/1000 to tmp array index 2
# Page 6521/33000; a portion of slice 97/1000 to tmp array index 3
# Page 6522/33000; a portion of slice 97/1000 to tmp array index 4
# Page 6523/33000; a portion of slice 97/1000 to tmp array index 5
# Page 6551/33000; a portion of slice 98/1000 to tmp array index 0
# Page 6552/33000; a portion of slice 98/1000 to tmp array index 1
# Page 6553/33000; a portion of slice 98/1000 to tmp array index 2
# Page 6554/33000; a portion of slice 98/1000 to tmp array index 3
# Page 6555/33000; a portion of slice 98/1000 to tmp array index 4
# Page 6556/33000; a portion of slice 98/1000 to tmp array index 5
# Page 6584/33000; a portion of slice 99/1000 to tmp array index 0
# Page 6585/33000; a portion of slice 99/1000 to tmp array index 1
# Page 6586/33000; a portion of slice 99/1000 to tmp array index 2
# Page 6587/33000; a portion of slice 99/1000 to tmp array index 3
# Page 6588/33000; a portion of slice 99/1000 to tmp array index 4
# Page 6589/33000; a portion of slice 99/1000 to tmp array index 5
# Page 6617/33000; a portion of slice 100/1000 to tmp array index 0
# Page 6618/33000; a portion of slice 100/1000 to tmp array index 1
# Page 6619/33000; a portion of slice 100/1000 to tmp array index 2
# Page 6620/33000; a portion of slice 100/1000 to tmp array index 3
# Page 6621/33000; a portion of slice 100/1000 to tmp array index 4
# Page 6622/33000; a portion of slice 100/1000 to tmp array index 5
# Page 6650/33000; a portion of slice 101/1000 to tmp array index 0
# Page 6651/33000; a portion of slice 101/1000 to tmp array index 1
# Page 6652/33000; a portion of slice 101/1000 to tmp array index 2
# Page 6653/33000; a portion of slice 101/1000 to tmp array index 3
# Page 6654/33000; a portion of slice 101/1000 to tmp array index 4
# Page 6655/33000; a portion of slice 101/1000 to tmp array index 5
# Page 6683/33000; a portion of slice 102/1000 to tmp array index 0
# Page 6684/33000; a portion of slice 102/1000 to tmp array index 1
# Page 6685/33000; a portion of slice 102/1000 to tmp array index 2
# Page 6686/33000; a portion of slice 102/1000 to tmp array index 3
# Page 6687/33000; a portion of slice 102/1000 to tmp array index 4
# Page 6688/33000; a portion of slice 102/1000 to tmp array index 5
# Page 6716/33000; a portion of slice 103/1000 to tmp array index 0
# Page 6717/33000; a portion of slice 103/1000 to tmp array index 1
# Page 6718/33000; a portion of slice 103/1000 to tmp array index 2
# Page 6719/33000; a portion of slice 103/1000 to tmp array index 3
# Page 6720/33000; a portion of slice 103/1000 to tmp array index 4
# Page 6721/33000; a portion of slice 103/1000 to tmp array index 5
# Page 6749/33000; a portion of slice 104/1000 to tmp array index 0
# Page 6750/33000; a portion of slice 104/1000 to tmp array index 1
# Page 6751/33000; a portion of slice 104/1000 to tmp array index 2
# Page 6752/33000; a portion of slice 104/1000 to tmp array index 3
# Page 6753/33000; a portion of slice 104/1000 to tmp array index 4
# Page 6754/33000; a portion of slice 104/1000 to tmp array index 5
# Page 6782/33000; a portion of slice 105/1000 to tmp array index 0
# Page 6783/33000; a portion of slice 105/1000 to tmp array index 1
# Page 6784/33000; a portion of slice 105/1000 to tmp array index 2
# Page 6785/33000; a portion of slice 105/1000 to tmp array index 3
# Page 6786/33000; a portion of slice 105/1000 to tmp array index 4
# Page 6787/33000; a portion of slice 105/1000 to tmp array index 5
# Page 6815/33000; a portion of slice 106/1000 to tmp array index 0
# Page 6816/33000; a portion of slice 106/1000 to tmp array index 1
# Page 6817/33000; a portion of slice 106/1000 to tmp array index 2
# Page 6818/33000; a portion of slice 106/1000 to tmp array index 3
# Page 6819/33000; a portion of slice 106/1000 to tmp array index 4
# Page 6820/33000; a portion of slice 106/1000 to tmp array index 5
# Page 6848/33000; a portion of slice 107/1000 to tmp array index 0
# Page 6849/33000; a portion of slice 107/1000 to tmp array index 1
# Page 6850/33000; a portion of slice 107/1000 to tmp array index 2
# Page 6851/33000; a portion of slice 107/1000 to tmp array index 3
# Page 6852/33000; a portion of slice 107/1000 to tmp array index 4
# Page 6853/33000; a portion of slice 107/1000 to tmp array index 5
# Page 6881/33000; a portion of slice 108/1000 to tmp array index 0
# Page 6882/33000; a portion of slice 108/1000 to tmp array index 1
# Page 6883/33000; a portion of slice 108/1000 to tmp array index 2
# Page 6884/33000; a portion of slice 108/1000 to tmp array index 3
# Page 6885/33000; a portion of slice 108/1000 to tmp array index 4
# Page 6886/33000; a portion of slice 108/1000 to tmp array index 5
# Page 6914/33000; a portion of slice 109/1000 to tmp array index 0
# Page 6915/33000; a portion of slice 109/1000 to tmp array index 1
# Page 6916/33000; a portion of slice 109/1000 to tmp array index 2
# Page 6917/33000; a portion of slice 109/1000 to tmp array index 3
# Page 6918/33000; a portion of slice 109/1000 to tmp array index 4
# Page 6919/33000; a portion of slice 109/1000 to tmp array index 5
# Page 6947/33000; a portion of slice 110/1000 to tmp array index 0
# Page 6948/33000; a portion of slice 110/1000 to tmp array index 1
# Page 6949/33000; a portion of slice 110/1000 to tmp array index 2
# Page 6950/33000; a portion of slice 110/1000 to tmp array index 3
# Page 6951/33000; a portion of slice 110/1000 to tmp array index 4
# Page 6952/33000; a portion of slice 110/1000 to tmp array index 5
# Page 6980/33000; a portion of slice 111/1000 to tmp array index 0
# Page 6981/33000; a portion of slice 111/1000 to tmp array index 1
# Page 6982/33000; a portion of slice 111/1000 to tmp array index 2
# Page 6983/33000; a portion of slice 111/1000 to tmp array index 3
# Page 6984/33000; a portion of slice 111/1000 to tmp array index 4
# Page 6985/33000; a portion of slice 111/1000 to tmp array index 5
# Page 7013/33000; a portion of slice 112/1000 to tmp array index 0
# Page 7014/33000; a portion of slice 112/1000 to tmp array index 1
# Page 7015/33000; a portion of slice 112/1000 to tmp array index 2
# Page 7016/33000; a portion of slice 112/1000 to tmp array index 3
# Page 7017/33000; a portion of slice 112/1000 to tmp array index 4
# Page 7018/33000; a portion of slice 112/1000 to tmp array index 5
# Page 7046/33000; a portion of slice 113/1000 to tmp array index 0
# Page 7047/33000; a portion of slice 113/1000 to tmp array index 1
# Page 7048/33000; a portion of slice 113/1000 to tmp array index 2
# Page 7049/33000; a portion of slice 113/1000 to tmp array index 3
# Page 7050/33000; a portion of slice 113/1000 to tmp array index 4
# Page 7051/33000; a portion of slice 113/1000 to tmp array index 5
# Page 7079/33000; a portion of slice 114/1000 to tmp array index 0
# Page 7080/33000; a portion of slice 114/1000 to tmp array index 1
# Page 7081/33000; a portion of slice 114/1000 to tmp array index 2
# Page 7082/33000; a portion of slice 114/1000 to tmp array index 3
# Page 7083/33000; a portion of slice 114/1000 to tmp array index 4
# Page 7084/33000; a portion of slice 114/1000 to tmp array index 5
# Page 7112/33000; a portion of slice 115/1000 to tmp array index 0
# Page 7113/33000; a portion of slice 115/1000 to tmp array index 1
# Page 7114/33000; a portion of slice 115/1000 to tmp array index 2
# Page 7115/33000; a portion of slice 115/1000 to tmp array index 3
# Page 7116/33000; a portion of slice 115/1000 to tmp array index 4
# Page 7117/33000; a portion of slice 115/1000 to tmp array index 5
# Page 7145/33000; a portion of slice 116/1000 to tmp array index 0
# Page 7146/33000; a portion of slice 116/1000 to tmp array index 1
# Page 7147/33000; a portion of slice 116/1000 to tmp array index 2
# Page 7148/33000; a portion of slice 116/1000 to tmp array index 3
# Page 7149/33000; a portion of slice 116/1000 to tmp array index 4
# Page 7150/33000; a portion of slice 116/1000 to tmp array index 5
# Page 7178/33000; a portion of slice 117/1000 to tmp array index 0
# Page 7179/33000; a portion of slice 117/1000 to tmp array index 1
# Page 7180/33000; a portion of slice 117/1000 to tmp array index 2
# Page 7181/33000; a portion of slice 117/1000 to tmp array index 3
# Page 7182/33000; a portion of slice 117/1000 to tmp array index 4
# Page 7183/33000; a portion of slice 117/1000 to tmp array index 5
# Page 7211/33000; a portion of slice 118/1000 to tmp array index 0
# Page 7212/33000; a portion of slice 118/1000 to tmp array index 1
# Page 7213/33000; a portion of slice 118/1000 to tmp array index 2
# Page 7214/33000; a portion of slice 118/1000 to tmp array index 3
# Page 7215/33000; a portion of slice 118/1000 to tmp array index 4
# Page 7216/33000; a portion of slice 118/1000 to tmp array index 5
# Page 7244/33000; a portion of slice 119/1000 to tmp array index 0
# Page 7245/33000; a portion of slice 119/1000 to tmp array index 1
# Page 7246/33000; a portion of slice 119/1000 to tmp array index 2
# Page 7247/33000; a portion of slice 119/1000 to tmp array index 3
# Page 7248/33000; a portion of slice 119/1000 to tmp array index 4
# Page 7249/33000; a portion of slice 119/1000 to tmp array index 5
# Page 7277/33000; a portion of slice 120/1000 to tmp array index 0
# Page 7278/33000; a portion of slice 120/1000 to tmp array index 1
# Page 7279/33000; a portion of slice 120/1000 to tmp array index 2
# Page 7280/33000; a portion of slice 120/1000 to tmp array index 3
# Page 7281/33000; a portion of slice 120/1000 to tmp array index 4
# Page 7282/33000; a portion of slice 120/1000 to tmp array index 5
# Page 7310/33000; a portion of slice 121/1000 to tmp array index 0
# Page 7311/33000; a portion of slice 121/1000 to tmp array index 1
# Page 7312/33000; a portion of slice 121/1000 to tmp array index 2
# Page 7313/33000; a portion of slice 121/1000 to tmp array index 3
# Page 7314/33000; a portion of slice 121/1000 to tmp array index 4
# Page 7315/33000; a portion of slice 121/1000 to tmp array index 5
# Page 7343/33000; a portion of slice 122/1000 to tmp array index 0
# Page 7344/33000; a portion of slice 122/1000 to tmp array index 1
# Page 7345/33000; a portion of slice 122/1000 to tmp array index 2
# ...
# Page 35032/33000; a portion of slice 961/1000 to tmp array index 2
# Page 35033/33000; a portion of slice 961/1000 to tmp array index 3
# Page 35034/33000; a portion of slice 961/1000 to tmp array index 4
# Page 35035/33000; a portion of slice 961/1000 to tmp array index 5
# Page 35063/33000; a portion of slice 962/1000 to tmp array index 0
# Page 35064/33000; a portion of slice 962/1000 to tmp array index 1
# Page 35065/33000; a portion of slice 962/1000 to tmp array index 2
# Page 35066/33000; a portion of slice 962/1000 to tmp array index 3
# Page 35067/33000; a portion of slice 962/1000 to tmp array index 4
# Page 35068/33000; a portion of slice 962/1000 to tmp array index 5
# Page 35096/33000; a portion of slice 963/1000 to tmp array index 0
# Page 35097/33000; a portion of slice 963/1000 to tmp array index 1
# Page 35098/33000; a portion of slice 963/1000 to tmp array index 2
# Page 35099/33000; a portion of slice 963/1000 to tmp array index 3
# Page 35100/33000; a portion of slice 963/1000 to tmp array index 4
# Page 35101/33000; a portion of slice 963/1000 to tmp array index 5
# Page 35129/33000; a portion of slice 964/1000 to tmp array index 0
# Page 35130/33000; a portion of slice 964/1000 to tmp array index 1
# Page 35131/33000; a portion of slice 964/1000 to tmp array index 2
# Page 35132/33000; a portion of slice 964/1000 to tmp array index 3
# Page 35133/33000; a portion of slice 964/1000 to tmp array index 4
# Page 35134/33000; a portion of slice 964/1000 to tmp array index 5
# Page 35162/33000; a portion of slice 965/1000 to tmp array index 0
# Page 35163/33000; a portion of slice 965/1000 to tmp array index 1
# Page 35164/33000; a portion of slice 965/1000 to tmp array index 2
# Page 35165/33000; a portion of slice 965/1000 to tmp array index 3
# Page 35166/33000; a portion of slice 965/1000 to tmp array index 4
# Page 35167/33000; a portion of slice 965/1000 to tmp array index 5
# Page 35195/33000; a portion of slice 966/1000 to tmp array index 0
# Page 35196/33000; a portion of slice 966/1000 to tmp array index 1
# Page 35197/33000; a portion of slice 966/1000 to tmp array index 2
# Page 35198/33000; a portion of slice 966/1000 to tmp array index 3
# Page 35199/33000; a portion of slice 966/1000 to tmp array index 4
# Page 35200/33000; a portion of slice 966/1000 to tmp array index 5
# Page 35228/33000; a portion of slice 967/1000 to tmp array index 0
# Page 35229/33000; a portion of slice 967/1000 to tmp array index 1
# Page 35230/33000; a portion of slice 967/1000 to tmp array index 2
# Page 35231/33000; a portion of slice 967/1000 to tmp array index 3
# Page 35232/33000; a portion of slice 967/1000 to tmp array index 4
# Page 35233/33000; a portion of slice 967/1000 to tmp array index 5
# Page 35261/33000; a portion of slice 968/1000 to tmp array index 0
# Page 35262/33000; a portion of slice 968/1000 to tmp array index 1
# Page 35263/33000; a portion of slice 968/1000 to tmp array index 2
# Page 35264/33000; a portion of slice 968/1000 to tmp array index 3
# Page 35265/33000; a portion of slice 968/1000 to tmp array index 4
# Page 35266/33000; a portion of slice 968/1000 to tmp array index 5
# Page 35294/33000; a portion of slice 969/1000 to tmp array index 0
# Page 35295/33000; a portion of slice 969/1000 to tmp array index 1
# Page 35296/33000; a portion of slice 969/1000 to tmp array index 2
# Page 35297/33000; a portion of slice 969/1000 to tmp array index 3
# Page 35298/33000; a portion of slice 969/1000 to tmp array index 4
# Page 35299/33000; a portion of slice 969/1000 to tmp array index 5
# Page 35327/33000; a portion of slice 970/1000 to tmp array index 0
# Page 35328/33000; a portion of slice 970/1000 to tmp array index 1
# Page 35329/33000; a portion of slice 970/1000 to tmp array index 2
# Page 35330/33000; a portion of slice 970/1000 to tmp array index 3
# Page 35331/33000; a portion of slice 970/1000 to tmp array index 4
# Page 35332/33000; a portion of slice 970/1000 to tmp array index 5
# Page 35360/33000; a portion of slice 971/1000 to tmp array index 0
# Page 35361/33000; a portion of slice 971/1000 to tmp array index 1
# Page 35362/33000; a portion of slice 971/1000 to tmp array index 2
# Page 35363/33000; a portion of slice 971/1000 to tmp array index 3
# Page 35364/33000; a portion of slice 971/1000 to tmp array index 4
# Page 35365/33000; a portion of slice 971/1000 to tmp array index 5
# Page 35393/33000; a portion of slice 972/1000 to tmp array index 0
# Page 35394/33000; a portion of slice 972/1000 to tmp array index 1
# Page 35395/33000; a portion of slice 972/1000 to tmp array index 2
# Page 35396/33000; a portion of slice 972/1000 to tmp array index 3
# Page 35397/33000; a portion of slice 972/1000 to tmp array index 4
# Page 35398/33000; a portion of slice 972/1000 to tmp array index 5
# Page 35426/33000; a portion of slice 973/1000 to tmp array index 0
# Page 35427/33000; a portion of slice 973/1000 to tmp array index 1
# Page 35428/33000; a portion of slice 973/1000 to tmp array index 2
# Page 35429/33000; a portion of slice 973/1000 to tmp array index 3
# Page 35430/33000; a portion of slice 973/1000 to tmp array index 4
# Page 35431/33000; a portion of slice 973/1000 to tmp array index 5
# Page 35459/33000; a portion of slice 974/1000 to tmp array index 0
# Page 35460/33000; a portion of slice 974/1000 to tmp array index 1
# Page 35461/33000; a portion of slice 974/1000 to tmp array index 2
# Page 35462/33000; a portion of slice 974/1000 to tmp array index 3
# Page 35463/33000; a portion of slice 974/1000 to tmp array index 4
# Page 35464/33000; a portion of slice 974/1000 to tmp array index 5
# Page 35492/33000; a portion of slice 975/1000 to tmp array index 0
# Page 35493/33000; a portion of slice 975/1000 to tmp array index 1
# Page 35494/33000; a portion of slice 975/1000 to tmp array index 2
# Page 35495/33000; a portion of slice 975/1000 to tmp array index 3
# Page 35496/33000; a portion of slice 975/1000 to tmp array index 4
# Page 35497/33000; a portion of slice 975/1000 to tmp array index 5
# Page 35525/33000; a portion of slice 976/1000 to tmp array index 0
# Page 35526/33000; a portion of slice 976/1000 to tmp array index 1
# Page 35527/33000; a portion of slice 976/1000 to tmp array index 2
# Page 35528/33000; a portion of slice 976/1000 to tmp array index 3
# Page 35529/33000; a portion of slice 976/1000 to tmp array index 4
# Page 35530/33000; a portion of slice 976/1000 to tmp array index 5
# Page 35558/33000; a portion of slice 977/1000 to tmp array index 0
# Page 35559/33000; a portion of slice 977/1000 to tmp array index 1
# Page 35560/33000; a portion of slice 977/1000 to tmp array index 2
# Page 35561/33000; a portion of slice 977/1000 to tmp array index 3
# Page 35562/33000; a portion of slice 977/1000 to tmp array index 4
# Page 35563/33000; a portion of slice 977/1000 to tmp array index 5
# Page 35591/33000; a portion of slice 978/1000 to tmp array index 0
# Page 35592/33000; a portion of slice 978/1000 to tmp array index 1
# Page 35593/33000; a portion of slice 978/1000 to tmp array index 2
# Page 35594/33000; a portion of slice 978/1000 to tmp array index 3
# Page 35595/33000; a portion of slice 978/1000 to tmp array index 4
# Page 35596/33000; a portion of slice 978/1000 to tmp array index 5
# Page 35624/33000; a portion of slice 979/1000 to tmp array index 0
# Page 35625/33000; a portion of slice 979/1000 to tmp array index 1
# Page 35626/33000; a portion of slice 979/1000 to tmp array index 2
# Page 35627/33000; a portion of slice 979/1000 to tmp array index 3
# Page 35628/33000; a portion of slice 979/1000 to tmp array index 4
# Page 35629/33000; a portion of slice 979/1000 to tmp array index 5
# Page 35657/33000; a portion of slice 980/1000 to tmp array index 0
# Page 35658/33000; a portion of slice 980/1000 to tmp array index 1
# Page 35659/33000; a portion of slice 980/1000 to tmp array index 2
# Page 35660/33000; a portion of slice 980/1000 to tmp array index 3
# Page 35661/33000; a portion of slice 980/1000 to tmp array index 4
# Page 35662/33000; a portion of slice 980/1000 to tmp array index 5
# Page 35690/33000; a portion of slice 981/1000 to tmp array index 0
# Page 35691/33000; a portion of slice 981/1000 to tmp array index 1
# Page 35692/33000; a portion of slice 981/1000 to tmp array index 2
# Page 35693/33000; a portion of slice 981/1000 to tmp array index 3
# Page 35694/33000; a portion of slice 981/1000 to tmp array index 4
# Page 35695/33000; a portion of slice 981/1000 to tmp array index 5
# Page 35723/33000; a portion of slice 982/1000 to tmp array index 0
# Page 35724/33000; a portion of slice 982/1000 to tmp array index 1
# Page 35725/33000; a portion of slice 982/1000 to tmp array index 2
# Page 35726/33000; a portion of slice 982/1000 to tmp array index 3
# Page 35727/33000; a portion of slice 982/1000 to tmp array index 4
# Page 35728/33000; a portion of slice 982/1000 to tmp array index 5
# Page 35756/33000; a portion of slice 983/1000 to tmp array index 0
# Page 35757/33000; a portion of slice 983/1000 to tmp array index 1
# Page 35758/33000; a portion of slice 983/1000 to tmp array index 2
# Page 35759/33000; a portion of slice 983/1000 to tmp array index 3
# Page 35760/33000; a portion of slice 983/1000 to tmp array index 4
# Page 35761/33000; a portion of slice 983/1000 to tmp array index 5
# Page 35789/33000; a portion of slice 984/1000 to tmp array index 0
# Page 35790/33000; a portion of slice 984/1000 to tmp array index 1
# Page 35791/33000; a portion of slice 984/1000 to tmp array index 2
# Page 35792/33000; a portion of slice 984/1000 to tmp array index 3
# Page 35793/33000; a portion of slice 984/1000 to tmp array index 4
# Page 35794/33000; a portion of slice 984/1000 to tmp array index 5
# Page 35822/33000; a portion of slice 985/1000 to tmp array index 0
# Page 35823/33000; a portion of slice 985/1000 to tmp array index 1
# Page 35824/33000; a portion of slice 985/1000 to tmp array index 2
# Page 35825/33000; a portion of slice 985/1000 to tmp array index 3
# Page 35826/33000; a portion of slice 985/1000 to tmp array index 4
# Page 35827/33000; a portion of slice 985/1000 to tmp array index 5
# Page 35855/33000; a portion of slice 986/1000 to tmp array index 0
# Page 35856/33000; a portion of slice 986/1000 to tmp array index 1
# Page 35857/33000; a portion of slice 986/1000 to tmp array index 2
# Page 35858/33000; a portion of slice 986/1000 to tmp array index 3
# Page 35859/33000; a portion of slice 986/1000 to tmp array index 4
# Page 35860/33000; a portion of slice 986/1000 to tmp array index 5
# Page 35888/33000; a portion of slice 987/1000 to tmp array index 0
# Page 35889/33000; a portion of slice 987/1000 to tmp array index 1
# Page 35890/33000; a portion of slice 987/1000 to tmp array index 2
# Page 35891/33000; a portion of slice 987/1000 to tmp array index 3
# Page 35892/33000; a portion of slice 987/1000 to tmp array index 4
# Page 35893/33000; a portion of slice 987/1000 to tmp array index 5
# Page 35921/33000; a portion of slice 988/1000 to tmp array index 0
# Page 35922/33000; a portion of slice 988/1000 to tmp array index 1
# Page 35923/33000; a portion of slice 988/1000 to tmp array index 2
# Page 35924/33000; a portion of slice 988/1000 to tmp array index 3
# Page 35925/33000; a portion of slice 988/1000 to tmp array index 4
# Page 35926/33000; a portion of slice 988/1000 to tmp array index 5
# Page 35954/33000; a portion of slice 989/1000 to tmp array index 0
# Page 35955/33000; a portion of slice 989/1000 to tmp array index 1
# Page 35956/33000; a portion of slice 989/1000 to tmp array index 2
# Page 35957/33000; a portion of slice 989/1000 to tmp array index 3
# Page 35958/33000; a portion of slice 989/1000 to tmp array index 4
# Page 35959/33000; a portion of slice 989/1000 to tmp array index 5
# Page 35987/33000; a portion of slice 990/1000 to tmp array index 0
# Page 35988/33000; a portion of slice 990/1000 to tmp array index 1
# Page 35989/33000; a portion of slice 990/1000 to tmp array index 2
# Page 35990/33000; a portion of slice 990/1000 to tmp array index 3
# Page 35991/33000; a portion of slice 990/1000 to tmp array index 4
# Page 35992/33000; a portion of slice 990/1000 to tmp array index 5
# Page 36020/33000; a portion of slice 991/1000 to tmp array index 0
# Page 36021/33000; a portion of slice 991/1000 to tmp array index 1
# Page 36022/33000; a portion of slice 991/1000 to tmp array index 2
# Page 36023/33000; a portion of slice 991/1000 to tmp array index 3
# Page 36024/33000; a portion of slice 991/1000 to tmp array index 4
# Page 36025/33000; a portion of slice 991/1000 to tmp array index 5
# Page 36053/33000; a portion of slice 992/1000 to tmp array index 0
# Page 36054/33000; a portion of slice 992/1000 to tmp array index 1
# Page 36055/33000; a portion of slice 992/1000 to tmp array index 2
# Page 36056/33000; a portion of slice 992/1000 to tmp array index 3
# Page 36057/33000; a portion of slice 992/1000 to tmp array index 4
# Page 36058/33000; a portion of slice 992/1000 to tmp array index 5
# Page 36086/33000; a portion of slice 993/1000 to tmp array index 0
# Page 36087/33000; a portion of slice 993/1000 to tmp array index 1
# Page 36088/33000; a portion of slice 993/1000 to tmp array index 2
# Page 36089/33000; a portion of slice 993/1000 to tmp array index 3
# Page 36090/33000; a portion of slice 993/1000 to tmp array index 4
# Page 36091/33000; a portion of slice 993/1000 to tmp array index 5
# Page 36119/33000; a portion of slice 994/1000 to tmp array index 0
# Page 36120/33000; a portion of slice 994/1000 to tmp array index 1
# Page 36121/33000; a portion of slice 994/1000 to tmp array index 2
# Page 36122/33000; a portion of slice 994/1000 to tmp array index 3
# Page 36123/33000; a portion of slice 994/1000 to tmp array index 4
# Page 36124/33000; a portion of slice 994/1000 to tmp array index 5
# Page 36152/33000; a portion of slice 995/1000 to tmp array index 0
# Page 36153/33000; a portion of slice 995/1000 to tmp array index 1
# Page 36154/33000; a portion of slice 995/1000 to tmp array index 2
# Page 36155/33000; a portion of slice 995/1000 to tmp array index 3
# Page 36156/33000; a portion of slice 995/1000 to tmp array index 4
# Page 36157/33000; a portion of slice 995/1000 to tmp array index 5
# Page 36185/33000; a portion of slice 996/1000 to tmp array index 0
# Page 36186/33000; a portion of slice 996/1000 to tmp array index 1
# Page 36187/33000; a portion of slice 996/1000 to tmp array index 2
# Page 36188/33000; a portion of slice 996/1000 to tmp array index 3
# Page 36189/33000; a portion of slice 996/1000 to tmp array index 4
# Page 36190/33000; a portion of slice 996/1000 to tmp array index 5
# Page 36218/33000; a portion of slice 997/1000 to tmp array index 0
# Page 36219/33000; a portion of slice 997/1000 to tmp array index 1
# Page 36220/33000; a portion of slice 997/1000 to tmp array index 2
# Page 36221/33000; a portion of slice 997/1000 to tmp array index 3
# Page 36222/33000; a portion of slice 997/1000 to tmp array index 4
# Page 36223/33000; a portion of slice 997/1000 to tmp array index 5
# Page 36251/33000; a portion of slice 998/1000 to tmp array index 0
# Page 36252/33000; a portion of slice 998/1000 to tmp array index 1
# Page 36253/33000; a portion of slice 998/1000 to tmp array index 2
# Page 36254/33000; a portion of slice 998/1000 to tmp array index 3
# Page 36255/33000; a portion of slice 998/1000 to tmp array index 4
# Page 36256/33000; a portion of slice 998/1000 to tmp array index 5
# Page 36284/33000; a portion of slice 999/1000 to tmp array index 0
# Page 36285/33000; a portion of slice 999/1000 to tmp array index 1
# Page 36286/33000; a portion of slice 999/1000 to tmp array index 2
# Page 36287/33000; a portion of slice 999/1000 to tmp array index 3
# Page 36288/33000; a portion of slice 999/1000 to tmp array index 4
# Page 36289/33000; a portion of slice 999/1000 to tmp array index 5
# Page 36317/33000; a portion of slice 1000/1000 to tmp array index 0
# Page 36318/33000; a portion of slice 1000/1000 to tmp array index 1
# Page 36319/33000; a portion of slice 1000/1000 to tmp array index 2
# Page 36320/33000; a portion of slice 1000/1000 to tmp array index 3
# Page 36321/33000; a portion of slice 1000/1000 to tmp array index 4
# Page 36322/33000; a portion of slice 1000/1000 to tmp array index 5

# %% [markdown]
# # Now, Make a DLC project folder and prep for annotations

# %% [markdown]
# ## Create a project and copy the mcherry from above

# %%
# %env DLClight=True
import deeplabcut
import os
# Out:
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# mcherry video, which will be tracked
if os.name == 'nt':
    video_foldername = 'Y:\\shared_projects\\wbfm\\dat\\short_wbfm_z_stabilized'
else:
    video_foldername = '/users/charles.fieseler/shared_projects/wbfm/dat/short_wbfm_z_stabilized/'
    '202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1_bigtiff_mcherry_frames1000_slice17_22'
fname = f'202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1_bigtiff_mcherry_frames{num_frames}_slice{which_slices[0]}_{which_slices[-1]}.avi'
video_fname = os.path.join(video_foldername, fname)

# %%
if os.name == 'nt':
    project_foldername = 'C:\\Users\\charles.fieseler\\Documents\\Current_work\\DLC_for_WBFM\\DLC_Projects'
else:
    raise Exception
# fname = '202009282020-09-28_17-30-28_worm4_chemotaxis-channel-1-pco_camera2bigtiff.btf'
# input_fname = os.path.join(input_foldername, fname)
#     project_foldername = '/groups/zimmer/Ulises/wbfm/20200924and28/202009282020-09-28_17-30-28_worm4_chemotaxis-channel-1-pco_camera2/'

task = 'wbfm_3d_annotation_test'
experimenter = 'Charlie'

# %%
path_config_file = deeplabcut.create_new_project(task,experimenter,videos=[video_fname],copy_videos=True,working_directory=project_foldername)
# Out:
# Created "C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\videos"
# Created "C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\labeled-data"
# Created "C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\training-datasets"
# Created "C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\dlc-models"
# Copying the videos
# C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\videos\202009282020-09-28_17-30-28_worm4_chemotaxis-channel-0-pco_camera1_bigtiff_mcherry_frames1000_slice17_22.avi
# Generated "C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\config.yaml"
#
# A new project with name wbfm_3d_annotation_test-Charlie-2020-10-21 is created at C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects and a configurable file (config.yaml) is stored there. Change the parameters in this file to adapt to your project's needs.
#  Once you have changed the configuration file, use the function 'extract_frames' to select frames for labeling.
# . [OPTIONAL] Use the function 'add_new_videos' to add new videos to your project (at any stage).

# %% [markdown]
# ## Extract individual volumes to be annotated

# %%
import deeplabcut
from DLC_for_WBFM.utils.preprocessing.custom_frame_extraction import *
# Out:
# Bad key savefig.frameon in file C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.1/matplotlibrc.template
# or from the matplotlib source distribution
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\charles.fieseler\Anaconda3\envs\DLC-preprocessing\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Get a couple volumes to annotate
num_training_volumes = 5
which_volumes = list(range(start_volume, start_volume + num_training_volumes))

# Take the entire z stack
which_slice = None
nz = 33

# %%
project_folder = 'C:\\Users\\charles.fieseler\\Documents\\Current_work\\DLC_for_WBFM\\DLC_Projects\\wbfm_3d_annotation_test-Charlie-2020-10-21\\'
path_config_file = os.path.join(project_folder, 'config.yaml')

video_fname = os.path.join(project_folder, 'videos\\mcherry_frames1000_slice17_22.btf')

# %%
extract_volume_from_tiff_in_dlc_project(path_config_file, nz=nz, which_vol=which_volumes, which_slice=which_slice, video_fname=video_fname)
# Out:
# Config file read successfully.
# Reading volume 100/4
# Converted volume indices: 3300 to 3332 (not including last frame)
# Saved volume to C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\labeled-data\mcherry_frames1000_slice17_22\img100.tif
# Reading volume 101/4
# Converted volume indices: 3333 to 3365 (not including last frame)
# Saved volume to C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\labeled-data\mcherry_frames1000_slice17_22\img101.tif
# Reading volume 102/4
# Converted volume indices: 3366 to 3398 (not including last frame)
# Saved volume to C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\labeled-data\mcherry_frames1000_slice17_22\img102.tif
# Reading volume 103/4
# Converted volume indices: 3399 to 3431 (not including last frame)
# Saved volume to C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\labeled-data\mcherry_frames1000_slice17_22\img103.tif
# Reading volume 104/4
# Converted volume indices: 3432 to 3464 (not including last frame)
# Saved volume to C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\labeled-data\mcherry_frames1000_slice17_22\img104.tif

# %% [markdown]
# ### Synchronize the chosen volumes with training frames
#
# For now, just pops up the GUI to do it manually

# %%
deeplabcut.extract_frames(path_config_file, mode='manual')

# %% [markdown]
# ## Now, use ICY to annotate in 3d

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Convert the generated .xml file to DLC format
from DLC_for_WBFM.utils.training_data.DLC_XML_conversion_utils import *
import deeplabcut

# %%
project_folder = 'C:\\Users\\charles.fieseler\\Documents\\Current_work\\DLC_for_WBFM\\DLC_Projects\\wbfm_3d_annotation_test-Charlie-2020-10-21\\'
path_config_file = os.path.join(project_folder, 'config.yaml')

video_fname = os.path.join(project_folder, 'videos\\mcherry_frames1000_slice17_22.btf')

# %%
df = icy_xml_to_dlc(path_config_file)
# Out:
# Found .xml annotations: Icy_annotations.xml
# Found 1 group(s) of tracks
# Relative image names:
# ['labeled-data\\mcherry_frames1000_slice17_22\\img0000.png', 'labeled-data\\mcherry_frames1000_slice17_22\\img0001.png', 'labeled-data\\mcherry_frames1000_slice17_22\\img0002.png', 'labeled-data\\mcherry_frames1000_slice17_22\\img0003.png', 'labeled-data\\mcherry_frames1000_slice17_22\\img0004.png']
# ['neuron0', 'neuron1', 'neuron2', 'neuron3', 'neuron4', 'neuron5', 'neuron6', 'neuron7', 'neuron8', 'neuron9', 'neuron10', 'neuron11', 'neuron12', 'neuron13', 'neuron14', 'neuron15', 'neuron16', 'neuron17', 'neuron18', 'neuron19']
# ['bodypart1', 'bodypart2', 'bodypart3', 'objectA']
# Finished writing .csv and .h5; wrote 20 neurons
# Found .xml annotations: Icy_annotations.xml
# Adding body part annotations for 20 neurons
# Finished! Check the config.yaml file to make sure the bodyparts are properly written
# Finished updating config file with

# %%
# Check the annotations
deeplabcut.create_training_dataset(path_config_file)
deeplabcut.check_labels(path_config_file)
# Out:
# C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\training-datasets\iteration-0\UnaugmentedDataSet_wbfm_3d_annotation_testOct21  already exists!
# Downloading a ImageNet-pretrained model from http://download.tensorflow.org/models/resnet_v1_50_2016_08_28.tar.gz....
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# Creating images with labels by Charlie.
# They are stored in the following folder: C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\wbfm_3d_annotation_test-Charlie-2020-10-21\labeled-data\mcherry_frames1000_slice17_22_labeled.
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %%
df.to_hdf(project_folder+"tmp.h5",'df_with_missing',format='table', mode='w')

# %%
df2 = pd.read_hdf(project_folder+"tmp.h5")

# %%
df2
# Out:
# scorer                                             Charlie                 \
# bodyparts                                          neuron0        neuron1
# coords                                                   x      y       x
# labeled-data\mcherry_frames1000_slice17_22\img0...   390.0  319.0   395.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   366.0  328.0   372.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   348.0  323.0   357.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   348.0  321.0   360.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   352.0  318.0   367.0
#
# scorer                                                                    \
# bodyparts                                                 neuron2
# coords                                                  y       x      y
# labeled-data\mcherry_frames1000_slice17_22\img0...  306.0   404.0  313.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  313.0   376.0  323.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  308.0   357.0  319.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  306.0   359.0  318.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  309.0   366.0  321.0
#
# scorer                                                                     \
# bodyparts                                          neuron3        neuron4
# coords                                                   x      y       x
# labeled-data\mcherry_frames1000_slice17_22\img0...   419.0  318.0   388.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   390.0  332.0   372.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   366.0  329.0   364.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   366.0  329.0   372.0
# labeled-data\mcherry_frames1000_slice17_22\img0...   373.0  330.0   375.0
#
# scorer                                                     ...           \
# bodyparts                                                  ... neuron15
# coords                                                  y  ...        x
# labeled-data\mcherry_frames1000_slice17_22\img0...  289.0  ...    378.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  291.0  ...    380.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  279.0  ...    391.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  291.0  ...    397.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  281.0  ...    407.0
#
# scorer                                                                     \
# bodyparts                                                 neuron16
# coords                                                  y        x      y
# labeled-data\mcherry_frames1000_slice17_22\img0...  234.0    376.0  225.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  238.0    380.0  229.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  227.0    395.0  219.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  238.0    400.0  228.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  232.0    410.0  224.0
#
# scorer                                                                       \
# bodyparts                                          neuron17        neuron18
# coords                                                    x      y        x
# labeled-data\mcherry_frames1000_slice17_22\img0...    358.0  201.0    367.0
# labeled-data\mcherry_frames1000_slice17_22\img0...    375.0  197.0    378.0
# labeled-data\mcherry_frames1000_slice17_22\img0...    397.0  185.0    395.0
# labeled-data\mcherry_frames1000_slice17_22\img0...    401.0  193.0    401.0
# labeled-data\mcherry_frames1000_slice17_22\img0...    405.0  184.0    406.0
#
# scorer
# bodyparts                                                 neuron19
# coords                                                  y        x      y
# labeled-data\mcherry_frames1000_slice17_22\img0...  217.0    348.0  208.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  217.0    365.0  200.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  205.0    385.0  184.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  215.0    391.0  194.0
# labeled-data\mcherry_frames1000_slice17_22\img0...  208.0    392.0  184.0
#
# [5 rows x 40 columns]

# %%
df3 = pd.read_hdf(project_folder+"CollectedData_Charlie.h5")

# %%
df3['Charlie'].shape
# Out:
# (5, 40)

# %%
df_old = pd.read_hdf(r"C:\Users\charles.fieseler\Documents\Current_work\DLC_for_WBFM\DLC_Projects\Chip_with_WBFM_hardware_z8_FULL-Charlie-2020-10-15\labeled-data\27082020_trial2_HEAD_500frames_mcherry_slice8\CollectedData_Charlie.h5")

# %%
df_old['Charlie'].shape
# Out:
# (9, 18)

# %%
# %debug
# Out:
# > c:\users\charles.fieseler\anaconda3\envs\dlc-preprocessing\lib\site-packages\pandas\core\indexes\multi.py(2980)_get_level_indexer()
#    2978             if i == j:
#    2979                 # The label is present in self.levels[level] but unused:
# -> 2980                 raise KeyError(key)
#    2981             return slice(i, j)
#    2982
#
# ipdb> u
# > c:\users\charles.fieseler\anaconda3\envs\dlc-preprocessing\lib\site-packages\pandas\core\indexes\multi.py(2701)get_loc()
#    2699
#    2700         if not isinstance(key, tuple):
# -> 2701             loc = self._get_level_indexer(key, level=0)
#    2702             return _maybe_to_slice(loc)
#    2703
#
# ipdb> u
# > c:\users\charles.fieseler\anaconda3\envs\dlc-preprocessing\lib\site-packages\pandas\core\frame.py(2951)_getitem_multilevel()
#    2949     def _getitem_multilevel(self, key):
#    2950         # self.columns is a MultiIndex
# -> 2951         loc = self.columns.get_loc(key)
#    2952         if isinstance(loc, (slice, np.ndarray)):
#    2953             new_columns = self.columns[loc]
#
# ipdb> u
# > c:\users\charles.fieseler\anaconda3\envs\dlc-preprocessing\lib\site-packages\pandas\core\frame.py(2901)__getitem__()
#    2899         if is_single_key:
#    2900             if self.columns.nlevels > 1:
# -> 2901                 return self._getitem_multilevel(key)
#    2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#
# ipdb> u
# > c:\users\charles.fieseler\anaconda3\envs\dlc-preprocessing\lib\site-packages\deeplabcut\generate_training_dataset\trainingsetmanipulation.py(635)create_training_dataset()
#     633
#     634     Data = merge_annotateddatasets(cfg,project_path,Path(os.path.join(project_path,trainingsetfolder)),windows2linux)
# --> 635     Data = Data[scorer] #extract labeled data
#     636
#     637     #loading & linking pretrained models
#
# ipdb> Data
# Empty DataFrame
# Columns: []
# Index: [labeled-data\mcherry_frames1000_slice17_22\img0000.png, labeled-data\mcherry_frames1000_slice17_22\img0001.png, labeled-data\mcherry_frames1000_slice17_22\img0002.png, labeled-data\mcherry_frames1000_slice17_22\img0003.png, labeled-data\mcherry_frames1000_slice17_22\img0004.png]
# ipdb> Data[0]
# *** KeyError: 0
# ipdb> DataFrame.shape
# *** NameError: name 'DataFrame' is not defined
# ipdb> len(DataFrame)
# *** NameError: name 'DataFrame' is not defined
# ipdb> Data.shape
# (5, 0)
# ipdb> len(Data)
# 5
# ipdb> q
