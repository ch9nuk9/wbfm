# %% [markdown]
# # Ome-tiff
#
# ## Write from a folder of different files
#
# Takes in a folder of individual volumes and writes them to one ome-tiff video file

# %%
import h5py
import numpy as np
import tifffile
import os

from video_conversion_utils import *

# %%
# Take a subset of data; full volumes
num_frames = 100

# Data location
# folder_name = '/groups/zimmer/Ulises/wbfm/wbfm_december2018/20181220/data/worm1/mCherry/ome/'
folder_name = '/users/charles.fieseler/DeepLabCut-dev/DLC_postprocessing/aligned_volumes/'

# Output location
out_fname = '/users/charles.fieseler/test_worm1_data/mCherry_volume_aligned/test_{}frames.ome.tiff'.format(num_frames)
out_dtype = 'uint16'

# No return, just writes the file
dat = write_video_from_ome_folder(num_frames, folder_name, out_fname,
                               out_dtype=out_dtype)
# Out:
# Final shape should be:  [100, 39, 650, 850]
# Reading frame 1/100:
# Reading frame 2/100:
# Reading frame 3/100:
# Reading frame 4/100:
# Reading frame 5/100:
# Reading frame 6/100:
# Reading frame 7/100:
# Reading frame 8/100:
# Reading frame 9/100:
# Reading frame 10/100:
# Reading frame 11/100:
# Reading frame 12/100:
# Reading frame 13/100:
# Reading frame 14/100:
# Reading frame 15/100:
# Reading frame 16/100:
# Reading frame 17/100:
# Reading frame 18/100:
# Reading frame 19/100:
# Reading frame 20/100:
# Reading frame 21/100:
# Reading frame 22/100:
# Reading frame 23/100:
# Reading frame 24/100:
# Reading frame 25/100:
# Reading frame 26/100:
# Reading frame 27/100:
# Reading frame 28/100:
# Reading frame 29/100:
# Reading frame 30/100:
# Reading frame 31/100:
# Reading frame 32/100:
# Reading frame 33/100:
# Reading frame 34/100:
# Reading frame 35/100:
# Reading frame 36/100:
# Reading frame 37/100:
# Reading frame 38/100:
# Reading frame 39/100:
# Reading frame 40/100:
# Reading frame 41/100:
# Reading frame 42/100:
# Reading frame 43/100:
# Reading frame 44/100:
# Reading frame 45/100:
# Reading frame 46/100:
# Reading frame 47/100:
# Reading frame 48/100:
# Reading frame 49/100:
# Reading frame 50/100:
# Reading frame 51/100:
# Reading frame 52/100:
# Reading frame 53/100:
# Reading frame 54/100:
# Reading frame 55/100:
# Reading frame 56/100:
# Reading frame 57/100:
# Reading frame 58/100:
# Reading frame 59/100:
# Reading frame 60/100:
# Reading frame 61/100:
# Reading frame 62/100:
# Reading frame 63/100:
# Reading frame 64/100:
# Reading frame 65/100:
# Reading frame 66/100:
# Reading frame 67/100:
# Reading frame 68/100:
# Reading frame 69/100:
# Reading frame 70/100:
# Reading frame 71/100:
# Reading frame 72/100:
# Reading frame 73/100:
# Reading frame 74/100:
# Reading frame 75/100:
# Reading frame 76/100:
# Reading frame 77/100:
# Reading frame 78/100:
# Reading frame 79/100:
# Reading frame 80/100:
# Reading frame 81/100:
# Reading frame 82/100:
# Reading frame 83/100:
# Reading frame 84/100:
# Reading frame 85/100:
# Reading frame 86/100:
# Reading frame 87/100:
# Reading frame 88/100:
# Reading frame 89/100:
# Reading frame 90/100:
# Reading frame 91/100:
# Reading frame 92/100:
# Reading frame 93/100:
# Reading frame 94/100:
# Reading frame 95/100:
# Reading frame 96/100:
# Reading frame 97/100:
# Reading frame 98/100:
# Reading frame 99/100:
# Reading frame 100/100:

# %%
# Take a subset of data; single slice
num_frames = 100
which_slice = 13

# Data location
folder_name = '/groups/zimmer/Ulises/wbfm/wbfm_december2018/20181220/data/worm1/mCherry/ome/'

# Output location
out_fname = '/users/charles.fieseler/test_worm1_data/mCherry/test_{}frames_{}slice.ome.tiff'.format(num_frames, which_slice)

# Writes the file
dat = write_video_from_ome_folder(num_frames, folder_name, out_fname,
                               which_slice=which_slice)

# %% [markdown]
# ## Write from a single large file

# %%
# mCherry
foldername = '/users/charles.fieseler/Oriana_data/worm3/ScarletTracking/'
fname = '15052020_GCaMPXX_worm3_gfp5cherry1gain100_20ms4-Add_w1dual2-GFP-mCherry-SD-DV--488Ex--561Ex_Scarlet.ome.tif'
# GCaMP
# foldername = '/users/charles.fieseler/Oriana_data/worm3/GCaMP/'
# fname = '15052020_GCaMPXX_worm3_gfp5cherry1gain100_20ms4-Add_w2dual1-GFP-mCherry-SD-DV--488Ex--561Ex_GCaMP.ome.tif'
video_fname = os.path.join(foldername, fname)

num_frames = 50
which_slice = 'all'
out_fname = '/users/charles.fieseler/test_worm1_data/immobilized/test_uint16_{}frames_{}slice.ome.tiff'.format(num_frames, which_slice)
which_slice = None

dat = write_video_from_ome_file(num_frames, video_fname, out_fname, which_slice=which_slice, out_dtype='uint32')
# Out:
# dict_keys(['Image', 'Creator', 'UUID', '{http://www.w3.org/2001/XMLSchema-instance}schemaLocation'])
# Read volume 0/50
# Final shape should be:  [50, 14, 209, 505]
# Read volume 1/50
# Read volume 2/50
# Read volume 3/50
# Read volume 4/50
# Read volume 5/50
# Read volume 6/50
# Read volume 7/50
# Read volume 8/50
# Read volume 9/50
# Read volume 10/50
# Read volume 11/50
# Read volume 12/50
# Read volume 13/50
# Read volume 14/50
# Read volume 15/50
# Read volume 16/50
# Read volume 17/50
# Read volume 18/50
# Read volume 19/50
# Read volume 20/50
# Read volume 21/50
# Read volume 22/50
# Read volume 23/50
# Read volume 24/50
# Read volume 25/50
# Read volume 26/50
# Read volume 27/50
# Read volume 28/50
# Read volume 29/50
# Read volume 30/50
# Read volume 31/50
# Read volume 32/50
# Read volume 33/50
# Read volume 34/50
# Read volume 35/50
# Read volume 36/50
# Read volume 37/50
# Read volume 38/50
# Read volume 39/50
# Read volume 40/50
# Read volume 41/50
# Read volume 42/50
# Read volume 43/50
# Read volume 44/50
# Read volume 45/50
# Read volume 46/50
# Read volume 47/50
# Read volume 48/50
# Read volume 49/50

# %% [markdown]
# # Save: .avi

# %%
# fname = '/users/charles.fieseler/test_worm1_data/mCherry_slices/test_{}frames_{}slice'.format(num_frames, which_slice)

write_numpy_as_avi(dat, fname=out_fname) # e.g. from above OME-TIFF
# Out:
# Writing to /users/charles.fieseler/test_worm1_data/GCaMP/test_100frames.ome.tiff.avi
# Writing frame 0/100
# Writing frame 10/100
# Writing frame 20/100
# Writing frame 30/100
# Writing frame 40/100
# Writing frame 50/100
# Writing frame 60/100
# Writing frame 70/100
# Writing frame 80/100
# Writing frame 90/100
# Finished

# %% [markdown]
# # Sanity checking

# %%
frame = cv2.convertScaleAbs(dat[0,...])#, alpha=(255.0/65535.0))

print(np.max(frame))

plt.figure(figsize=(15,15))
plt.imshow(frame)
# Out:
# 255
